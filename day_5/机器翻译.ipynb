# %% [markdown]
# # 机器翻译
#
# 本教程源代码目录在[book/machine_translation](https://github.com/PaddlePaddle/book/tree/develop/08.machine_translation),初次使用请您参考[Book文档使用说明](https://github.com/PaddlePaddle/book/blob/develop/README.cn.md#运行这本书)。
#
# ### 说明
# 1. 硬件要求 本文可支持在CPU、GPU下运行
# 2. 对docker file cuda/cudnn的支持 如果您使用了本文配套的docker镜像，请注意：该镜像对GPU的支持仅限于CUDA 8，cuDNN 5
# 3. 文档中代码和train.py不一致的问题 请注意：为使本文更加易读易用，我们拆分、调整了train.py的代码并放入本文。本文中代码与train.py的运行结果一致，如希望直接看到训练脚本输出效果，可运行[train.py](https://github.com/PaddlePaddle/book/blob/develop/08.machine_translation/train.py)。
#
# ## 背景介绍
#
# 机器翻译（machine translation, MT）是用计算机来实现不同语言之间翻译的技术。被翻译的语言通常称为源语言（source language），翻译成的结果语言称为目标语言（target language）。机器翻译即实现从源语言到目标语言转换的过程，是自然语言处理的重要研究领域之一。
#
# 早期机器翻译系统多为基于规则的翻译系统，需要由语言学家编写两种语言之间的转换规则，再将这些规则录入计算机。该方法对语言学家的要求非常高，而且我们几乎无法总结一门语言会用到的所有规则，更何况两种甚至更多的语言。因此，传统机器翻译方法面临的主要挑战是无法得到一个完备的规则集合\[[1](#参考文献)\]。
#
# 为解决以上问题，统计机器翻译（Statistical Machine Translation, SMT）技术应运而生。在统计机器翻译技术中，转化规则是由机器自动从大规模的语料中学习得到的，而非我们人主动提供规则。因此，它克服了基于规则的翻译系统所面临的知识获取瓶颈的问题，但仍然存在许多挑战：1）人为设计许多特征（feature），但永远无法覆盖所有的语言现象；2）难以利用全局的特征；3）依赖于许多预处理环节，如词语对齐、分词或符号化（tokenization）、规则抽取、句法分析等，而每个环节的错误会逐步累积，对翻译的影响也越来越大。
#
# 近年来，深度学习技术的发展为解决上述挑战提供了新的思路。将深度学习应用于机器翻译任务的方法大致分为两类：1）仍以统计机器翻译系统为框架，只是利用神经网络来改进其中的关键模块，如语言模型、调序模型等（见图1的左半部分）；2）不再以统计机器翻译系统为框架，而是直接用神经网络将源语言映射到目标语言，即端到端的神经网络机器翻译（End-to-End Neural Machine Translation, End-to-End NMT）（见图1的右半部分），简称为NMT模型。
# <div align="center">
# <img src="./nmt.png" width = "400" align=center/><br/>
# 图1. 基于神经网络的机器翻译系统
# </div>
#
# 本教程主要介绍NMT模型，以及如何用PaddlePaddle来训练一个NMT模型。
#
# ## 效果展示
#
# 以中英翻译（中文翻译到英文）的模型为例，当模型训练完毕时，如果输入如下已分词的中文句子：

# %% [markdown]
# 这些 是 希望 的 曙光 和 解脱 的 迹象 .

# %% [markdown]
# 如果设定显示翻译结果的条数（即[柱搜索算法](#柱搜索算法)的宽度）为3，生成的英语句子如下：

# %% [markdown]
# 0 -5.36816   These are signs of hope and relief . <e>
# 1 -6.23177   These are the light of hope and relief . <e>
# 2 -7.7914  These are the light of hope and the relief of hope . <e>

# %% [markdown]
# - 左起第一列是生成句子的序号；左起第二列是该条句子的得分（从大到小），分值越高越好；左起第三列是生成的英语句子。
#
# - 另外有两个特殊标志：`<e>`表示句子的结尾，`<unk>`表示未登录词（unknown word），即未在训练字典中出现的词。
#
# ## 模型概览
#
# 本节依次介绍GRU（Gated Recurrent Unit，门控循环单元），双向循环神经网络（Bi-directional Recurrent Neural Network），NMT模型中典型的编码器-解码器（Encoder-Decoder）框架和注意力（Attention）机制，以及柱搜索（beam search）算法。
#
# ### GRU
#
# 我们已经在[情感分析](https://github.com/PaddlePaddle/book/blob/develop/06.understand_sentiment/README.cn.md)一章中介绍了循环神经网络（RNN）及长短时间记忆网络（LSTM）。相比于简单的RNN，LSTM增加了记忆单元（memory cell）、输入门（input gate）、遗忘门（forget gate）及输出门（output gate），这些门及记忆单元组合起来大大提升了RNN处理远距离依赖问题的能力。
#
# GRU\[[2](#参考文献)\]是Cho等人在LSTM上提出的简化版本，也是RNN的一种扩展，如下图所示。GRU单元只有两个门：
# - 重置门（reset gate）：如果重置门关闭，会忽略掉历史信息，即历史不相干的信息不会影响未来的输出。
# - 更新门（update gate）：将LSTM的输入门和遗忘门合并，用于控制历史信息对当前时刻隐层输出的影响。如果更新门接近1，会把历史信息传递下去。
# <p align="center">
# <img src="./gru.png" width=700><br/>
# 图2. GRU（门控循环单元）
# </p>
#
# 一般来说，具有短距离依赖属性的序列，其重置门比较活跃；相反，具有长距离依赖属性的序列，其更新门比较活跃。另外，Chung等人\[[3](#参考文献)\]通过多组实验表明，GRU虽然参数更少，但是在多个任务上都和LSTM有相近的表现。
#
# ### 双向循环神经网络
#
# 我们已经在[语义角色标注](https://github.com/PaddlePaddle/book/blob/develop/07.label_semantic_roles/README.cn.md)一章中介绍了一种双向循环神经网络，这里介绍Bengio团队在论文\[[2](#参考文献),[4](#参考文献)\]中提出的另一种结构。该结构的目的是输入一个序列，得到其在每个时刻的特征表示，即输出的每个时刻都用定长向量表示到该时刻的上下文语义信息。
#
# 具体来说，该双向循环神经网络分别在时间维以顺序和逆序——即前向（forward）和后向（backward）——依次处理输入序列，并将每个时间步RNN的输出拼接成为最终的输出层。这样每个时间步的输出节点，都包含了输入序列中当前时刻完整的过去和未来的上下文信息。下图展示的是一个按时间步展开的双向循环神经网络。该网络包含一个前向和一个后向RNN，其中有六个权重矩阵：输入到前向隐层和后向隐层的权重矩阵（$W_1, W_3$），隐层到隐层自己的权重矩阵（$W_2,W_5$），前向隐层和后向隐层到输出层的权重矩阵（$W_4, W_6$）。注意，该网络的前向隐层和后向隐层之间没有连接。
#
#
# <div align="center">
# <img src = "./bi_rnn.png" width="400"><br/>
# 图2. 按时间步展开的双向循环神经网络
# </div>
#
# ### 编码器-解码器框架
#
# 编码器-解码器（Encoder-Decoder）\[[2](#参考文献)\]框架用于解决由一个任意长度的源序列到另一个任意长度的目标序列的变换问题。即编码阶段将整个源序列编码成一个向量，解码阶段通过最大化预测序列概率，从中解码出整个目标序列。编码和解码的过程通常都使用RNN实现。
#
# <div align="center">
# <img src ="./encoder_decoder.png" width="700"><br/>
# 图3. 编码器-解码器框架
# </div>
#
# <a name="编码器"></a>
# #### 编码器
#
# 编码阶段分为三步：
#
# 1. one-hot vector表示：将源语言句子$x=\left \{ x_1,x_2,...,x_T \right \}$的每个词$x_i$表示成一个列向量$w_i\epsilon \left \{ 0,1 \right \}^{\left | V \right |},i=1,2,...,T$。这个向量$w_i$的维度与词汇表大小$\left | V \right |$ 相同，并且只有一个维度上有值1（该位置对应该词在词汇表中的位置），其余全是0。
#
# 2. 映射到低维语义空间的词向量：one-hot vector表示存在两个问题，1）生成的向量维度往往很大，容易造成维数灾难；2）难以刻画词与词之间的关系（如语义相似性，也就是无法很好地表达语义）。因此，需再one-hot vector映射到低维的语义空间，由一个固定维度的稠密向量（称为词向量）表示。记映射矩阵为$C\epsilon R^{K\times \left | V \right |}$，用$s_i=Cw_i$表示第$i$个词的词向量，$K$为向量维度。
#
# 3. 用RNN编码源语言词序列：这一过程的计算公式为$h_i=\varnothing _\theta \left ( h_{i-1}, s_i \right )$，其中$h_0$是一个全零的向量，$\varnothing _\theta$是一个非线性激活函数，最后得到的$\mathbf{h}=\left \{ h_1,..., h_T \right \}$就是RNN依次读入源语言$T$个词的状态编码序列。整句话的向量表示可以采用$\mathbf{h}$在最后一个时间步$T$的状态编码，或使用时间维上的池化（pooling）结果。
#
# 第3步也可以使用双向循环神经网络实现更复杂的句编码表示，具体可以用双向GRU实现。前向GRU按照词序列$(x_1,x_2,...,x_T)$的顺序依次编码源语言端词，并得到一系列隐层状态$(\overrightarrow{h_1},\overrightarrow{h_2},...,\overrightarrow{h_T})$。类似的，后向GRU按照$(x_T,x_{T-1},...,x_1)$的顺序依次编码源语言端词，得到$(\overleftarrow{h_1},\overleftarrow{h_2},...,\overleftarrow{h_T})$。最后对于词$x_i$，通过拼接两个GRU的结果得到它的隐层状态，即$h_i=\left [ \overrightarrow{h_i^T},\overleftarrow{h_i^T} \right ]^{T}$。
# <div align="center">
# <img src="./encoder_attention.png" width="400"><br/>
# 图4. 使用双向GRU的编码器
# </div>
#
# #### 解码器
#
# 机器翻译任务的训练过程中，解码阶段的目标是最大化下一个正确的目标语言词的概率。思路是：
# 1. 每一个时刻，根据源语言句子的编码信息（又叫上下文向量，context vector）$c$、真实目标语言序列的第$i$个词$u_i$和$i$时刻RNN的隐层状态$z_i$，计算出下一个隐层状态$z_{i+1}$。计算公式如下：
#
# <div align="center">
# <img src="./decoder_formula.png" width="200"><br/>
# </div>
#
# 其中$\phi _{\theta '}$是一个非线性激活函数；$c$是源语言句子的上下文向量，在不使用注意力机制时，如果[编码器](#编码器)的输出是源语言句子编码后的最后一个元素，则可以定义$c=h_T$；$u_i$是目标语言序列的第$i$个单词，$u_0$是目标语言序列的开始标记`<s>`，表示解码开始；$z_i$是$i$时刻解码RNN的隐层状态，$z_0$是一个全零的向量。
#
# 1. 将$z_{i+1}$通过`softmax`归一化，得到目标语言序列的第$i+1$个单词的概率分布$p_{i+1}$。概率分布公式如下：
#
# <div align="center">
# <img src="./probability_formula.png" width="400"><br/>
# </div>
#
# 其中$W_sz_{i+1}+b_z$是对每个可能的输出单词进行打分，再用softmax归一化就可以得到第$i+1$个词的概率$p_{i+1}$。
#
# 1. 根据$p_{i+1}$和$u_{i+1}$计算代价。
#
# 2. 重复步骤1~3，直到目标语言序列中的所有词处理完毕。
#
# 机器翻译任务的生成过程，通俗来讲就是根据预先训练的模型来翻译源语言句子。生成过程中的解码阶段和上述训练过程的有所差异，具体介绍请见[柱搜索算法](#柱搜索算法)。
#
# ### 注意力机制
#
# 如果编码阶段的输出是一个固定维度的向量，会带来以下两个问题：1）不论源语言序列的长度是5个词还是50个词，如果都用固定维度的向量去编码其中的语义和句法结构信息，对模型来说是一个非常高的要求，特别是对长句子序列而言；2）直觉上，当人类翻译一句话时，会对与当前译文更相关的源语言片段上给予更多关注，且关注点会随着翻译的进行而改变。而固定维度的向量则相当于，任何时刻都对源语言所有信息给予了同等程度的关注，这是不合理的。因此，Bahdanau等人\[[4](#参考文献)\]引入注意力（attention）机制，可以对编码后的上下文片段进行解码，以此来解决长句子的特征学习问题。下面介绍在注意力机制下的解码器结构。
#
# 与简单的解码器不同，这里$z_i$的计算公式为：
#
# <div align="center">
# <img src="./attention_decoder_formula.png" width="200"><br/>
# </div>
#
# 可见，源语言句子的编码向量表示为第$i$个词的上下文片段$c_i$，即针对每一个目标语言中的词$u_i$，都有一个特定的$c_i$与之对应。$c_i$的计算公式如下：
#
# <div align="center">
# <img src="./sum_formula.png" width="300"><br/>
# </div>
#
# 从公式中可以看出，注意力机制是通过对编码器中各时刻的RNN状态$h_j$进行加权平均实现的。权重$a_{ij}$表示目标语言中第$i$个词对源语言中第$j$个词的注意力大小，$a_{ij}$的计算公式如下：
#
# <div align="center">
# <img src="./weight_formula.png" width="300"><br/>
# </div>
#
# 其中，$align$可以看作是一个对齐模型，用来衡量目标语言中第$i$个词和源语言中第$j$个词的匹配程度。具体而言，这个程度是通过解码RNN的第$i$个隐层状态$z_i$和源语言句子的第$j$个上下文片段$h_j$计算得到的。传统的对齐模型中，目标语言的每个词明确对应源语言的一个或多个词（hard alignment）；而在注意力模型中采用的是soft alignment，即任何两个目标语言和源语言词间均存在一定的关联，且这个关联强度是由模型计算得到的实数，因此可以融入整个NMT框架，并通过反向传播算法进行训练。
#
# <p align="center">
# <img src="./decoder_attention.png" width=500><br/>
# 图6. 基于注意力机制的解码器
# </p>
#
# <a name="柱搜索算法"></a>
# ### 柱搜索算法
#
# 柱搜索（[beam search](http://en.wikipedia.org/wiki/Beam_search)）是一种启发式图搜索算法，用于在图或树中搜索有限集合中的最优扩展节点，通常用在解空间非常大的系统（如机器翻译、语音识别）中，原因是内存无法装下图或树中所有展开的解。如在机器翻译任务中希望翻译“`<s>你好<e>`”，就算目标语言字典中只有3个词（`<s>`, `<e>`, `hello`），也可能生成无限句话（`hello`循环出现的次数不定），为了找到其中较好的翻译结果，我们可采用柱搜索算法。
#
# 柱搜索算法使用广度优先策略建立搜索树，在树的每一层，按照启发代价（heuristic cost）（本教程中，为生成词的log概率之和）对节点进行排序，然后仅留下预先确定的个数（文献中通常称为beam width、beam size、柱宽度等）的节点。只有这些节点会在下一层继续扩展，其他节点就被剪掉了，也就是说保留了质量较高的节点，剪枝了质量较差的节点。因此，搜索所占用的空间和时间大幅减少，但缺点是无法保证一定获得最优解。
#
# 使用柱搜索算法的解码阶段，目标是最大化生成序列的概率。思路是：
# 1. 每一个时刻，根据源语言句子的编码信息$c$、生成的第$i$个目标语言序列单词$u_i$和$i$时刻RNN的隐层状态$z_i$，计算出下一个隐层状态$z_{i+1}$。
#
# 2. 将$z_{i+1}$通过`softmax`归一化，得到目标语言序列的第$i+1$个单词的概率分布$p_{i+1}$。
#
# 3. 根据$p_{i+1}$采样出单词$u_{i+1}$。
#
# 4. 重复步骤1~3，直到获得句子结束标记`<e>`或超过句子的最大生成长度为止。
#
# 注意：$z_{i+1}$和$p_{i+1}$的计算公式同[解码器](#解码器)中的一样。且由于生成时的每一步都是通过贪心法实现的，因此并不能保证得到全局最优解。
#
# ## 数据介绍
#
# 本教程使用[WMT-16](http://www.statmt.org/wmt16/)新增的[multimodal task](http://www.statmt.org/wmt16/multimodal-task.html)中的[translation task](http://www.statmt.org/wmt16/multimodal-task.html#task1)的数据集。该数据集为英德翻译数据，包含29001条训练数据，1000条测试数据。
#
# ### 数据预处理
#
# 我们的预处理流程包括两步：
#
# - 将每个源语言到目标语言的平行语料库文件合并为一个文件：
#
# - 合并每个`XXX.src`和`XXX.trg`文件为`XXX`。
#
# - `XXX`中的第$i$行内容为`XXX.src`中的第$i$行和`XXX.trg`中的第$i$行连接，用'\t'分隔。
#
# - 创建训练数据的“源字典”和“目标字典”。每个字典都有**DICTSIZE**个单词，包括：语料中词频最高的（DICTSIZE - 3）个单词，和3个特殊符号`<s>`（序列的开始）、`<e>`（序列的结束）和`<unk>`（未登录词）。
#
# ### 示例数据
#
# 为了验证训练流程，PaddlePaddle接口`paddle.dataset.wmt16`中提供了对该数据集[预处理后的版本](http://paddlemodels.bj.bcebos.com/wmt/wmt16.tar.gz)，调用该接口即可直接使用，因为数据规模限制，这里只作为示例使用，在相应的测试集上具有一定效果但在更多测试数据上的效果无法保证。
#
# ## 模型配置说明
#
# 下面我们开始根据输入数据的形式配置模型。首先引入所需的库函数以及定义全局变量：

# %%
from __future__ import print_function
import os
import six

import paddle
import paddle.fluid as fluid

dict_size = 30000  # 词典大小
source_dict_size = target_dict_size = dict_size  # 源/目标语言字典大小
word_dim = 512  # 词向量维度 多少数字，表示一个词
hidden_dim = 512  # 编码器中的隐层大小 隐含层的数量，神经元的数量 循环神经网络，编码
decoder_size = hidden_dim  # 解码器中的隐层大小，解码
max_length = 256  # 解码生成句子的最大长度 翻译，最长翻译256
beam_size = 4  # beam search的柱宽度
batch_size = 64  # batch 中的样本数 训练过程，一批给多少数据

is_sparse = True # 稀松，表示数据时，稀松表示，节省内存
model_save_dir = "machine_translation.inference.model"

# %% [markdown]
# 然后如下实现编码器框架：

# %%
def encoder():
    # 定义源语言id序列的输入数据
    src_word_id = fluid.layers.data(
        name="src_word_id", shape=[1], dtype='int64', lod_level=1) # 变量
    # 将上述编码映射到低维语言空间的词向量
    src_embedding = fluid.layers.embedding( # 词向量
        input=src_word_id,
        size=[source_dict_size, word_dim],
        dtype='float32',
        is_sparse=is_sparse) # 节省内存
    # 用双向GRU编码源语言序列，拼接两个GRU的编码结果得到h
    fc_forward = fluid.layers.fc(input=src_embedding, size=hidden_dim * 3, bias_attr=False)
    src_forward = fluid.layers.dynamic_gru(input=fc_forward, size=hidden_dim) # 循环神经网络
    
    fc_backward = fluid.layers.fc(input=src_embedding, size=hidden_dim * 3, bias_attr=False)
    src_backward = fluid.layers.dynamic_gru(input=fc_backward, size=hidden_dim, is_reverse=True) # 循环神经网络，反转倒序
    
    encoded_vector = fluid.layers.concat(input=[src_forward, src_backward], axis=1)
    return encoded_vector # 编码好的向量，代表源语言！

# %% [markdown]
# 再实现基于注意力机制的解码器：
#   - 首先定义解码器中单步的计算，即$z_{i+1}=\phi _{\theta '}\left ( c_i,u_i,z_i \right )$，如下：

# %%
# 定义RNN中的单步计算
def cell(x, hidden, encoder_out, encoder_out_proj):
    # 定义attention用以计算context，即 c_i，这里使用Bahdanau attention机制
    def simple_attention(encoder_vec, encoder_proj, decoder_state):
        decoder_state_proj = fluid.layers.fc(input=decoder_state, size=decoder_size, bias_attr=False)
        # sequence_expand将单步内容扩展为与encoder输出相同的序列
        decoder_state_expand = fluid.layers.sequence_expand(x=decoder_state_proj, y=encoder_proj)
        mixed_state = fluid.layers.elementwise_add(encoder_proj,
                                                decoder_state_expand)
        attention_weights = fluid.layers.fc(
            input=mixed_state, size=1, bias_attr=False)
        attention_weights = fluid.layers.sequence_softmax(
            input=attention_weights)
        weigths_reshape = fluid.layers.reshape(x=attention_weights, shape=[-1])
        scaled = fluid.layers.elementwise_mul(
            x=encoder_vec, y=weigths_reshape, axis=0)
        context = fluid.layers.sequence_pool(input=scaled, pool_type='sum')
        return context

    context = simple_attention(encoder_out, encoder_out_proj, hidden)
    out = fluid.layers.fc(
        input=[x, context], size=decoder_size * 3, bias_attr=False)
    out = fluid.layers.gru_unit(
        input=out, hidden=hidden, size=decoder_size * 3)[0]
    return out, out

# %% [markdown]
# - 基于定义的单步计算，使用`DynamicRNN`实现多步循环的训练模式下解码器，如下：

# %%
def train_decoder(encoder_out):
    # 获取编码器输出的最后一步并进行非线性映射以构造解码器RNN的初始状态
    encoder_last = fluid.layers.sequence_last_step(input=encoder_out)
    encoder_last_proj = fluid.layers.fc(input=encoder_last, size=decoder_size, act='tanh')
    # 编码器输出在attention中计算结果的cache
    encoder_out_proj = fluid.layers.fc(input=encoder_out, size=decoder_size, bias_attr=False)

    # 定义目标语言id序列的输入数据，并映射到低维语言空间的词向量
    trg_language_word = fluid.layers.data(
        name="target_language_word", shape=[1], dtype='int64', lod_level=1)
    trg_embedding = fluid.layers.embedding( # 目标语言的词向量编码
        input=trg_language_word,
        size=[target_dict_size, word_dim],
        dtype='float32',
        is_sparse=is_sparse)

    rnn = fluid.layers.DynamicRNN()
    with rnn.block():
        # 获取当前步目标语言输入的词向量
        x = rnn.step_input(trg_embedding)
        # 获取隐层状态
        pre_state = rnn.memory(init=encoder_last_proj, need_reorder=True)
        # 在DynamicRNN中需使用static_input获取encoder相关的内容
        # 对decoder来说这些内容在每个时间步都是固定的
        encoder_out = rnn.static_input(encoder_out)
        encoder_out_proj = rnn.static_input(encoder_out_proj)
        # 执行单步的计算单元
        out, current_state = cell(x, pre_state, encoder_out, encoder_out_proj)
        # 计算归一化的单词预测概率
        prob = fluid.layers.fc(input=out, size=target_dict_size, act='softmax')
        # 更新隐层状态
        rnn.update_memory(pre_state, current_state)
        # 输出预测概率
        rnn.output(prob)

    return rnn()

# %% [markdown]
# 接着就可以使用编码器和解码器定义整个训练网络；为了进行训练还需要定义优化器，如下：

# %%
def train_model():
#     模拟大脑：收到一段语音，大脑就会对其进行编码，翻译，另一种语言的编码对应---->输出
    encoder_out = encoder() # 对一种语言编码，编的合适，定义编码
    
#     翻译结果
    rnn_out = train_decoder(encoder_out) #解码 ，将编码的结果交给了解码，希望解码的结果正确，翻译准确
    
#     目标值
    label = fluid.layers.data(
        name="target_language_next_word", shape=[1], dtype='int64', lod_level=1)
    
    # 定义损失函数
    cost = fluid.layers.cross_entropy(input=rnn_out, label=label) # 定义损失函数，交叉熵
    avg_cost = fluid.layers.mean(cost) # 平均交叉熵
    return avg_cost

def optimizer_func():
    # 设置梯度裁剪
    fluid.clip.set_gradient_clip(
        clip=fluid.clip.GradientClipByGlobalNorm(clip_norm=5.0))
    # 定义先增后降的学习率策略
    lr_decay = fluid.layers.learning_rate_scheduler.noam_decay(hidden_dim, 1000)
    return fluid.optimizer.Adam( # Adam 梯度下降
        learning_rate=lr_decay,
        regularization=fluid.regularizer.L2DecayRegularizer(
            regularization_coeff=1e-4))

# %% [markdown]
# 以上是训练所需的模型构件，预测（生成）模式下基于beam search的解码器需要借助`while_op`实现，如下：

# %%
def infer_decoder(encoder_out):
    # 获取编码器输出的最后一步并进行非线性映射以构造解码器RNN的初始状态
    encoder_last = fluid.layers.sequence_last_step(input=encoder_out)
    encoder_last_proj = fluid.layers.fc(
        input=encoder_last, size=decoder_size, act='tanh')
    # 编码器输出在attention中计算结果的cache
    encoder_out_proj = fluid.layers.fc(
        input=encoder_out, size=decoder_size, bias_attr=False)

    # 最大解码步数
    max_len = fluid.layers.fill_constant(
        shape=[1], dtype='int64', value=max_length) # 256
    # 解码步数计数变量
    counter = fluid.layers.zeros(shape=[1], dtype='int64', force_cpu=True)

    # 定义 tensor array 用以保存各个时间步的内容，并写入初始id，score和state
    init_ids = fluid.layers.data(
        name="init_ids", shape=[1], dtype="int64", lod_level=2)
    init_scores = fluid.layers.data(
        name="init_scores", shape=[1], dtype="float32", lod_level=2)
    ids_array = fluid.layers.array_write(init_ids, i=counter)
    scores_array = fluid.layers.array_write(init_scores, i=counter)
    state_array = fluid.layers.array_write(encoder_last_proj, i=counter)

    # 定义循环终止条件变量
    cond = fluid.layers.less_than(x=counter, y=max_len)
    while_op = fluid.layers.While(cond=cond)
    with while_op.block():
        # 获取解码器在当前步的输入，包括上一步选择的id，对应的score和上一步的state
        pre_ids = fluid.layers.array_read(array=ids_array, i=counter)
        pre_score = fluid.layers.array_read(array=scores_array, i=counter)
        pre_state = fluid.layers.array_read(array=state_array, i=counter)

        # 同train_decoder中的内容，进行RNN的单步计算
        pre_ids_emb = fluid.layers.embedding(
            input=pre_ids,
            size=[target_dict_size, word_dim],
            dtype='float32',
            is_sparse=is_sparse)
        out, current_state = cell(pre_ids_emb, pre_state, encoder_out,
                            encoder_out_proj)
        prob = fluid.layers.fc(
            input=current_state, size=target_dict_size, act='softmax')

        # 计算累计得分，进行beam search
        topk_scores, topk_indices = fluid.layers.topk(prob, k=beam_size)
        accu_scores = fluid.layers.elementwise_add(
            x=fluid.layers.log(topk_scores),
            y=fluid.layers.reshape(pre_score, shape=[-1]),
            axis=0)
        accu_scores = fluid.layers.lod_reset(x=accu_scores, y=pre_ids)
        selected_ids, selected_scores = fluid.layers.beam_search(
            pre_ids, pre_score, topk_indices, accu_scores, beam_size, end_id=1)

        fluid.layers.increment(x=counter, value=1, in_place=True)
        # 将 search 结果写入 tensor array 中
        fluid.layers.array_write(selected_ids, array=ids_array, i=counter)
        fluid.layers.array_write(selected_scores, array=scores_array, i=counter)
        # sequence_expand 作为 gather 使用以获取search结果对应的状态，并更新
        current_state = fluid.layers.sequence_expand(current_state,
                                                     selected_ids)
        fluid.layers.array_write(current_state, array=state_array, i=counter)
        current_enc_out = fluid.layers.sequence_expand(encoder_out,
                                                       selected_ids)
        fluid.layers.assign(current_enc_out, encoder_out)
        current_enc_out_proj = fluid.layers.sequence_expand(
            encoder_out_proj, selected_ids)
        fluid.layers.assign(current_enc_out_proj, encoder_out_proj)

        # 更新循环终止条件
        length_cond = fluid.layers.less_than(x=counter, y=max_len)
        finish_cond = fluid.layers.logical_not(
            fluid.layers.is_empty(x=selected_ids))
        fluid.layers.logical_and(x=length_cond, y=finish_cond, out=cond)

    # 根据保存的每一步的结果，回溯生成最终解码结果
    translation_ids, translation_scores = fluid.layers.beam_search_decode(
        ids=ids_array, scores=scores_array, beam_size=beam_size, end_id=1)

    return translation_ids, translation_scores

# %% [markdown]
# 使用编码器和预测模式的解码器，预测网络定义如下：

# %%
def infer_model():
    encoder_out = encoder()
    translation_ids, translation_scores = infer_decoder(encoder_out)
    return translation_ids, translation_scores

# %% [markdown]
# ## 训练模型
#
# ### 构建训练程序
#
# 定义用于训练的`Program`，在其中创建训练的网络结构并添加优化器。同时还要定义用于初始化的`Program`，在创建训练网络的同时隐式的加入参数初始化的操作。

# %%
train_prog = fluid.Program()
startup_prog = fluid.Program()
with fluid.program_guard(train_prog, startup_prog):
    with fluid.unique_name.guard():
        avg_cost = train_model()
        optimizer = optimizer_func()
        optimizer.minimize(avg_cost)

# %% [markdown]
# ### 定义训练环境与执行器
#
# 定义您的训练环境，可以指定训练是发生在CPU还是GPU上；并基于这个训练环境定义执行器。

# %%
use_cuda = True
# 定义使用设备和执行器
place = fluid.CUDAPlace(0) if use_cuda else fluid.CPUPlace()
exe = fluid.Executor(place)

# %% [markdown]
# ### 构建数据提供器
#
# 使用封装的`paddle.dataset.wmt16.train`接口定义数据生成器，其每次产生一条样本，shuffle和组完batch后作为训练的输入；另外还需要指明输入数据中各字段和`data_layer`定义的各输入的对应关系，这可以通过`DataFeeder`完成, 下面的feeder将产生数据的第一列映射到`src_word_id`这个输入。

# %%
# 定义训练数据生成器
train_data = paddle.batch(
    paddle.reader.shuffle(
        paddle.dataset.wmt16.train(source_dict_size, target_dict_size),
        buf_size=10000),
    batch_size=batch_size)
# DataFeeder完成
feeder = fluid.DataFeeder(
    feed_list=[
        'src_word_id', 'target_language_word', 'target_language_next_word'
    ],
    place=place,
    program=train_prog)

# %% [markdown]
# ### 训练主循环
#
# 通过训练循环数（EPOCH_NUM）来进行训练循环，并且每次循环都保存训练好的参数。注意，循环训练前要首先执行初始化的`Program`来初始化参数。另外作为示例这里EPOCH_NUM设置较小，该数据集上实际大概需要20个epoch左右收敛。

# %%
# 执行初始化 Program，进行参数初始化
exe.run(startup_prog)
# 循环迭代执行训练
EPOCH_NUM = 18
for pass_id in six.moves.xrange(EPOCH_NUM):
    batch_id = 0
    for data in train_data():
        cost = exe.run(
            train_prog, feed=feeder.feed(data), fetch_list=[avg_cost])[0]
        print('pass_id: %d, batch_id: %d, loss: %f' % (pass_id, batch_id,
                                                        cost))
        batch_id += 1
    # 保存模型
    fluid.io.save_params(exe, model_save_dir, main_program=train_prog)
# Out:
# pass_id: 0, batch_id: 0, loss: 10.309033
# pass_id: 0, batch_id: 1, loss: 10.309109
# pass_id: 0, batch_id: 2, loss: 10.308564
# pass_id: 0, batch_id: 3, loss: 10.307018
# pass_id: 0, batch_id: 4, loss: 10.304734
# pass_id: 0, batch_id: 5, loss: 10.301283
# pass_id: 0, batch_id: 6, loss: 10.295944
# pass_id: 0, batch_id: 7, loss: 10.289010
# pass_id: 0, batch_id: 8, loss: 10.278788
# pass_id: 0, batch_id: 9, loss: 10.264537
# pass_id: 0, batch_id: 10, loss: 10.237727
# pass_id: 0, batch_id: 11, loss: 10.191200
# pass_id: 0, batch_id: 12, loss: 10.075276
# pass_id: 0, batch_id: 13, loss: 9.709288
# pass_id: 0, batch_id: 14, loss: 9.267098
# pass_id: 0, batch_id: 15, loss: 8.844710
# pass_id: 0, batch_id: 16, loss: 8.338139
# pass_id: 0, batch_id: 17, loss: 7.689950
# pass_id: 0, batch_id: 18, loss: 7.102168
# pass_id: 0, batch_id: 19, loss: 6.715383
# pass_id: 0, batch_id: 20, loss: 6.443065
# pass_id: 0, batch_id: 21, loss: 6.418921
# pass_id: 0, batch_id: 22, loss: 6.250311
# pass_id: 0, batch_id: 23, loss: 6.135741
# pass_id: 0, batch_id: 24, loss: 6.206826
# pass_id: 0, batch_id: 25, loss: 6.019142
# pass_id: 0, batch_id: 26, loss: 6.074398
# pass_id: 0, batch_id: 27, loss: 6.065973
# pass_id: 0, batch_id: 28, loss: 6.144929
# pass_id: 0, batch_id: 29, loss: 6.069446
# pass_id: 0, batch_id: 30, loss: 5.977684
# pass_id: 0, batch_id: 31, loss: 5.772751
# pass_id: 0, batch_id: 32, loss: 5.963152
# pass_id: 0, batch_id: 33, loss: 5.942574
# pass_id: 0, batch_id: 34, loss: 6.047554
# pass_id: 0, batch_id: 35, loss: 5.859328
# pass_id: 0, batch_id: 36, loss: 5.861662
# pass_id: 0, batch_id: 37, loss: 5.879591
# pass_id: 0, batch_id: 38, loss: 5.925607
# pass_id: 0, batch_id: 39, loss: 5.749765
# pass_id: 0, batch_id: 40, loss: 6.099907
# pass_id: 0, batch_id: 41, loss: 5.896762
# pass_id: 0, batch_id: 42, loss: 5.771705
# pass_id: 0, batch_id: 43, loss: 5.823287
# pass_id: 0, batch_id: 44, loss: 5.984426
# pass_id: 0, batch_id: 45, loss: 5.936198
# pass_id: 0, batch_id: 46, loss: 5.964918
# pass_id: 0, batch_id: 47, loss: 5.902710
# pass_id: 0, batch_id: 48, loss: 5.894820
# pass_id: 0, batch_id: 49, loss: 5.867579
# pass_id: 0, batch_id: 50, loss: 5.682345
# pass_id: 0, batch_id: 51, loss: 5.821299
# pass_id: 0, batch_id: 52, loss: 5.801548
# pass_id: 0, batch_id: 53, loss: 5.690529
# pass_id: 0, batch_id: 54, loss: 5.828625
# pass_id: 0, batch_id: 55, loss: 5.821267
# pass_id: 0, batch_id: 56, loss: 5.748335
# pass_id: 0, batch_id: 57, loss: 5.751829
# pass_id: 0, batch_id: 58, loss: 5.897043
# pass_id: 0, batch_id: 59, loss: 5.878310
# pass_id: 0, batch_id: 60, loss: 5.958480
# pass_id: 0, batch_id: 61, loss: 5.705746
# pass_id: 0, batch_id: 62, loss: 5.897205
# pass_id: 0, batch_id: 63, loss: 5.778736
# pass_id: 0, batch_id: 64, loss: 5.770895
# pass_id: 0, batch_id: 65, loss: 5.670692
# pass_id: 0, batch_id: 66, loss: 5.847653
# pass_id: 0, batch_id: 67, loss: 5.609456
# pass_id: 0, batch_id: 68, loss: 5.820207
# pass_id: 0, batch_id: 69, loss: 5.748645
# pass_id: 0, batch_id: 70, loss: 5.749827
# pass_id: 0, batch_id: 71, loss: 5.712135
# pass_id: 0, batch_id: 72, loss: 5.872025
# pass_id: 0, batch_id: 73, loss: 5.975886
# pass_id: 0, batch_id: 74, loss: 5.832299
# pass_id: 0, batch_id: 75, loss: 5.715001
# pass_id: 0, batch_id: 76, loss: 5.715276
# pass_id: 0, batch_id: 77, loss: 5.673704
# pass_id: 0, batch_id: 78, loss: 5.707038
# pass_id: 0, batch_id: 79, loss: 5.597036
# pass_id: 0, batch_id: 80, loss: 5.869226
# pass_id: 0, batch_id: 81, loss: 5.600985
# pass_id: 0, batch_id: 82, loss: 5.744018
# pass_id: 0, batch_id: 83, loss: 5.498197
# pass_id: 0, batch_id: 84, loss: 5.626670
# pass_id: 0, batch_id: 85, loss: 5.936977
# pass_id: 0, batch_id: 86, loss: 5.592450
# pass_id: 0, batch_id: 87, loss: 5.746199
# pass_id: 0, batch_id: 88, loss: 5.672042
# pass_id: 0, batch_id: 89, loss: 5.511389
# pass_id: 0, batch_id: 90, loss: 5.566180
# pass_id: 0, batch_id: 91, loss: 5.745438
# pass_id: 0, batch_id: 92, loss: 5.622704
# pass_id: 0, batch_id: 93, loss: 5.667134
# pass_id: 0, batch_id: 94, loss: 5.716406
# pass_id: 0, batch_id: 95, loss: 5.658648
# pass_id: 0, batch_id: 96, loss: 5.641342
# pass_id: 0, batch_id: 97, loss: 5.405982
# pass_id: 0, batch_id: 98, loss: 5.618709
# pass_id: 0, batch_id: 99, loss: 5.669881
# pass_id: 0, batch_id: 100, loss: 5.686061
# pass_id: 0, batch_id: 101, loss: 5.487362
# pass_id: 0, batch_id: 102, loss: 5.610390
# pass_id: 0, batch_id: 103, loss: 5.413317
# pass_id: 0, batch_id: 104, loss: 5.722318
# pass_id: 0, batch_id: 105, loss: 5.572934
# pass_id: 0, batch_id: 106, loss: 5.656363
# pass_id: 0, batch_id: 107, loss: 5.588042
# pass_id: 0, batch_id: 108, loss: 5.668130
# pass_id: 0, batch_id: 109, loss: 5.598596
# pass_id: 0, batch_id: 110, loss: 5.603130
# pass_id: 0, batch_id: 111, loss: 5.737634
# pass_id: 0, batch_id: 112, loss: 5.523508
# pass_id: 0, batch_id: 113, loss: 5.704388
# pass_id: 0, batch_id: 114, loss: 5.479033
# pass_id: 0, batch_id: 115, loss: 5.560001
# pass_id: 0, batch_id: 116, loss: 5.646446
# pass_id: 0, batch_id: 117, loss: 5.656035
# pass_id: 0, batch_id: 118, loss: 5.326362
# pass_id: 0, batch_id: 119, loss: 5.515216
# pass_id: 0, batch_id: 120, loss: 5.480901
# pass_id: 0, batch_id: 121, loss: 5.622843
# pass_id: 0, batch_id: 122, loss: 5.204587
# pass_id: 0, batch_id: 123, loss: 5.417517
# pass_id: 0, batch_id: 124, loss: 5.296666
# pass_id: 0, batch_id: 125, loss: 5.402617
# pass_id: 0, batch_id: 126, loss: 5.314600
# pass_id: 0, batch_id: 127, loss: 5.629214
# pass_id: 0, batch_id: 128, loss: 5.459438
# pass_id: 0, batch_id: 129, loss: 5.557045
# pass_id: 0, batch_id: 130, loss: 5.337585
# pass_id: 0, batch_id: 131, loss: 5.392852
# pass_id: 0, batch_id: 132, loss: 5.358306
# pass_id: 0, batch_id: 133, loss: 5.490702
# pass_id: 0, batch_id: 134, loss: 5.343474
# pass_id: 0, batch_id: 135, loss: 5.482245
# pass_id: 0, batch_id: 136, loss: 5.339264
# pass_id: 0, batch_id: 137, loss: 5.415143
# pass_id: 0, batch_id: 138, loss: 5.320620
# pass_id: 0, batch_id: 139, loss: 5.362225
# pass_id: 0, batch_id: 140, loss: 5.480181
# pass_id: 0, batch_id: 141, loss: 5.641285
# pass_id: 0, batch_id: 142, loss: 5.334977
# pass_id: 0, batch_id: 143, loss: 5.216766
# pass_id: 0, batch_id: 144, loss: 5.566852
# pass_id: 0, batch_id: 145, loss: 5.486354
# pass_id: 0, batch_id: 146, loss: 5.480470
# pass_id: 0, batch_id: 147, loss: 5.406596
# pass_id: 0, batch_id: 148, loss: 5.277930
# pass_id: 0, batch_id: 149, loss: 5.177997
# pass_id: 0, batch_id: 150, loss: 5.372434
# pass_id: 0, batch_id: 151, loss: 5.433051
# pass_id: 0, batch_id: 152, loss: 5.298167
# pass_id: 0, batch_id: 153, loss: 5.353612
# pass_id: 0, batch_id: 154, loss: 5.317110
# pass_id: 0, batch_id: 155, loss: 5.430917
# pass_id: 0, batch_id: 156, loss: 5.325873
# pass_id: 0, batch_id: 157, loss: 5.344278
# pass_id: 0, batch_id: 158, loss: 5.333771
# pass_id: 0, batch_id: 159, loss: 5.427428
# pass_id: 0, batch_id: 160, loss: 5.397366
# pass_id: 0, batch_id: 161, loss: 5.513634
# pass_id: 0, batch_id: 162, loss: 5.422625
# pass_id: 0, batch_id: 163, loss: 5.490927
# pass_id: 0, batch_id: 164, loss: 5.292185
# pass_id: 0, batch_id: 165, loss: 5.346212
# pass_id: 0, batch_id: 166, loss: 5.318021
# pass_id: 0, batch_id: 167, loss: 5.272737
# pass_id: 0, batch_id: 168, loss: 5.288477
# pass_id: 0, batch_id: 169, loss: 5.517583
# pass_id: 0, batch_id: 170, loss: 5.192279
# pass_id: 0, batch_id: 171, loss: 5.473548
# pass_id: 0, batch_id: 172, loss: 5.120530
# pass_id: 0, batch_id: 173, loss: 5.303497
# pass_id: 0, batch_id: 174, loss: 5.413722
# pass_id: 0, batch_id: 175, loss: 5.507737
# pass_id: 0, batch_id: 176, loss: 5.431808
# pass_id: 0, batch_id: 177, loss: 5.366877
# pass_id: 0, batch_id: 178, loss: 5.015510
# pass_id: 0, batch_id: 179, loss: 5.165350
# pass_id: 0, batch_id: 180, loss: 5.178838
# pass_id: 0, batch_id: 181, loss: 5.308161
# pass_id: 0, batch_id: 182, loss: 5.155950
# pass_id: 0, batch_id: 183, loss: 5.312706
# pass_id: 0, batch_id: 184, loss: 5.270171
# pass_id: 0, batch_id: 185, loss: 5.320850
# pass_id: 0, batch_id: 186, loss: 5.103294
# pass_id: 0, batch_id: 187, loss: 5.050642
# pass_id: 0, batch_id: 188, loss: 5.321202
# pass_id: 0, batch_id: 189, loss: 5.141872
# pass_id: 0, batch_id: 190, loss: 5.232016
# pass_id: 0, batch_id: 191, loss: 5.455094
# pass_id: 0, batch_id: 192, loss: 5.310616
# pass_id: 0, batch_id: 193, loss: 5.346473
# pass_id: 0, batch_id: 194, loss: 5.241081
# pass_id: 0, batch_id: 195, loss: 5.195024
# pass_id: 0, batch_id: 196, loss: 5.277455
# pass_id: 0, batch_id: 197, loss: 5.207218
# pass_id: 0, batch_id: 198, loss: 5.121508
# pass_id: 0, batch_id: 199, loss: 5.232966
# pass_id: 0, batch_id: 200, loss: 5.283779
# pass_id: 0, batch_id: 201, loss: 5.266332
# pass_id: 0, batch_id: 202, loss: 5.165976
# pass_id: 0, batch_id: 203, loss: 5.280165
# pass_id: 0, batch_id: 204, loss: 5.065462
# pass_id: 0, batch_id: 205, loss: 5.043393
# pass_id: 0, batch_id: 206, loss: 5.172926
# pass_id: 0, batch_id: 207, loss: 4.929812
# pass_id: 0, batch_id: 208, loss: 5.481525
# pass_id: 0, batch_id: 209, loss: 5.123187
# pass_id: 0, batch_id: 210, loss: 5.089492
# pass_id: 0, batch_id: 211, loss: 5.351289
# pass_id: 0, batch_id: 212, loss: 5.217939
# pass_id: 0, batch_id: 213, loss: 5.110686
# pass_id: 0, batch_id: 214, loss: 5.073106
# pass_id: 0, batch_id: 215, loss: 5.165368
# pass_id: 0, batch_id: 216, loss: 5.474913
# pass_id: 0, batch_id: 217, loss: 4.977128
# pass_id: 0, batch_id: 218, loss: 5.138643
# pass_id: 0, batch_id: 219, loss: 5.148786
# pass_id: 0, batch_id: 220, loss: 5.148611
# pass_id: 0, batch_id: 221, loss: 5.218425
# pass_id: 0, batch_id: 222, loss: 5.165510
# pass_id: 0, batch_id: 223, loss: 5.040143
# pass_id: 0, batch_id: 224, loss: 5.015100
# pass_id: 0, batch_id: 225, loss: 5.302050
# pass_id: 0, batch_id: 226, loss: 4.913542
# pass_id: 0, batch_id: 227, loss: 5.041280
# pass_id: 0, batch_id: 228, loss: 5.224446
# pass_id: 0, batch_id: 229, loss: 4.948337
# pass_id: 0, batch_id: 230, loss: 5.152398
# pass_id: 0, batch_id: 231, loss: 5.054357
# pass_id: 0, batch_id: 232, loss: 4.984314
# pass_id: 0, batch_id: 233, loss: 5.030034
# pass_id: 0, batch_id: 234, loss: 5.033206
# pass_id: 0, batch_id: 235, loss: 4.897952
# pass_id: 0, batch_id: 236, loss: 4.884457
# pass_id: 0, batch_id: 237, loss: 4.947807
# pass_id: 0, batch_id: 238, loss: 5.115436
# pass_id: 0, batch_id: 239, loss: 5.164942
# pass_id: 0, batch_id: 240, loss: 5.169080
# pass_id: 0, batch_id: 241, loss: 5.031440
# pass_id: 0, batch_id: 242, loss: 4.869956
# pass_id: 0, batch_id: 243, loss: 5.085633
# pass_id: 0, batch_id: 244, loss: 5.061493
# pass_id: 0, batch_id: 245, loss: 5.025691
# pass_id: 0, batch_id: 246, loss: 5.094975
# pass_id: 0, batch_id: 247, loss: 5.021098
# pass_id: 0, batch_id: 248, loss: 4.983112
# pass_id: 0, batch_id: 249, loss: 4.819310
# pass_id: 0, batch_id: 250, loss: 4.983413
# pass_id: 0, batch_id: 251, loss: 4.808753
# pass_id: 0, batch_id: 252, loss: 5.062516
# pass_id: 0, batch_id: 253, loss: 5.004946
# pass_id: 0, batch_id: 254, loss: 4.856855
# pass_id: 0, batch_id: 255, loss: 5.042489
# pass_id: 0, batch_id: 256, loss: 4.855570
# pass_id: 0, batch_id: 257, loss: 4.910435
# pass_id: 0, batch_id: 258, loss: 4.930162
# pass_id: 0, batch_id: 259, loss: 4.754040
# pass_id: 0, batch_id: 260, loss: 4.641896
# pass_id: 0, batch_id: 261, loss: 5.014914
# pass_id: 0, batch_id: 262, loss: 4.912591
# pass_id: 0, batch_id: 263, loss: 4.778179
# pass_id: 0, batch_id: 264, loss: 4.691906
# pass_id: 0, batch_id: 265, loss: 4.783015
# pass_id: 0, batch_id: 266, loss: 4.701013
# pass_id: 0, batch_id: 267, loss: 4.757894
# pass_id: 0, batch_id: 268, loss: 4.715776
# pass_id: 0, batch_id: 269, loss: 4.618839
# pass_id: 0, batch_id: 270, loss: 4.714977
# pass_id: 0, batch_id: 271, loss: 4.626358
# pass_id: 0, batch_id: 272, loss: 4.657157
# pass_id: 0, batch_id: 273, loss: 4.712160
# pass_id: 0, batch_id: 274, loss: 4.859424
# pass_id: 0, batch_id: 275, loss: 4.898884
# pass_id: 0, batch_id: 276, loss: 4.625100
# pass_id: 0, batch_id: 277, loss: 4.725876
# pass_id: 0, batch_id: 278, loss: 4.702351
# pass_id: 0, batch_id: 279, loss: 4.776365
# pass_id: 0, batch_id: 280, loss: 4.701760
# pass_id: 0, batch_id: 281, loss: 4.570657
# pass_id: 0, batch_id: 282, loss: 4.692089
# pass_id: 0, batch_id: 283, loss: 4.613667
# pass_id: 0, batch_id: 284, loss: 4.514768
# pass_id: 0, batch_id: 285, loss: 4.424563
# pass_id: 0, batch_id: 286, loss: 4.622795
# pass_id: 0, batch_id: 287, loss: 4.644610
# pass_id: 0, batch_id: 288, loss: 4.511172
# pass_id: 0, batch_id: 289, loss: 4.705463
# pass_id: 0, batch_id: 290, loss: 4.313247
# pass_id: 0, batch_id: 291, loss: 4.658752
# pass_id: 0, batch_id: 292, loss: 4.683640
# pass_id: 0, batch_id: 293, loss: 4.555507
# pass_id: 0, batch_id: 294, loss: 4.418720
# pass_id: 0, batch_id: 295, loss: 4.684969
# pass_id: 0, batch_id: 296, loss: 4.691001
# pass_id: 0, batch_id: 297, loss: 4.421734
# pass_id: 0, batch_id: 298, loss: 4.361220
# pass_id: 0, batch_id: 299, loss: 4.687808
# pass_id: 0, batch_id: 300, loss: 4.701040
# pass_id: 0, batch_id: 301, loss: 4.714509
# pass_id: 0, batch_id: 302, loss: 4.533857
# pass_id: 0, batch_id: 303, loss: 4.522919
# pass_id: 0, batch_id: 304, loss: 4.241555
# pass_id: 0, batch_id: 305, loss: 4.560237
# pass_id: 0, batch_id: 306, loss: 4.466604
# pass_id: 0, batch_id: 307, loss: 4.363579
# pass_id: 0, batch_id: 308, loss: 4.309441
# pass_id: 0, batch_id: 309, loss: 4.407541
# pass_id: 0, batch_id: 310, loss: 4.509481
# pass_id: 0, batch_id: 311, loss: 4.491484
# pass_id: 0, batch_id: 312, loss: 4.672922
# pass_id: 0, batch_id: 313, loss: 4.857202
# pass_id: 0, batch_id: 314, loss: 4.492556
# pass_id: 0, batch_id: 315, loss: 4.884256
# pass_id: 0, batch_id: 316, loss: 4.803549
# pass_id: 0, batch_id: 317, loss: 4.651818
# pass_id: 0, batch_id: 318, loss: 4.748769
# pass_id: 0, batch_id: 319, loss: 4.615445
# pass_id: 0, batch_id: 320, loss: 4.699535
# pass_id: 0, batch_id: 321, loss: 4.541174
# pass_id: 0, batch_id: 322, loss: 4.666345
# pass_id: 0, batch_id: 323, loss: 4.706595
# pass_id: 0, batch_id: 324, loss: 4.690260
# pass_id: 0, batch_id: 325, loss: 4.873580
# pass_id: 0, batch_id: 326, loss: 4.540364
# pass_id: 0, batch_id: 327, loss: 4.660895
# pass_id: 0, batch_id: 328, loss: 4.687245
# pass_id: 0, batch_id: 329, loss: 4.694607
# pass_id: 0, batch_id: 330, loss: 4.339877
# pass_id: 0, batch_id: 331, loss: 4.739233
# pass_id: 0, batch_id: 332, loss: 4.676155
# pass_id: 0, batch_id: 333, loss: 4.512671
# pass_id: 0, batch_id: 334, loss: 4.599828
# pass_id: 0, batch_id: 335, loss: 4.593978
# pass_id: 0, batch_id: 336, loss: 4.696501
# pass_id: 0, batch_id: 337, loss: 4.560525
# pass_id: 0, batch_id: 338, loss: 4.644865
# pass_id: 0, batch_id: 339, loss: 4.513103
# pass_id: 0, batch_id: 340, loss: 4.763485
# pass_id: 0, batch_id: 341, loss: 4.496577
# pass_id: 0, batch_id: 342, loss: 4.580745
# pass_id: 0, batch_id: 343, loss: 4.505931
# pass_id: 0, batch_id: 344, loss: 4.699474
# pass_id: 0, batch_id: 345, loss: 4.711361
# pass_id: 0, batch_id: 346, loss: 4.521988
# pass_id: 0, batch_id: 347, loss: 4.594864
# pass_id: 0, batch_id: 348, loss: 4.570979
# pass_id: 0, batch_id: 349, loss: 4.381535
# pass_id: 0, batch_id: 350, loss: 4.485883
# pass_id: 0, batch_id: 351, loss: 4.558157
# pass_id: 0, batch_id: 352, loss: 4.510356
# pass_id: 0, batch_id: 353, loss: 4.430479
# pass_id: 0, batch_id: 354, loss: 4.639428
# pass_id: 0, batch_id: 355, loss: 4.628474
# pass_id: 0, batch_id: 356, loss: 4.444060
# pass_id: 0, batch_id: 357, loss: 4.527195
# pass_id: 0, batch_id: 358, loss: 4.159727
# pass_id: 0, batch_id: 359, loss: 4.776938
# pass_id: 0, batch_id: 360, loss: 4.441454
# pass_id: 0, batch_id: 361, loss: 4.617405
# pass_id: 0, batch_id: 362, loss: 4.276990
# pass_id: 0, batch_id: 363, loss: 4.318286
# pass_id: 0, batch_id: 364, loss: 4.451139
# pass_id: 0, batch_id: 365, loss: 4.589140
# pass_id: 0, batch_id: 366, loss: 4.568991
# pass_id: 0, batch_id: 367, loss: 4.444923
# pass_id: 0, batch_id: 368, loss: 4.357804
# pass_id: 0, batch_id: 369, loss: 4.611251
# pass_id: 0, batch_id: 370, loss: 4.521060
# pass_id: 0, batch_id: 371, loss: 4.415516
# pass_id: 0, batch_id: 372, loss: 4.673971
# pass_id: 0, batch_id: 373, loss: 4.525331
# pass_id: 0, batch_id: 374, loss: 4.560359
# pass_id: 0, batch_id: 375, loss: 4.354182
# pass_id: 0, batch_id: 376, loss: 4.449265
# pass_id: 0, batch_id: 377, loss: 4.392197
# pass_id: 0, batch_id: 378, loss: 4.251495
# pass_id: 0, batch_id: 379, loss: 4.404630
# pass_id: 0, batch_id: 380, loss: 4.301610
# pass_id: 0, batch_id: 381, loss: 4.435324
# pass_id: 0, batch_id: 382, loss: 4.472181
# pass_id: 0, batch_id: 383, loss: 4.566777
# pass_id: 0, batch_id: 384, loss: 4.624972
# pass_id: 0, batch_id: 385, loss: 4.272658
# pass_id: 0, batch_id: 386, loss: 4.313584
# pass_id: 0, batch_id: 387, loss: 4.318722
# pass_id: 0, batch_id: 388, loss: 4.499672
# pass_id: 0, batch_id: 389, loss: 4.367975
# pass_id: 0, batch_id: 390, loss: 4.484199
# pass_id: 0, batch_id: 391, loss: 4.304480
# pass_id: 0, batch_id: 392, loss: 4.174312
# pass_id: 0, batch_id: 393, loss: 4.369161
# pass_id: 0, batch_id: 394, loss: 4.561588
# pass_id: 0, batch_id: 395, loss: 4.288021
# pass_id: 0, batch_id: 396, loss: 4.430681
# pass_id: 0, batch_id: 397, loss: 4.272377
# pass_id: 0, batch_id: 398, loss: 4.251220
# pass_id: 0, batch_id: 399, loss: 4.333295
# pass_id: 0, batch_id: 400, loss: 4.225224
# pass_id: 0, batch_id: 401, loss: 4.461141
# pass_id: 0, batch_id: 402, loss: 4.414415
# pass_id: 0, batch_id: 403, loss: 4.256808
# pass_id: 0, batch_id: 404, loss: 4.023746
# pass_id: 0, batch_id: 405, loss: 4.230636
# pass_id: 0, batch_id: 406, loss: 4.364407
# pass_id: 0, batch_id: 407, loss: 4.420164
# pass_id: 0, batch_id: 408, loss: 4.202783
# pass_id: 0, batch_id: 409, loss: 4.363063
# pass_id: 0, batch_id: 410, loss: 4.286310
# pass_id: 0, batch_id: 411, loss: 4.081124
# pass_id: 0, batch_id: 412, loss: 4.443497
# pass_id: 0, batch_id: 413, loss: 4.168543
# pass_id: 0, batch_id: 414, loss: 4.292085
# pass_id: 0, batch_id: 415, loss: 4.094208
# pass_id: 0, batch_id: 416, loss: 4.395391
# pass_id: 0, batch_id: 417, loss: 4.329077
# pass_id: 0, batch_id: 418, loss: 4.317297
# pass_id: 0, batch_id: 419, loss: 4.300472
# pass_id: 0, batch_id: 420, loss: 4.363942
# pass_id: 0, batch_id: 421, loss: 4.193428
# pass_id: 0, batch_id: 422, loss: 4.157035
# pass_id: 0, batch_id: 423, loss: 4.419559
# pass_id: 0, batch_id: 424, loss: 4.144846
# pass_id: 0, batch_id: 425, loss: 4.364092
# pass_id: 0, batch_id: 426, loss: 4.103915
# pass_id: 0, batch_id: 427, loss: 4.283925
# pass_id: 0, batch_id: 428, loss: 4.253278
# pass_id: 0, batch_id: 429, loss: 4.151719
# pass_id: 0, batch_id: 430, loss: 4.271956
# pass_id: 0, batch_id: 431, loss: 4.209316
# pass_id: 0, batch_id: 432, loss: 4.165129
# pass_id: 0, batch_id: 433, loss: 4.168839
# pass_id: 0, batch_id: 434, loss: 4.161236
# pass_id: 0, batch_id: 435, loss: 4.363915
# pass_id: 0, batch_id: 436, loss: 4.293426
# pass_id: 0, batch_id: 437, loss: 4.166795
# pass_id: 0, batch_id: 438, loss: 4.250154
# pass_id: 0, batch_id: 439, loss: 4.322641
# pass_id: 0, batch_id: 440, loss: 4.142207
# pass_id: 0, batch_id: 441, loss: 4.297994
# pass_id: 0, batch_id: 442, loss: 4.308295
# pass_id: 0, batch_id: 443, loss: 4.177019
# pass_id: 0, batch_id: 444, loss: 4.423447
# pass_id: 0, batch_id: 445, loss: 4.109055
# pass_id: 0, batch_id: 446, loss: 4.046958
# pass_id: 0, batch_id: 447, loss: 4.214202
# pass_id: 0, batch_id: 448, loss: 3.948032
# pass_id: 0, batch_id: 449, loss: 4.313721
# pass_id: 0, batch_id: 450, loss: 4.424515
# pass_id: 0, batch_id: 451, loss: 4.222580
# pass_id: 0, batch_id: 452, loss: 4.256216
# pass_id: 0, batch_id: 453, loss: 3.997056
# pass_id: 1, batch_id: 0, loss: 4.084713
# pass_id: 1, batch_id: 1, loss: 4.247953
# pass_id: 1, batch_id: 2, loss: 4.211404
# pass_id: 1, batch_id: 3, loss: 4.135811
# pass_id: 1, batch_id: 4, loss: 3.946007
# pass_id: 1, batch_id: 5, loss: 4.266450
# pass_id: 1, batch_id: 6, loss: 3.940284
# pass_id: 1, batch_id: 7, loss: 4.366963
# pass_id: 1, batch_id: 8, loss: 4.182318
# pass_id: 1, batch_id: 9, loss: 4.057315
# pass_id: 1, batch_id: 10, loss: 3.978214
# pass_id: 1, batch_id: 11, loss: 3.919132
# pass_id: 1, batch_id: 12, loss: 4.185559
# pass_id: 1, batch_id: 13, loss: 4.080951
# pass_id: 1, batch_id: 14, loss: 3.991248
# pass_id: 1, batch_id: 15, loss: 3.888970
# pass_id: 1, batch_id: 16, loss: 4.034610
# pass_id: 1, batch_id: 17, loss: 4.089529
# pass_id: 1, batch_id: 18, loss: 4.182164
# pass_id: 1, batch_id: 19, loss: 4.056061
# pass_id: 1, batch_id: 20, loss: 3.909290
# pass_id: 1, batch_id: 21, loss: 3.972624
# pass_id: 1, batch_id: 22, loss: 3.840405
# pass_id: 1, batch_id: 23, loss: 4.108736
# pass_id: 1, batch_id: 24, loss: 4.038531
# pass_id: 1, batch_id: 25, loss: 3.979599
# pass_id: 1, batch_id: 26, loss: 3.873426
# pass_id: 1, batch_id: 27, loss: 3.715023
# pass_id: 1, batch_id: 28, loss: 3.725674
# pass_id: 1, batch_id: 29, loss: 4.102206
# pass_id: 1, batch_id: 30, loss: 3.962479
# pass_id: 1, batch_id: 31, loss: 4.079162
# pass_id: 1, batch_id: 32, loss: 3.862473
# pass_id: 1, batch_id: 33, loss: 3.966232
# pass_id: 1, batch_id: 34, loss: 3.911928
# pass_id: 1, batch_id: 35, loss: 3.979688
# pass_id: 1, batch_id: 36, loss: 3.943411
# pass_id: 1, batch_id: 37, loss: 4.080096
# pass_id: 1, batch_id: 38, loss: 4.229827
# pass_id: 1, batch_id: 39, loss: 4.024025
# pass_id: 1, batch_id: 40, loss: 3.830012
# pass_id: 1, batch_id: 41, loss: 3.961657
# pass_id: 1, batch_id: 42, loss: 3.973256
# pass_id: 1, batch_id: 43, loss: 3.774103
# pass_id: 1, batch_id: 44, loss: 4.055497
# pass_id: 1, batch_id: 45, loss: 3.844903
# pass_id: 1, batch_id: 46, loss: 3.873907
# pass_id: 1, batch_id: 47, loss: 3.844627
# pass_id: 1, batch_id: 48, loss: 3.971822
# pass_id: 1, batch_id: 49, loss: 3.667139
# pass_id: 1, batch_id: 50, loss: 3.952704
# pass_id: 1, batch_id: 51, loss: 4.031412
# pass_id: 1, batch_id: 52, loss: 4.019041
# pass_id: 1, batch_id: 53, loss: 3.683876
# pass_id: 1, batch_id: 54, loss: 4.028131
# pass_id: 1, batch_id: 55, loss: 3.656988
# pass_id: 1, batch_id: 56, loss: 4.145926
# pass_id: 1, batch_id: 57, loss: 3.799685
# pass_id: 1, batch_id: 58, loss: 3.898146
# pass_id: 1, batch_id: 59, loss: 3.946385
# pass_id: 1, batch_id: 60, loss: 3.978706
# pass_id: 1, batch_id: 61, loss: 3.730010
# pass_id: 1, batch_id: 62, loss: 3.826336
# pass_id: 1, batch_id: 63, loss: 3.685535
# pass_id: 1, batch_id: 64, loss: 3.924907
# pass_id: 1, batch_id: 65, loss: 3.857821
# pass_id: 1, batch_id: 66, loss: 3.992092
# pass_id: 1, batch_id: 67, loss: 3.943791
# pass_id: 1, batch_id: 68, loss: 3.766580
# pass_id: 1, batch_id: 69, loss: 4.161312
# pass_id: 1, batch_id: 70, loss: 3.749837
# pass_id: 1, batch_id: 71, loss: 4.106913
# pass_id: 1, batch_id: 72, loss: 4.041341
# pass_id: 1, batch_id: 73, loss: 3.790348
# pass_id: 1, batch_id: 74, loss: 4.127838
# pass_id: 1, batch_id: 75, loss: 3.943025
# pass_id: 1, batch_id: 76, loss: 3.669295
# pass_id: 1, batch_id: 77, loss: 3.902853
# pass_id: 1, batch_id: 78, loss: 3.861243
# pass_id: 1, batch_id: 79, loss: 3.706081
# pass_id: 1, batch_id: 80, loss: 3.941839
# pass_id: 1, batch_id: 81, loss: 3.801741
# pass_id: 1, batch_id: 82, loss: 3.888968
# pass_id: 1, batch_id: 83, loss: 3.783144
# pass_id: 1, batch_id: 84, loss: 3.896257
# pass_id: 1, batch_id: 85, loss: 3.975030
# pass_id: 1, batch_id: 86, loss: 3.586988
# pass_id: 1, batch_id: 87, loss: 3.808358
# pass_id: 1, batch_id: 88, loss: 3.908495
# pass_id: 1, batch_id: 89, loss: 4.217571
# pass_id: 1, batch_id: 90, loss: 3.814520
# pass_id: 1, batch_id: 91, loss: 3.836084
# pass_id: 1, batch_id: 92, loss: 3.933982
# pass_id: 1, batch_id: 93, loss: 3.771023
# pass_id: 1, batch_id: 94, loss: 3.830049
# pass_id: 1, batch_id: 95, loss: 3.755168
# pass_id: 1, batch_id: 96, loss: 3.736933
# pass_id: 1, batch_id: 97, loss: 3.793360
# pass_id: 1, batch_id: 98, loss: 3.761785
# pass_id: 1, batch_id: 99, loss: 3.607018
# pass_id: 1, batch_id: 100, loss: 3.860637
# pass_id: 1, batch_id: 101, loss: 3.652407
# pass_id: 1, batch_id: 102, loss: 3.904769
# pass_id: 1, batch_id: 103, loss: 3.641126
# pass_id: 1, batch_id: 104, loss: 3.662966
# pass_id: 1, batch_id: 105, loss: 3.933328
# pass_id: 1, batch_id: 106, loss: 3.879611
# pass_id: 1, batch_id: 107, loss: 3.847656
# pass_id: 1, batch_id: 108, loss: 3.987865
# pass_id: 1, batch_id: 109, loss: 3.726105
# pass_id: 1, batch_id: 110, loss: 4.049165
# pass_id: 1, batch_id: 111, loss: 3.837938
# pass_id: 1, batch_id: 112, loss: 3.758629
# pass_id: 1, batch_id: 113, loss: 3.959320
# pass_id: 1, batch_id: 114, loss: 3.756692
# pass_id: 1, batch_id: 115, loss: 3.740196
# pass_id: 1, batch_id: 116, loss: 3.983955
# pass_id: 1, batch_id: 117, loss: 3.765320
# pass_id: 1, batch_id: 118, loss: 3.875098
# pass_id: 1, batch_id: 119, loss: 3.658259
# pass_id: 1, batch_id: 120, loss: 3.546771
# pass_id: 1, batch_id: 121, loss: 3.857419
# pass_id: 1, batch_id: 122, loss: 3.799680
# pass_id: 1, batch_id: 123, loss: 3.680670
# pass_id: 1, batch_id: 124, loss: 3.660549
# pass_id: 1, batch_id: 125, loss: 3.765732
# pass_id: 1, batch_id: 126, loss: 3.566272
# pass_id: 1, batch_id: 127, loss: 3.660165
# pass_id: 1, batch_id: 128, loss: 3.818201
# pass_id: 1, batch_id: 129, loss: 3.429387
# pass_id: 1, batch_id: 130, loss: 3.785361
# pass_id: 1, batch_id: 131, loss: 3.996162
# pass_id: 1, batch_id: 132, loss: 3.730380
# pass_id: 1, batch_id: 133, loss: 3.602055
# pass_id: 1, batch_id: 134, loss: 3.813323
# pass_id: 1, batch_id: 135, loss: 3.906723
# pass_id: 1, batch_id: 136, loss: 3.844027
# pass_id: 1, batch_id: 137, loss: 3.874297
# pass_id: 1, batch_id: 138, loss: 3.868174
# pass_id: 1, batch_id: 139, loss: 3.725425
# pass_id: 1, batch_id: 140, loss: 3.474428
# pass_id: 1, batch_id: 141, loss: 3.632301
# pass_id: 1, batch_id: 142, loss: 3.651026
# pass_id: 1, batch_id: 143, loss: 3.604500
# pass_id: 1, batch_id: 144, loss: 3.656221
# pass_id: 1, batch_id: 145, loss: 3.619231
# pass_id: 1, batch_id: 146, loss: 3.663420
# pass_id: 1, batch_id: 147, loss: 3.741347
# pass_id: 1, batch_id: 148, loss: 3.990384
# pass_id: 1, batch_id: 149, loss: 4.100525
# pass_id: 1, batch_id: 150, loss: 3.851447
# pass_id: 1, batch_id: 151, loss: 3.864885
# pass_id: 1, batch_id: 152, loss: 3.595194
# pass_id: 1, batch_id: 153, loss: 3.723155
# pass_id: 1, batch_id: 154, loss: 3.817980
# pass_id: 1, batch_id: 155, loss: 3.807497
# pass_id: 1, batch_id: 156, loss: 3.943866
# pass_id: 1, batch_id: 157, loss: 4.011836
# pass_id: 1, batch_id: 158, loss: 3.939835
# pass_id: 1, batch_id: 159, loss: 3.788409
# pass_id: 1, batch_id: 160, loss: 3.895811
# pass_id: 1, batch_id: 161, loss: 3.748291
# pass_id: 1, batch_id: 162, loss: 3.705773
# pass_id: 1, batch_id: 163, loss: 3.871826
# pass_id: 1, batch_id: 164, loss: 3.530017
# pass_id: 1, batch_id: 165, loss: 3.802309
# pass_id: 1, batch_id: 166, loss: 3.511306
# pass_id: 1, batch_id: 167, loss: 3.879784
# pass_id: 1, batch_id: 168, loss: 3.788116
# pass_id: 1, batch_id: 169, loss: 3.647645
# pass_id: 1, batch_id: 170, loss: 3.510226
# pass_id: 1, batch_id: 171, loss: 3.474000
# pass_id: 1, batch_id: 172, loss: 3.643688
# pass_id: 1, batch_id: 173, loss: 3.547067
# pass_id: 1, batch_id: 174, loss: 3.540621
# pass_id: 1, batch_id: 175, loss: 3.824472
# pass_id: 1, batch_id: 176, loss: 3.482773
# pass_id: 1, batch_id: 177, loss: 3.705708
# pass_id: 1, batch_id: 178, loss: 3.944937
# pass_id: 1, batch_id: 179, loss: 3.584347
# pass_id: 1, batch_id: 180, loss: 3.690002
# pass_id: 1, batch_id: 181, loss: 3.556320
# pass_id: 1, batch_id: 182, loss: 3.944247
# pass_id: 1, batch_id: 183, loss: 3.710340
# pass_id: 1, batch_id: 184, loss: 3.760743
# pass_id: 1, batch_id: 185, loss: 3.687024
# pass_id: 1, batch_id: 186, loss: 3.612123
# pass_id: 1, batch_id: 187, loss: 3.516908
# pass_id: 1, batch_id: 188, loss: 3.529773
# pass_id: 1, batch_id: 189, loss: 3.760913
# pass_id: 1, batch_id: 190, loss: 3.712437
# pass_id: 1, batch_id: 191, loss: 3.667912
# pass_id: 1, batch_id: 192, loss: 3.572444
# pass_id: 1, batch_id: 193, loss: 3.531649
# pass_id: 1, batch_id: 194, loss: 3.749635
# pass_id: 1, batch_id: 195, loss: 3.700807
# pass_id: 1, batch_id: 196, loss: 3.727963
# pass_id: 1, batch_id: 197, loss: 3.532172
# pass_id: 1, batch_id: 198, loss: 3.441871
# pass_id: 1, batch_id: 199, loss: 3.515136
# pass_id: 1, batch_id: 200, loss: 3.448417
# pass_id: 1, batch_id: 201, loss: 3.670458
# pass_id: 1, batch_id: 202, loss: 3.582721
# pass_id: 1, batch_id: 203, loss: 3.866405
# pass_id: 1, batch_id: 204, loss: 3.979319
# pass_id: 1, batch_id: 205, loss: 3.427201
# pass_id: 1, batch_id: 206, loss: 3.659221
# pass_id: 1, batch_id: 207, loss: 3.442713
# pass_id: 1, batch_id: 208, loss: 3.626608
# pass_id: 1, batch_id: 209, loss: 3.630127
# pass_id: 1, batch_id: 210, loss: 3.802534
# pass_id: 1, batch_id: 211, loss: 3.779517
# pass_id: 1, batch_id: 212, loss: 3.828894
# pass_id: 1, batch_id: 213, loss: 3.649344
# pass_id: 1, batch_id: 214, loss: 3.820235
# pass_id: 1, batch_id: 215, loss: 3.810724
# pass_id: 1, batch_id: 216, loss: 3.535806
# pass_id: 1, batch_id: 217, loss: 3.695391
# pass_id: 1, batch_id: 218, loss: 3.405701
# pass_id: 1, batch_id: 219, loss: 3.657023
# pass_id: 1, batch_id: 220, loss: 3.618433
# pass_id: 1, batch_id: 221, loss: 3.568602
# pass_id: 1, batch_id: 222, loss: 3.696801
# pass_id: 1, batch_id: 223, loss: 3.489869
# pass_id: 1, batch_id: 224, loss: 3.455435
# pass_id: 1, batch_id: 225, loss: 3.648445
# pass_id: 1, batch_id: 226, loss: 3.451482
# pass_id: 1, batch_id: 227, loss: 3.450953
# pass_id: 1, batch_id: 228, loss: 3.711449
# pass_id: 1, batch_id: 229, loss: 3.493078
# pass_id: 1, batch_id: 230, loss: 3.674343
# pass_id: 1, batch_id: 231, loss: 3.504287
# pass_id: 1, batch_id: 232, loss: 3.539299
# pass_id: 1, batch_id: 233, loss: 3.706771
# pass_id: 1, batch_id: 234, loss: 3.573186
# pass_id: 1, batch_id: 235, loss: 3.571326
# pass_id: 1, batch_id: 236, loss: 3.757329
# pass_id: 1, batch_id: 237, loss: 3.718438
# pass_id: 1, batch_id: 238, loss: 3.484510
# pass_id: 1, batch_id: 239, loss: 3.654843
# pass_id: 1, batch_id: 240, loss: 3.460146
# pass_id: 1, batch_id: 241, loss: 3.549843
# pass_id: 1, batch_id: 242, loss: 3.624614
# pass_id: 1, batch_id: 243, loss: 3.742997
# pass_id: 1, batch_id: 244, loss: 3.326490
# pass_id: 1, batch_id: 245, loss: 3.682914
# pass_id: 1, batch_id: 246, loss: 3.658858
# pass_id: 1, batch_id: 247, loss: 3.595840
# pass_id: 1, batch_id: 248, loss: 3.540150
# pass_id: 1, batch_id: 249, loss: 3.622159
# pass_id: 1, batch_id: 250, loss: 3.527912
# pass_id: 1, batch_id: 251, loss: 3.535654
# pass_id: 1, batch_id: 252, loss: 3.377705
# pass_id: 1, batch_id: 253, loss: 3.653042
# pass_id: 1, batch_id: 254, loss: 3.563957
# pass_id: 1, batch_id: 255, loss: 3.474037
# pass_id: 1, batch_id: 256, loss: 3.264121
# pass_id: 1, batch_id: 257, loss: 3.823610
# pass_id: 1, batch_id: 258, loss: 3.611580
# pass_id: 1, batch_id: 259, loss: 3.502952
# pass_id: 1, batch_id: 260, loss: 3.859932
# pass_id: 1, batch_id: 261, loss: 3.591194
# pass_id: 1, batch_id: 262, loss: 3.678270
# pass_id: 1, batch_id: 263, loss: 3.433106
# pass_id: 1, batch_id: 264, loss: 3.429210
# pass_id: 1, batch_id: 265, loss: 3.548957
# pass_id: 1, batch_id: 266, loss: 3.488125
# pass_id: 1, batch_id: 267, loss: 3.652003
# pass_id: 1, batch_id: 268, loss: 3.635517
# pass_id: 1, batch_id: 269, loss: 3.457557
# pass_id: 1, batch_id: 270, loss: 3.708389
# pass_id: 1, batch_id: 271, loss: 3.333121
# pass_id: 1, batch_id: 272, loss: 3.302430
# pass_id: 1, batch_id: 273, loss: 3.739659
# pass_id: 1, batch_id: 274, loss: 3.743898
# pass_id: 1, batch_id: 275, loss: 3.655029
# pass_id: 1, batch_id: 276, loss: 3.496807
# pass_id: 1, batch_id: 277, loss: 3.516611
# pass_id: 1, batch_id: 278, loss: 3.437663
# pass_id: 1, batch_id: 279, loss: 3.512250
# pass_id: 1, batch_id: 280, loss: 3.593524
# pass_id: 1, batch_id: 281, loss: 3.578158
# pass_id: 1, batch_id: 282, loss: 3.686469
# pass_id: 1, batch_id: 283, loss: 3.422049
# pass_id: 1, batch_id: 284, loss: 3.278892
# pass_id: 1, batch_id: 285, loss: 3.614770
# pass_id: 1, batch_id: 286, loss: 3.569341
# pass_id: 1, batch_id: 287, loss: 3.593407
# pass_id: 1, batch_id: 288, loss: 3.595962
# pass_id: 1, batch_id: 289, loss: 3.289838
# pass_id: 1, batch_id: 290, loss: 3.439705
# pass_id: 1, batch_id: 291, loss: 3.626652
# pass_id: 1, batch_id: 292, loss: 3.738742
# pass_id: 1, batch_id: 293, loss: 3.278991
# pass_id: 1, batch_id: 294, loss: 3.545004
# pass_id: 1, batch_id: 295, loss: 3.501750
# pass_id: 1, batch_id: 296, loss: 3.612631
# pass_id: 1, batch_id: 297, loss: 3.475435
# pass_id: 1, batch_id: 298, loss: 3.326825
# pass_id: 1, batch_id: 299, loss: 3.403189
# pass_id: 1, batch_id: 300, loss: 3.543122
# pass_id: 1, batch_id: 301, loss: 3.577668
# pass_id: 1, batch_id: 302, loss: 3.636727
# pass_id: 1, batch_id: 303, loss: 3.119190
# pass_id: 1, batch_id: 304, loss: 3.677004
# pass_id: 1, batch_id: 305, loss: 3.555159
# pass_id: 1, batch_id: 306, loss: 3.489057
# pass_id: 1, batch_id: 307, loss: 3.441513
# pass_id: 1, batch_id: 308, loss: 3.311938
# pass_id: 1, batch_id: 309, loss: 3.677933
# pass_id: 1, batch_id: 310, loss: 3.502698
# pass_id: 1, batch_id: 311, loss: 3.387781
# pass_id: 1, batch_id: 312, loss: 3.525952
# pass_id: 1, batch_id: 313, loss: 3.669055
# pass_id: 1, batch_id: 314, loss: 3.610943
# pass_id: 1, batch_id: 315, loss: 3.997391
# pass_id: 1, batch_id: 316, loss: 3.964119
# pass_id: 1, batch_id: 317, loss: 3.869420
# pass_id: 1, batch_id: 318, loss: 3.736203
# pass_id: 1, batch_id: 319, loss: 3.928215
# pass_id: 1, batch_id: 320, loss: 3.810312
# pass_id: 1, batch_id: 321, loss: 3.781541
# pass_id: 1, batch_id: 322, loss: 3.742435
# pass_id: 1, batch_id: 323, loss: 3.805665
# pass_id: 1, batch_id: 324, loss: 3.764197
# pass_id: 1, batch_id: 325, loss: 3.830069
# pass_id: 1, batch_id: 326, loss: 3.784474
# pass_id: 1, batch_id: 327, loss: 3.824764
# pass_id: 1, batch_id: 328, loss: 3.791001
# pass_id: 1, batch_id: 329, loss: 3.721003
# pass_id: 1, batch_id: 330, loss: 3.572856
# pass_id: 1, batch_id: 331, loss: 3.889035
# pass_id: 1, batch_id: 332, loss: 3.533855
# pass_id: 1, batch_id: 333, loss: 3.648818
# pass_id: 1, batch_id: 334, loss: 3.542557
# pass_id: 1, batch_id: 335, loss: 3.633839
# pass_id: 1, batch_id: 336, loss: 3.223696
# pass_id: 1, batch_id: 337, loss: 3.438693
# pass_id: 1, batch_id: 338, loss: 3.787768
# pass_id: 1, batch_id: 339, loss: 3.691517
# pass_id: 1, batch_id: 340, loss: 3.716362
# pass_id: 1, batch_id: 341, loss: 3.813786
# pass_id: 1, batch_id: 342, loss: 3.829309
# pass_id: 1, batch_id: 343, loss: 3.750502
# pass_id: 1, batch_id: 344, loss: 3.661417
# pass_id: 1, batch_id: 345, loss: 3.620291
# pass_id: 1, batch_id: 346, loss: 3.905934
# pass_id: 1, batch_id: 347, loss: 3.790837
# pass_id: 1, batch_id: 348, loss: 3.864309
# pass_id: 1, batch_id: 349, loss: 3.602333
# pass_id: 1, batch_id: 350, loss: 3.798422
# pass_id: 1, batch_id: 351, loss: 3.739948
# pass_id: 1, batch_id: 352, loss: 3.495068
# pass_id: 1, batch_id: 353, loss: 3.655001
# pass_id: 1, batch_id: 354, loss: 4.033210
# pass_id: 1, batch_id: 355, loss: 3.721221
# pass_id: 1, batch_id: 356, loss: 3.490952
# pass_id: 1, batch_id: 357, loss: 3.887884
# pass_id: 1, batch_id: 358, loss: 3.525706
# pass_id: 1, batch_id: 359, loss: 3.649850
# pass_id: 1, batch_id: 360, loss: 3.531448
# pass_id: 1, batch_id: 361, loss: 3.515779
# pass_id: 1, batch_id: 362, loss: 3.553120
# pass_id: 1, batch_id: 363, loss: 3.652824
# pass_id: 1, batch_id: 364, loss: 3.576910
# pass_id: 1, batch_id: 365, loss: 3.700696
# pass_id: 1, batch_id: 366, loss: 3.561820
# pass_id: 1, batch_id: 367, loss: 3.647947
# pass_id: 1, batch_id: 368, loss: 3.775694
# pass_id: 1, batch_id: 369, loss: 3.529644
# pass_id: 1, batch_id: 370, loss: 3.512290
# pass_id: 1, batch_id: 371, loss: 3.803511
# pass_id: 1, batch_id: 372, loss: 3.618682
# pass_id: 1, batch_id: 373, loss: 3.449517
# pass_id: 1, batch_id: 374, loss: 3.544476
# pass_id: 1, batch_id: 375, loss: 3.664097
# pass_id: 1, batch_id: 376, loss: 3.688024
# pass_id: 1, batch_id: 377, loss: 3.809180
# pass_id: 1, batch_id: 378, loss: 3.555874
# pass_id: 1, batch_id: 379, loss: 3.720274
# pass_id: 1, batch_id: 380, loss: 3.676694
# pass_id: 1, batch_id: 381, loss: 3.516922
# pass_id: 1, batch_id: 382, loss: 3.618826
# pass_id: 1, batch_id: 383, loss: 3.723733
# pass_id: 1, batch_id: 384, loss: 3.683467
# pass_id: 1, batch_id: 385, loss: 3.621504
# pass_id: 1, batch_id: 386, loss: 3.542124
# pass_id: 1, batch_id: 387, loss: 3.646997
# pass_id: 1, batch_id: 388, loss: 3.510794
# pass_id: 1, batch_id: 389, loss: 3.636590
# pass_id: 1, batch_id: 390, loss: 3.651717
# pass_id: 1, batch_id: 391, loss: 3.940679
# pass_id: 1, batch_id: 392, loss: 3.728152
# pass_id: 1, batch_id: 393, loss: 3.678622
# pass_id: 1, batch_id: 394, loss: 3.560554
# pass_id: 1, batch_id: 395, loss: 3.599767
# pass_id: 1, batch_id: 396, loss: 3.570784
# pass_id: 1, batch_id: 397, loss: 3.627470
# pass_id: 1, batch_id: 398, loss: 3.622684
# pass_id: 1, batch_id: 399, loss: 3.496597
# pass_id: 1, batch_id: 400, loss: 3.694001
# pass_id: 1, batch_id: 401, loss: 3.204829
# pass_id: 1, batch_id: 402, loss: 3.566527
# pass_id: 1, batch_id: 403, loss: 3.815877
# pass_id: 1, batch_id: 404, loss: 3.846692
# pass_id: 1, batch_id: 405, loss: 3.750376
# pass_id: 1, batch_id: 406, loss: 3.557849
# pass_id: 1, batch_id: 407, loss: 3.294275
# pass_id: 1, batch_id: 408, loss: 3.439940
# pass_id: 1, batch_id: 409, loss: 3.720072
# pass_id: 1, batch_id: 410, loss: 3.651988
# pass_id: 1, batch_id: 411, loss: 3.695440
# pass_id: 1, batch_id: 412, loss: 3.628936
# pass_id: 1, batch_id: 413, loss: 3.774634
# pass_id: 1, batch_id: 414, loss: 3.658257
# pass_id: 1, batch_id: 415, loss: 3.493302
# pass_id: 1, batch_id: 416, loss: 3.702401
# pass_id: 1, batch_id: 417, loss: 3.546119
# pass_id: 1, batch_id: 418, loss: 3.594379
# pass_id: 1, batch_id: 419, loss: 3.492488
# pass_id: 1, batch_id: 420, loss: 3.453444
# pass_id: 1, batch_id: 421, loss: 3.588048
# pass_id: 1, batch_id: 422, loss: 3.557234
# pass_id: 1, batch_id: 423, loss: 3.881019
# pass_id: 1, batch_id: 424, loss: 3.461476
# pass_id: 1, batch_id: 425, loss: 3.458951
# pass_id: 1, batch_id: 426, loss: 3.555248
# pass_id: 1, batch_id: 427, loss: 3.556354
# pass_id: 1, batch_id: 428, loss: 3.596415
# pass_id: 1, batch_id: 429, loss: 3.478318
# pass_id: 1, batch_id: 430, loss: 3.706089
# pass_id: 1, batch_id: 431, loss: 3.814560
# pass_id: 1, batch_id: 432, loss: 3.592890
# pass_id: 1, batch_id: 433, loss: 3.696274
# pass_id: 1, batch_id: 434, loss: 3.408932
# pass_id: 1, batch_id: 435, loss: 3.487797
# pass_id: 1, batch_id: 436, loss: 3.616107
# pass_id: 1, batch_id: 437, loss: 3.476746
# pass_id: 1, batch_id: 438, loss: 3.496823
# pass_id: 1, batch_id: 439, loss: 3.677699
# pass_id: 1, batch_id: 440, loss: 3.689001
# pass_id: 1, batch_id: 441, loss: 3.854760
# pass_id: 1, batch_id: 442, loss: 3.726341
# pass_id: 1, batch_id: 443, loss: 3.459960
# pass_id: 1, batch_id: 444, loss: 3.567039
# pass_id: 1, batch_id: 445, loss: 3.572671
# pass_id: 1, batch_id: 446, loss: 3.429540
# pass_id: 1, batch_id: 447, loss: 3.646860
# pass_id: 1, batch_id: 448, loss: 3.308935
# pass_id: 1, batch_id: 449, loss: 3.537839
# pass_id: 1, batch_id: 450, loss: 3.462516
# pass_id: 1, batch_id: 451, loss: 3.513224
# pass_id: 1, batch_id: 452, loss: 3.742109
# pass_id: 1, batch_id: 453, loss: 3.746813
# pass_id: 2, batch_id: 0, loss: 3.388593
# pass_id: 2, batch_id: 1, loss: 3.492400
# pass_id: 2, batch_id: 2, loss: 3.639957
# pass_id: 2, batch_id: 3, loss: 3.725703
# pass_id: 2, batch_id: 4, loss: 3.461924
# pass_id: 2, batch_id: 5, loss: 3.706562
# pass_id: 2, batch_id: 6, loss: 3.446841
# pass_id: 2, batch_id: 7, loss: 3.615747
# pass_id: 2, batch_id: 8, loss: 3.660710
# pass_id: 2, batch_id: 9, loss: 3.626328
# pass_id: 2, batch_id: 10, loss: 3.369035
# pass_id: 2, batch_id: 11, loss: 3.662956
# pass_id: 2, batch_id: 12, loss: 3.406786
# pass_id: 2, batch_id: 13, loss: 3.471199
# pass_id: 2, batch_id: 14, loss: 3.328049
# pass_id: 2, batch_id: 15, loss: 3.245660
# pass_id: 2, batch_id: 16, loss: 3.542459
# pass_id: 2, batch_id: 17, loss: 3.429864
# pass_id: 2, batch_id: 18, loss: 3.319029
# pass_id: 2, batch_id: 19, loss: 3.580652
# pass_id: 2, batch_id: 20, loss: 3.104532
# pass_id: 2, batch_id: 21, loss: 3.283720
# pass_id: 2, batch_id: 22, loss: 3.374316
# pass_id: 2, batch_id: 23, loss: 3.283892
# pass_id: 2, batch_id: 24, loss: 3.447712
# pass_id: 2, batch_id: 25, loss: 3.427072
# pass_id: 2, batch_id: 26, loss: 3.336103
# pass_id: 2, batch_id: 27, loss: 3.449970
# pass_id: 2, batch_id: 28, loss: 3.455209
# pass_id: 2, batch_id: 29, loss: 3.265148
# pass_id: 2, batch_id: 30, loss: 3.261547
# pass_id: 2, batch_id: 31, loss: 3.528655
# pass_id: 2, batch_id: 32, loss: 3.366433
# pass_id: 2, batch_id: 33, loss: 3.444970
# pass_id: 2, batch_id: 34, loss: 3.487284
# pass_id: 2, batch_id: 35, loss: 3.376830
# pass_id: 2, batch_id: 36, loss: 3.420112
# pass_id: 2, batch_id: 37, loss: 3.232019
# pass_id: 2, batch_id: 38, loss: 3.362234
# pass_id: 2, batch_id: 39, loss: 3.492567
# pass_id: 2, batch_id: 40, loss: 3.666654
# pass_id: 2, batch_id: 41, loss: 3.061378
# pass_id: 2, batch_id: 42, loss: 3.145564
# pass_id: 2, batch_id: 43, loss: 3.357012
# pass_id: 2, batch_id: 44, loss: 3.360061
# pass_id: 2, batch_id: 45, loss: 3.173395
# pass_id: 2, batch_id: 46, loss: 3.247525
# pass_id: 2, batch_id: 47, loss: 3.356263
# pass_id: 2, batch_id: 48, loss: 3.432523
# pass_id: 2, batch_id: 49, loss: 3.491558
# pass_id: 2, batch_id: 50, loss: 3.595441
# pass_id: 2, batch_id: 51, loss: 3.100750
# pass_id: 2, batch_id: 52, loss: 3.499222
# pass_id: 2, batch_id: 53, loss: 3.233608
# pass_id: 2, batch_id: 54, loss: 3.206448
# pass_id: 2, batch_id: 55, loss: 3.333961
# pass_id: 2, batch_id: 56, loss: 3.307354
# pass_id: 2, batch_id: 57, loss: 3.301480
# pass_id: 2, batch_id: 58, loss: 3.382247
# pass_id: 2, batch_id: 59, loss: 3.386022
# pass_id: 2, batch_id: 60, loss: 3.179159
# pass_id: 2, batch_id: 61, loss: 3.251422
# pass_id: 2, batch_id: 62, loss: 3.161568
# pass_id: 2, batch_id: 63, loss: 3.070165
# pass_id: 2, batch_id: 64, loss: 3.388049
# pass_id: 2, batch_id: 65, loss: 3.321046
# pass_id: 2, batch_id: 66, loss: 3.175339
# pass_id: 2, batch_id: 67, loss: 3.286465
# pass_id: 2, batch_id: 68, loss: 3.163215
# pass_id: 2, batch_id: 69, loss: 3.183687
# pass_id: 2, batch_id: 70, loss: 3.331417
# pass_id: 2, batch_id: 71, loss: 3.259071
# pass_id: 2, batch_id: 72, loss: 3.202912
# pass_id: 2, batch_id: 73, loss: 3.187152
# pass_id: 2, batch_id: 74, loss: 3.216064
# pass_id: 2, batch_id: 75, loss: 3.530973
# pass_id: 2, batch_id: 76, loss: 3.375281
# pass_id: 2, batch_id: 77, loss: 3.273863
# pass_id: 2, batch_id: 78, loss: 3.167873
# pass_id: 2, batch_id: 79, loss: 3.337704
# pass_id: 2, batch_id: 80, loss: 3.226752
# pass_id: 2, batch_id: 81, loss: 3.314321
# pass_id: 2, batch_id: 82, loss: 3.313714
# pass_id: 2, batch_id: 83, loss: 3.490115
# pass_id: 2, batch_id: 84, loss: 3.304904
# pass_id: 2, batch_id: 85, loss: 3.387191
# pass_id: 2, batch_id: 86, loss: 3.315278
# pass_id: 2, batch_id: 87, loss: 3.196220
# pass_id: 2, batch_id: 88, loss: 3.470651
# pass_id: 2, batch_id: 89, loss: 3.258134
# pass_id: 2, batch_id: 90, loss: 3.321925
# pass_id: 2, batch_id: 91, loss: 3.356495
# pass_id: 2, batch_id: 92, loss: 3.399023
# pass_id: 2, batch_id: 93, loss: 3.366712
# pass_id: 2, batch_id: 94, loss: 3.225117
# pass_id: 2, batch_id: 95, loss: 3.207012
# pass_id: 2, batch_id: 96, loss: 3.264915
# pass_id: 2, batch_id: 97, loss: 3.231156
# pass_id: 2, batch_id: 98, loss: 3.260868
# pass_id: 2, batch_id: 99, loss: 3.245723
# pass_id: 2, batch_id: 100, loss: 3.292242
# pass_id: 2, batch_id: 101, loss: 3.108784
# pass_id: 2, batch_id: 102, loss: 3.304183
# pass_id: 2, batch_id: 103, loss: 3.109356
# pass_id: 2, batch_id: 104, loss: 3.288528
# pass_id: 2, batch_id: 105, loss: 3.169843
# pass_id: 2, batch_id: 106, loss: 3.095678
# pass_id: 2, batch_id: 107, loss: 3.484432
# pass_id: 2, batch_id: 108, loss: 3.277402
# pass_id: 2, batch_id: 109, loss: 3.039155
# pass_id: 2, batch_id: 110, loss: 3.480577
# pass_id: 2, batch_id: 111, loss: 3.245394
# pass_id: 2, batch_id: 112, loss: 3.256464
# pass_id: 2, batch_id: 113, loss: 3.317899
# pass_id: 2, batch_id: 114, loss: 3.259216
# pass_id: 2, batch_id: 115, loss: 3.334494
# pass_id: 2, batch_id: 116, loss: 3.203496
# pass_id: 2, batch_id: 117, loss: 3.221604
# pass_id: 2, batch_id: 118, loss: 3.080238
# pass_id: 2, batch_id: 119, loss: 3.113497
# pass_id: 2, batch_id: 120, loss: 3.223982
# pass_id: 2, batch_id: 121, loss: 3.417707
# pass_id: 2, batch_id: 122, loss: 2.962266
# pass_id: 2, batch_id: 123, loss: 3.546049
# pass_id: 2, batch_id: 124, loss: 3.324757
# pass_id: 2, batch_id: 125, loss: 3.282614
# pass_id: 2, batch_id: 126, loss: 3.189037
# pass_id: 2, batch_id: 127, loss: 3.305067
# pass_id: 2, batch_id: 128, loss: 3.313159
# pass_id: 2, batch_id: 129, loss: 3.047241
# pass_id: 2, batch_id: 130, loss: 3.155337
# pass_id: 2, batch_id: 131, loss: 3.363307
# pass_id: 2, batch_id: 132, loss: 3.336178
# pass_id: 2, batch_id: 133, loss: 3.131199
# pass_id: 2, batch_id: 134, loss: 3.259171
# pass_id: 2, batch_id: 135, loss: 3.255697
# pass_id: 2, batch_id: 136, loss: 3.209809
# pass_id: 2, batch_id: 137, loss: 3.396977
# pass_id: 2, batch_id: 138, loss: 3.445149
# pass_id: 2, batch_id: 139, loss: 3.091701
# pass_id: 2, batch_id: 140, loss: 3.048500
# pass_id: 2, batch_id: 141, loss: 3.389245
# pass_id: 2, batch_id: 142, loss: 2.939502
# pass_id: 2, batch_id: 143, loss: 3.313362
# pass_id: 2, batch_id: 144, loss: 3.377696
# pass_id: 2, batch_id: 145, loss: 3.401215
# pass_id: 2, batch_id: 146, loss: 3.244580
# pass_id: 2, batch_id: 147, loss: 3.110857
# pass_id: 2, batch_id: 148, loss: 3.342284
# pass_id: 2, batch_id: 149, loss: 3.174030
# pass_id: 2, batch_id: 150, loss: 3.263324
# pass_id: 2, batch_id: 151, loss: 3.095563
# pass_id: 2, batch_id: 152, loss: 3.301547
# pass_id: 2, batch_id: 153, loss: 3.346436
# pass_id: 2, batch_id: 154, loss: 3.492825
# pass_id: 2, batch_id: 155, loss: 3.015429
# pass_id: 2, batch_id: 156, loss: 3.305417
# pass_id: 2, batch_id: 157, loss: 3.097817
# pass_id: 2, batch_id: 158, loss: 3.278746
# pass_id: 2, batch_id: 159, loss: 3.370824
# pass_id: 2, batch_id: 160, loss: 3.216509
# pass_id: 2, batch_id: 161, loss: 3.176914
# pass_id: 2, batch_id: 162, loss: 3.229415
# pass_id: 2, batch_id: 163, loss: 3.215579
# pass_id: 2, batch_id: 164, loss: 3.416986
# pass_id: 2, batch_id: 165, loss: 3.465929
# pass_id: 2, batch_id: 166, loss: 3.428895
# pass_id: 2, batch_id: 167, loss: 3.306209
# pass_id: 2, batch_id: 168, loss: 3.230175
# pass_id: 2, batch_id: 169, loss: 3.280042
# pass_id: 2, batch_id: 170, loss: 3.023456
# pass_id: 2, batch_id: 171, loss: 3.426311
# pass_id: 2, batch_id: 172, loss: 3.205006
# pass_id: 2, batch_id: 173, loss: 2.979206
# pass_id: 2, batch_id: 174, loss: 3.325685
# pass_id: 2, batch_id: 175, loss: 3.168158
# pass_id: 2, batch_id: 176, loss: 3.356619
# pass_id: 2, batch_id: 177, loss: 3.110039
# pass_id: 2, batch_id: 178, loss: 3.292662
# pass_id: 2, batch_id: 179, loss: 3.169909
# pass_id: 2, batch_id: 180, loss: 3.184240
# pass_id: 2, batch_id: 181, loss: 3.136494
# pass_id: 2, batch_id: 182, loss: 3.196700
# pass_id: 2, batch_id: 183, loss: 2.904158
# pass_id: 2, batch_id: 184, loss: 3.164359
# pass_id: 2, batch_id: 185, loss: 3.063534
# pass_id: 2, batch_id: 186, loss: 3.200302
# pass_id: 2, batch_id: 187, loss: 2.987128
# pass_id: 2, batch_id: 188, loss: 3.368001
# pass_id: 2, batch_id: 189, loss: 3.189313
# pass_id: 2, batch_id: 190, loss: 3.073685
# pass_id: 2, batch_id: 191, loss: 3.150380
# pass_id: 2, batch_id: 192, loss: 3.093962
# pass_id: 2, batch_id: 193, loss: 3.274743
# pass_id: 2, batch_id: 194, loss: 3.147902
# pass_id: 2, batch_id: 195, loss: 3.141240
# pass_id: 2, batch_id: 196, loss: 3.540098
# pass_id: 2, batch_id: 197, loss: 3.164273
# pass_id: 2, batch_id: 198, loss: 3.137602
# pass_id: 2, batch_id: 199, loss: 3.006516
# pass_id: 2, batch_id: 200, loss: 2.914477
# pass_id: 2, batch_id: 201, loss: 3.208235
# pass_id: 2, batch_id: 202, loss: 3.221273
# pass_id: 2, batch_id: 203, loss: 3.522104
# pass_id: 2, batch_id: 204, loss: 3.335254
# pass_id: 2, batch_id: 205, loss: 3.160305
# pass_id: 2, batch_id: 206, loss: 3.043227
# pass_id: 2, batch_id: 207, loss: 3.211823
# pass_id: 2, batch_id: 208, loss: 3.153534
# pass_id: 2, batch_id: 209, loss: 3.287407
# pass_id: 2, batch_id: 210, loss: 3.030531
# pass_id: 2, batch_id: 211, loss: 3.152055
# pass_id: 2, batch_id: 212, loss: 3.232711
# pass_id: 2, batch_id: 213, loss: 3.044367
# pass_id: 2, batch_id: 214, loss: 3.120463
# pass_id: 2, batch_id: 215, loss: 3.043607
# pass_id: 2, batch_id: 216, loss: 3.131404
# pass_id: 2, batch_id: 217, loss: 3.382475
# pass_id: 2, batch_id: 218, loss: 3.076913
# pass_id: 2, batch_id: 219, loss: 3.165027
# pass_id: 2, batch_id: 220, loss: 2.956348
# pass_id: 2, batch_id: 221, loss: 3.239734
# pass_id: 2, batch_id: 222, loss: 3.263957
# pass_id: 2, batch_id: 223, loss: 3.178230
# pass_id: 2, batch_id: 224, loss: 3.161088
# pass_id: 2, batch_id: 225, loss: 3.177260
# pass_id: 2, batch_id: 226, loss: 3.231795
# pass_id: 2, batch_id: 227, loss: 3.267008
# pass_id: 2, batch_id: 228, loss: 3.362611
# pass_id: 2, batch_id: 229, loss: 3.050419
# pass_id: 2, batch_id: 230, loss: 3.184414
# pass_id: 2, batch_id: 231, loss: 3.158807
# pass_id: 2, batch_id: 232, loss: 2.993593
# pass_id: 2, batch_id: 233, loss: 2.967866
# pass_id: 2, batch_id: 234, loss: 3.179198
# pass_id: 2, batch_id: 235, loss: 3.028409
# pass_id: 2, batch_id: 236, loss: 2.915929
# pass_id: 2, batch_id: 237, loss: 2.984982
# pass_id: 2, batch_id: 238, loss: 3.158079
# pass_id: 2, batch_id: 239, loss: 3.124318
# pass_id: 2, batch_id: 240, loss: 3.042799
# pass_id: 2, batch_id: 241, loss: 3.208892
# ...
# pass_id: 17, batch_id: 82, loss: 1.533489
# pass_id: 17, batch_id: 83, loss: 1.651408
# pass_id: 17, batch_id: 84, loss: 1.392516
# pass_id: 17, batch_id: 85, loss: 1.471534
# pass_id: 17, batch_id: 86, loss: 1.580288
# pass_id: 17, batch_id: 87, loss: 1.373946
# pass_id: 17, batch_id: 88, loss: 1.545256
# pass_id: 17, batch_id: 89, loss: 1.594758
# pass_id: 17, batch_id: 90, loss: 1.411482
# pass_id: 17, batch_id: 91, loss: 1.591914
# pass_id: 17, batch_id: 92, loss: 1.436491
# pass_id: 17, batch_id: 93, loss: 1.753231
# pass_id: 17, batch_id: 94, loss: 1.606611
# pass_id: 17, batch_id: 95, loss: 1.625120
# pass_id: 17, batch_id: 96, loss: 1.710527
# pass_id: 17, batch_id: 97, loss: 1.532506
# pass_id: 17, batch_id: 98, loss: 1.505534
# pass_id: 17, batch_id: 99, loss: 1.269974
# pass_id: 17, batch_id: 100, loss: 1.509499
# pass_id: 17, batch_id: 101, loss: 1.295924
# pass_id: 17, batch_id: 102, loss: 1.232550
# pass_id: 17, batch_id: 103, loss: 1.554499
# pass_id: 17, batch_id: 104, loss: 1.783088
# pass_id: 17, batch_id: 105, loss: 1.544807
# pass_id: 17, batch_id: 106, loss: 1.445686
# pass_id: 17, batch_id: 107, loss: 1.386538
# pass_id: 17, batch_id: 108, loss: 1.434441
# pass_id: 17, batch_id: 109, loss: 1.503433
# pass_id: 17, batch_id: 110, loss: 1.708125
# pass_id: 17, batch_id: 111, loss: 1.676339
# pass_id: 17, batch_id: 112, loss: 1.403466
# pass_id: 17, batch_id: 113, loss: 1.580434
# pass_id: 17, batch_id: 114, loss: 1.373864
# pass_id: 17, batch_id: 115, loss: 1.611912
# pass_id: 17, batch_id: 116, loss: 1.556947
# pass_id: 17, batch_id: 117, loss: 1.491853
# pass_id: 17, batch_id: 118, loss: 1.422665
# pass_id: 17, batch_id: 119, loss: 1.606825
# pass_id: 17, batch_id: 120, loss: 1.562510
# pass_id: 17, batch_id: 121, loss: 1.425830
# pass_id: 17, batch_id: 122, loss: 1.488423
# pass_id: 17, batch_id: 123, loss: 1.261581
# pass_id: 17, batch_id: 124, loss: 1.406585
# pass_id: 17, batch_id: 125, loss: 1.549302
# pass_id: 17, batch_id: 126, loss: 1.688404
# pass_id: 17, batch_id: 127, loss: 1.575881
# pass_id: 17, batch_id: 128, loss: 1.514988
# pass_id: 17, batch_id: 129, loss: 1.451731
# pass_id: 17, batch_id: 130, loss: 1.389268
# pass_id: 17, batch_id: 131, loss: 1.577408
# pass_id: 17, batch_id: 132, loss: 1.527299
# pass_id: 17, batch_id: 133, loss: 1.427262
# pass_id: 17, batch_id: 134, loss: 1.604670
# pass_id: 17, batch_id: 135, loss: 1.584533
# pass_id: 17, batch_id: 136, loss: 1.461492
# pass_id: 17, batch_id: 137, loss: 1.455045
# pass_id: 17, batch_id: 138, loss: 1.705129
# pass_id: 17, batch_id: 139, loss: 1.664170
# pass_id: 17, batch_id: 140, loss: 1.537888
# pass_id: 17, batch_id: 141, loss: 1.383327
# pass_id: 17, batch_id: 142, loss: 1.485434
# pass_id: 17, batch_id: 143, loss: 1.637063
# pass_id: 17, batch_id: 144, loss: 1.537516
# pass_id: 17, batch_id: 145, loss: 1.603580
# pass_id: 17, batch_id: 146, loss: 1.576855
# pass_id: 17, batch_id: 147, loss: 1.704588
# pass_id: 17, batch_id: 148, loss: 1.515562
# pass_id: 17, batch_id: 149, loss: 1.448808
# pass_id: 17, batch_id: 150, loss: 1.442720
# pass_id: 17, batch_id: 151, loss: 1.449855
# pass_id: 17, batch_id: 152, loss: 1.565863
# pass_id: 17, batch_id: 153, loss: 1.413596
# pass_id: 17, batch_id: 154, loss: 1.579168
# pass_id: 17, batch_id: 155, loss: 1.369078
# pass_id: 17, batch_id: 156, loss: 1.438053
# pass_id: 17, batch_id: 157, loss: 1.534304
# pass_id: 17, batch_id: 158, loss: 1.646741
# pass_id: 17, batch_id: 159, loss: 1.694492
# pass_id: 17, batch_id: 160, loss: 1.531684
# pass_id: 17, batch_id: 161, loss: 1.539765
# pass_id: 17, batch_id: 162, loss: 1.599489
# pass_id: 17, batch_id: 163, loss: 1.533564
# pass_id: 17, batch_id: 164, loss: 1.550387
# pass_id: 17, batch_id: 165, loss: 1.500905
# pass_id: 17, batch_id: 166, loss: 1.673933
# pass_id: 17, batch_id: 167, loss: 1.538801
# pass_id: 17, batch_id: 168, loss: 1.562117
# pass_id: 17, batch_id: 169, loss: 1.697031
# pass_id: 17, batch_id: 170, loss: 1.453301
# pass_id: 17, batch_id: 171, loss: 1.340191
# pass_id: 17, batch_id: 172, loss: 1.321576
# pass_id: 17, batch_id: 173, loss: 1.533214
# pass_id: 17, batch_id: 174, loss: 1.517277
# pass_id: 17, batch_id: 175, loss: 1.250353
# pass_id: 17, batch_id: 176, loss: 1.493638
# pass_id: 17, batch_id: 177, loss: 1.382783
# pass_id: 17, batch_id: 178, loss: 1.543988
# pass_id: 17, batch_id: 179, loss: 1.621105
# pass_id: 17, batch_id: 180, loss: 1.234994
# pass_id: 17, batch_id: 181, loss: 1.448089
# pass_id: 17, batch_id: 182, loss: 1.545133
# pass_id: 17, batch_id: 183, loss: 1.421794
# pass_id: 17, batch_id: 184, loss: 1.483128
# pass_id: 17, batch_id: 185, loss: 1.416697
# pass_id: 17, batch_id: 186, loss: 1.505908
# pass_id: 17, batch_id: 187, loss: 1.523638
# pass_id: 17, batch_id: 188, loss: 1.497257
# pass_id: 17, batch_id: 189, loss: 1.471429
# pass_id: 17, batch_id: 190, loss: 1.235087
# pass_id: 17, batch_id: 191, loss: 1.588774
# pass_id: 17, batch_id: 192, loss: 1.384187
# pass_id: 17, batch_id: 193, loss: 1.432950
# pass_id: 17, batch_id: 194, loss: 1.470126
# pass_id: 17, batch_id: 195, loss: 1.662285
# pass_id: 17, batch_id: 196, loss: 1.312933
# pass_id: 17, batch_id: 197, loss: 1.405072
# pass_id: 17, batch_id: 198, loss: 1.537698
# pass_id: 17, batch_id: 199, loss: 1.427900
# pass_id: 17, batch_id: 200, loss: 1.459788
# pass_id: 17, batch_id: 201, loss: 1.358219
# pass_id: 17, batch_id: 202, loss: 1.507748
# pass_id: 17, batch_id: 203, loss: 1.512936
# pass_id: 17, batch_id: 204, loss: 1.575360
# pass_id: 17, batch_id: 205, loss: 1.320652
# pass_id: 17, batch_id: 206, loss: 1.531121
# pass_id: 17, batch_id: 207, loss: 1.464324
# pass_id: 17, batch_id: 208, loss: 1.444971
# pass_id: 17, batch_id: 209, loss: 1.365357
# pass_id: 17, batch_id: 210, loss: 1.566878
# pass_id: 17, batch_id: 211, loss: 1.351356
# pass_id: 17, batch_id: 212, loss: 1.521377
# pass_id: 17, batch_id: 213, loss: 1.415216
# pass_id: 17, batch_id: 214, loss: 1.573937
# pass_id: 17, batch_id: 215, loss: 1.482235
# pass_id: 17, batch_id: 216, loss: 1.592786
# pass_id: 17, batch_id: 217, loss: 1.432147
# pass_id: 17, batch_id: 218, loss: 1.383443
# pass_id: 17, batch_id: 219, loss: 1.602876
# pass_id: 17, batch_id: 220, loss: 1.257888
# pass_id: 17, batch_id: 221, loss: 1.248717
# pass_id: 17, batch_id: 222, loss: 1.687083
# pass_id: 17, batch_id: 223, loss: 1.466570
# pass_id: 17, batch_id: 224, loss: 1.494948
# pass_id: 17, batch_id: 225, loss: 1.600353
# pass_id: 17, batch_id: 226, loss: 1.565365
# pass_id: 17, batch_id: 227, loss: 1.354768
# pass_id: 17, batch_id: 228, loss: 1.455286
# pass_id: 17, batch_id: 229, loss: 1.330779
# pass_id: 17, batch_id: 230, loss: 1.438356
# pass_id: 17, batch_id: 231, loss: 1.475532
# pass_id: 17, batch_id: 232, loss: 1.338716
# pass_id: 17, batch_id: 233, loss: 1.599320
# pass_id: 17, batch_id: 234, loss: 1.378033
# pass_id: 17, batch_id: 235, loss: 1.429874
# pass_id: 17, batch_id: 236, loss: 1.335668
# pass_id: 17, batch_id: 237, loss: 1.469239
# pass_id: 17, batch_id: 238, loss: 1.439213
# pass_id: 17, batch_id: 239, loss: 1.367432
# pass_id: 17, batch_id: 240, loss: 1.418932
# pass_id: 17, batch_id: 241, loss: 1.492701
# pass_id: 17, batch_id: 242, loss: 1.632130
# pass_id: 17, batch_id: 243, loss: 1.490896
# pass_id: 17, batch_id: 244, loss: 1.305164
# pass_id: 17, batch_id: 245, loss: 1.443228
# pass_id: 17, batch_id: 246, loss: 1.482736
# pass_id: 17, batch_id: 247, loss: 1.533294
# pass_id: 17, batch_id: 248, loss: 1.312790
# pass_id: 17, batch_id: 249, loss: 1.506074
# pass_id: 17, batch_id: 250, loss: 1.402552
# pass_id: 17, batch_id: 251, loss: 1.652691
# pass_id: 17, batch_id: 252, loss: 1.365724
# pass_id: 17, batch_id: 253, loss: 1.453942
# pass_id: 17, batch_id: 254, loss: 1.500453
# pass_id: 17, batch_id: 255, loss: 1.405007
# pass_id: 17, batch_id: 256, loss: 1.553701
# pass_id: 17, batch_id: 257, loss: 1.429075
# pass_id: 17, batch_id: 258, loss: 1.479399
# pass_id: 17, batch_id: 259, loss: 1.323849
# pass_id: 17, batch_id: 260, loss: 1.445572
# pass_id: 17, batch_id: 261, loss: 1.557543
# pass_id: 17, batch_id: 262, loss: 1.538976
# pass_id: 17, batch_id: 263, loss: 1.595001
# pass_id: 17, batch_id: 264, loss: 1.433353
# pass_id: 17, batch_id: 265, loss: 1.501352
# pass_id: 17, batch_id: 266, loss: 1.606189
# pass_id: 17, batch_id: 267, loss: 1.324789
# pass_id: 17, batch_id: 268, loss: 1.460218
# pass_id: 17, batch_id: 269, loss: 1.349674
# pass_id: 17, batch_id: 270, loss: 1.612295
# pass_id: 17, batch_id: 271, loss: 1.365654
# pass_id: 17, batch_id: 272, loss: 1.554976
# pass_id: 17, batch_id: 273, loss: 1.396530
# pass_id: 17, batch_id: 274, loss: 1.552563
# pass_id: 17, batch_id: 275, loss: 1.457623
# pass_id: 17, batch_id: 276, loss: 1.602252
# pass_id: 17, batch_id: 277, loss: 1.630854
# pass_id: 17, batch_id: 278, loss: 1.577261
# pass_id: 17, batch_id: 279, loss: 1.641989
# pass_id: 17, batch_id: 280, loss: 1.330746
# pass_id: 17, batch_id: 281, loss: 1.488019
# pass_id: 17, batch_id: 282, loss: 1.329030
# pass_id: 17, batch_id: 283, loss: 1.345551
# pass_id: 17, batch_id: 284, loss: 1.518314
# pass_id: 17, batch_id: 285, loss: 1.432853
# pass_id: 17, batch_id: 286, loss: 1.381399
# pass_id: 17, batch_id: 287, loss: 1.589516
# pass_id: 17, batch_id: 288, loss: 1.584335
# pass_id: 17, batch_id: 289, loss: 1.627895
# pass_id: 17, batch_id: 290, loss: 1.430519
# pass_id: 17, batch_id: 291, loss: 1.517776
# pass_id: 17, batch_id: 292, loss: 1.504233
# pass_id: 17, batch_id: 293, loss: 1.529674
# pass_id: 17, batch_id: 294, loss: 1.493340
# pass_id: 17, batch_id: 295, loss: 1.336098
# pass_id: 17, batch_id: 296, loss: 1.482289
# pass_id: 17, batch_id: 297, loss: 1.487227
# pass_id: 17, batch_id: 298, loss: 1.392017
# pass_id: 17, batch_id: 299, loss: 1.320789
# pass_id: 17, batch_id: 300, loss: 1.609045
# pass_id: 17, batch_id: 301, loss: 1.498798
# pass_id: 17, batch_id: 302, loss: 1.594123
# pass_id: 17, batch_id: 303, loss: 1.397572
# pass_id: 17, batch_id: 304, loss: 1.545561
# pass_id: 17, batch_id: 305, loss: 1.526342
# pass_id: 17, batch_id: 306, loss: 1.481199
# pass_id: 17, batch_id: 307, loss: 1.482255
# pass_id: 17, batch_id: 308, loss: 1.469960
# pass_id: 17, batch_id: 309, loss: 1.411458
# pass_id: 17, batch_id: 310, loss: 1.422477
# pass_id: 17, batch_id: 311, loss: 1.709993
# pass_id: 17, batch_id: 312, loss: 1.771309
# pass_id: 17, batch_id: 313, loss: 1.867994
# pass_id: 17, batch_id: 314, loss: 1.687000
# pass_id: 17, batch_id: 315, loss: 1.584700
# pass_id: 17, batch_id: 316, loss: 1.518772
# pass_id: 17, batch_id: 317, loss: 1.673841
# pass_id: 17, batch_id: 318, loss: 1.702767
# pass_id: 17, batch_id: 319, loss: 1.929455
# pass_id: 17, batch_id: 320, loss: 1.554105
# pass_id: 17, batch_id: 321, loss: 1.642005
# pass_id: 17, batch_id: 322, loss: 1.648741
# pass_id: 17, batch_id: 323, loss: 1.605093
# pass_id: 17, batch_id: 324, loss: 1.592746
# pass_id: 17, batch_id: 325, loss: 1.604104
# pass_id: 17, batch_id: 326, loss: 1.585537
# pass_id: 17, batch_id: 327, loss: 1.766739
# pass_id: 17, batch_id: 328, loss: 1.846304
# pass_id: 17, batch_id: 329, loss: 1.691094
# pass_id: 17, batch_id: 330, loss: 1.754404
# pass_id: 17, batch_id: 331, loss: 1.595977
# pass_id: 17, batch_id: 332, loss: 1.757408
# pass_id: 17, batch_id: 333, loss: 1.698134
# pass_id: 17, batch_id: 334, loss: 1.579578
# pass_id: 17, batch_id: 335, loss: 1.737324
# pass_id: 17, batch_id: 336, loss: 1.719075
# pass_id: 17, batch_id: 337, loss: 1.756641
# pass_id: 17, batch_id: 338, loss: 1.538175
# pass_id: 17, batch_id: 339, loss: 1.701015
# pass_id: 17, batch_id: 340, loss: 1.725064
# pass_id: 17, batch_id: 341, loss: 1.819080
# pass_id: 17, batch_id: 342, loss: 1.606697
# pass_id: 17, batch_id: 343, loss: 1.667985
# pass_id: 17, batch_id: 344, loss: 1.864336
# pass_id: 17, batch_id: 345, loss: 1.798974
# pass_id: 17, batch_id: 346, loss: 1.581365
# pass_id: 17, batch_id: 347, loss: 1.492296
# pass_id: 17, batch_id: 348, loss: 1.721573
# pass_id: 17, batch_id: 349, loss: 1.600099
# pass_id: 17, batch_id: 350, loss: 1.721390
# pass_id: 17, batch_id: 351, loss: 1.611236
# pass_id: 17, batch_id: 352, loss: 1.615140
# pass_id: 17, batch_id: 353, loss: 1.753730
# pass_id: 17, batch_id: 354, loss: 1.862253
# pass_id: 17, batch_id: 355, loss: 1.666048
# pass_id: 17, batch_id: 356, loss: 1.676019
# pass_id: 17, batch_id: 357, loss: 1.485954
# pass_id: 17, batch_id: 358, loss: 1.530462
# pass_id: 17, batch_id: 359, loss: 1.624692
# pass_id: 17, batch_id: 360, loss: 1.723922
# pass_id: 17, batch_id: 361, loss: 1.730117
# pass_id: 17, batch_id: 362, loss: 1.697315
# pass_id: 17, batch_id: 363, loss: 1.641486
# pass_id: 17, batch_id: 364, loss: 1.851108
# pass_id: 17, batch_id: 365, loss: 1.805902
# pass_id: 17, batch_id: 366, loss: 1.756844
# pass_id: 17, batch_id: 367, loss: 1.866899
# pass_id: 17, batch_id: 368, loss: 1.789609
# pass_id: 17, batch_id: 369, loss: 1.699380
# pass_id: 17, batch_id: 370, loss: 1.623517
# pass_id: 17, batch_id: 371, loss: 1.749037
# pass_id: 17, batch_id: 372, loss: 1.704749
# pass_id: 17, batch_id: 373, loss: 1.781416
# pass_id: 17, batch_id: 374, loss: 1.665967
# pass_id: 17, batch_id: 375, loss: 1.647265
# pass_id: 17, batch_id: 376, loss: 1.544644
# pass_id: 17, batch_id: 377, loss: 1.634779
# pass_id: 17, batch_id: 378, loss: 1.686182
# pass_id: 17, batch_id: 379, loss: 1.637937
# pass_id: 17, batch_id: 380, loss: 1.628003
# pass_id: 17, batch_id: 381, loss: 1.595271
# pass_id: 17, batch_id: 382, loss: 1.827440
# pass_id: 17, batch_id: 383, loss: 1.627986
# pass_id: 17, batch_id: 384, loss: 1.698027
# pass_id: 17, batch_id: 385, loss: 1.553262
# pass_id: 17, batch_id: 386, loss: 1.514419
# pass_id: 17, batch_id: 387, loss: 1.733448
# pass_id: 17, batch_id: 388, loss: 1.720868
# pass_id: 17, batch_id: 389, loss: 1.566933
# pass_id: 17, batch_id: 390, loss: 1.795184
# pass_id: 17, batch_id: 391, loss: 1.582995
# pass_id: 17, batch_id: 392, loss: 1.492305
# pass_id: 17, batch_id: 393, loss: 1.800512
# pass_id: 17, batch_id: 394, loss: 1.607800
# pass_id: 17, batch_id: 395, loss: 1.606846
# pass_id: 17, batch_id: 396, loss: 1.603185
# pass_id: 17, batch_id: 397, loss: 1.725004
# pass_id: 17, batch_id: 398, loss: 1.627401
# pass_id: 17, batch_id: 399, loss: 1.704888
# pass_id: 17, batch_id: 400, loss: 1.670648
# pass_id: 17, batch_id: 401, loss: 1.663837
# pass_id: 17, batch_id: 402, loss: 1.763835
# pass_id: 17, batch_id: 403, loss: 1.469655
# pass_id: 17, batch_id: 404, loss: 1.667266
# pass_id: 17, batch_id: 405, loss: 1.426178
# pass_id: 17, batch_id: 406, loss: 1.638783
# pass_id: 17, batch_id: 407, loss: 1.896285
# pass_id: 17, batch_id: 408, loss: 1.498919
# pass_id: 17, batch_id: 409, loss: 1.817482
# pass_id: 17, batch_id: 410, loss: 1.698292
# pass_id: 17, batch_id: 411, loss: 1.620573
# pass_id: 17, batch_id: 412, loss: 1.767643
# pass_id: 17, batch_id: 413, loss: 1.520586
# pass_id: 17, batch_id: 414, loss: 1.943385
# pass_id: 17, batch_id: 415, loss: 1.567575
# pass_id: 17, batch_id: 416, loss: 1.707403
# pass_id: 17, batch_id: 417, loss: 1.736445
# pass_id: 17, batch_id: 418, loss: 1.460551
# pass_id: 17, batch_id: 419, loss: 1.562139
# pass_id: 17, batch_id: 420, loss: 1.622319
# pass_id: 17, batch_id: 421, loss: 1.623598
# pass_id: 17, batch_id: 422, loss: 1.617045
# pass_id: 17, batch_id: 423, loss: 1.620221
# pass_id: 17, batch_id: 424, loss: 1.791422
# pass_id: 17, batch_id: 425, loss: 1.775751
# pass_id: 17, batch_id: 426, loss: 1.685148
# pass_id: 17, batch_id: 427, loss: 1.691375
# pass_id: 17, batch_id: 428, loss: 1.764358
# pass_id: 17, batch_id: 429, loss: 1.604277
# pass_id: 17, batch_id: 430, loss: 1.712676
# pass_id: 17, batch_id: 431, loss: 1.676021
# pass_id: 17, batch_id: 432, loss: 1.668328
# pass_id: 17, batch_id: 433, loss: 1.808927
# pass_id: 17, batch_id: 434, loss: 1.798579
# pass_id: 17, batch_id: 435, loss: 1.660485
# pass_id: 17, batch_id: 436, loss: 1.865364
# pass_id: 17, batch_id: 437, loss: 1.645351
# pass_id: 17, batch_id: 438, loss: 1.668261
# pass_id: 17, batch_id: 439, loss: 1.662630
# pass_id: 17, batch_id: 440, loss: 1.706042
# pass_id: 17, batch_id: 441, loss: 1.532627
# pass_id: 17, batch_id: 442, loss: 1.847870
# pass_id: 17, batch_id: 443, loss: 1.747396
# pass_id: 17, batch_id: 444, loss: 1.627490
# pass_id: 17, batch_id: 445, loss: 1.960182
# pass_id: 17, batch_id: 446, loss: 1.815169
# pass_id: 17, batch_id: 447, loss: 1.729281
# pass_id: 17, batch_id: 448, loss: 1.710020
# pass_id: 17, batch_id: 449, loss: 1.639574
# pass_id: 17, batch_id: 450, loss: 1.733263
# pass_id: 17, batch_id: 451, loss: 1.728470
# pass_id: 17, batch_id: 452, loss: 1.743885
# pass_id: 17, batch_id: 453, loss: 1.810999

# %% [markdown]
# ## 应用模型
#
# ### 构建预测程序
#
# 定义用于预测的`Program`，在其中创建预测的网络结构。

# %%
infer_prog = fluid.Program()
startup_prog = fluid.Program()
with fluid.program_guard(infer_prog, startup_prog):
    with fluid.unique_name.guard():
        translation_ids, translation_scores = infer_model()

# %% [markdown]
# ### 构建数据提供器
#
# 和训练类似，这里使用封装的`paddle.dataset.wmt16.test`接口定义测试数据生成器，测试数据共1000条，组完batch后作为预测的输入；另外我们获取源语言和目标语言id到word的词典，以将id序列转换为明文序列打印输出。

# %%
test_data = paddle.batch(
    paddle.dataset.wmt16.test(source_dict_size, target_dict_size),
    batch_size=batch_size)
src_idx2word = paddle.dataset.wmt16.get_dict(
    "en", source_dict_size, reverse=True)
trg_idx2word = paddle.dataset.wmt16.get_dict(
    "de", target_dict_size, reverse=True)

# %% [markdown]
# ### 测试
# 首先要加载训练过程保存下来的模型，然后就可以循环测试数据进行预测了。这里每次运行我们都会创建`data_layer`对应输入数据的`dict`传入，这个和`DataFeeder`相同的效果。生成过程对于每个测试数据都会将源语言句子和`beam_size`个生成句子打印输出。

# %%
    import numpy as np
    fluid.io.load_params(exe, model_save_dir, main_program=infer_prog)

    for data in test_data():
        src_word_id = fluid.create_lod_tensor(
            data=[x[0] for x in data],
            recursive_seq_lens=[[len(x[0]) for x in data]],
            place=place)
        # init_ids内容为start token
        init_ids = fluid.create_lod_tensor(
            data=np.array([[0]] * len(data), dtype='int64'),
            recursive_seq_lens=[[1] * len(data)] * 2,
            place=place)
        # init_scores为beam search过程累积得分的初值
        init_scores = fluid.create_lod_tensor(
            data=np.array([[0.]] * len(data), dtype='float32'),
            recursive_seq_lens=[[1] * len(data)] * 2,
            place=place)
        seq_ids, seq_scores = exe.run(
            infer_prog,
            feed={
                'src_word_id': src_word_id,
                'init_ids': init_ids,
                'init_scores': init_scores
            },
            fetch_list=[translation_ids, translation_scores],
            return_numpy=False)
        # 如何解析翻译结果详见 train.py 中对应代码的注释说明
        hyps = [[] for i in range(len(seq_ids.lod()[0]) - 1)]
        scores = [[] for i in range(len(seq_scores.lod()[0]) - 1)]
        for i in range(len(seq_ids.lod()[0]) - 1):
            start = seq_ids.lod()[0][i]
            end = seq_ids.lod()[0][i + 1]
            print("Original sentence:")
            print(" ".join([src_idx2word[idx] for idx in data[i][0][1:-1]]))
            print("Translated score and sentence:")
            for j in range(end - start):
                sub_start = seq_ids.lod()[1][start + j]
                sub_end = seq_ids.lod()[1][start + j + 1]
                hyps[i].append(" ".join([
                    trg_idx2word[idx]
                    for idx in np.array(seq_ids)[sub_start:sub_end][1:-1]
                ]))
                scores[i].append(np.array(seq_scores)[sub_end - 1])
                print(scores[i][-1], hyps[i][-1].encode('utf8'))
# Out:
# Original sentence:
# A man in an orange hat starring at something .
# Translated score and sentence:
# -6.541696 b'Ein Mann in einem gelben Hemd schaut auf etwas .'
# -6.5729966 b'Ein Mann in einem gelben T-Shirt schaut auf etwas .'
# -6.7337995 b'Ein Mann in einem gelben T-Shirt starrt auf etwas .'
# -6.757338 b'Ein Mann in einem gelben Hemd starrt auf etwas .'
# Original sentence:
# A Boston Terrier is running on lush green grass in front of a white fence .
# Translated score and sentence:
# -14.105242 b'Ein Tourist springt vor einem wei\xc3\x9fen wei\xc3\x9fen Zaun auf einem gr\xc3\xbcnen Zaun .'
# -14.845966 b'Ein Tourist springt vor einem wei\xc3\x9fen wei\xc3\x9fen Zaun auf einem wei\xc3\x9fen Zaun .'
# -15.499738 b'Ein Tourist springt vor einem wei\xc3\x9fen wei\xc3\x9fen Zaun auf einem gr\xc3\xbcnen Hang .'
# -15.921158 b'Ein Tourist springt vor einem wei\xc3\x9fen wei\xc3\x9fen Zaun auf einem gr\xc3\xbcnen Zaun vor .'
# Original sentence:
# A girl in karate uniform breaking a stick with a front kick .
# Translated score and sentence:
# -18.798029 b'Ein M\xc3\xa4dchen in einem Tutu , das einen Baum macht , macht einen Handstand .'
# -20.506317 b'Ein M\xc3\xa4dchen in einem Tutu , das einen Baum macht , macht einen Handstand aus .'
# -20.544834 b'Ein M\xc3\xa4dchen in einem Tutu , das einen Baum macht , macht einen Handstand vor .'
# -24.09013 b'Ein M\xc3\xa4dchen in einem Tutu , das einen Baum macht , macht einen Handstand aus dem Essen .'
# Original sentence:
# Five people wearing winter jackets and helmets stand in the snow , with <unk> in the background .
# Translated score and sentence:
# -10.570401 b'F\xc3\xbcnf Personen mit Helmen und Helm stehen im Schnee und im Hintergrund sind B\xc3\xa4ume zu sehen .'
# -10.822256 b'F\xc3\xbcnf Personen mit Rettungswesten und Helm stehen im Schnee und im Hintergrund sind B\xc3\xa4ume zu sehen .'
# -10.8779125 b'F\xc3\xbcnf Personen mit Rettungswesten und Helmen stehen im Schnee und im Hintergrund sind B\xc3\xa4ume zu sehen .'
# -10.924651 b'F\xc3\xbcnf Personen mit Helm und Helm stehen im Schnee und im Hintergrund sind B\xc3\xa4ume zu sehen .'
# Original sentence:
# People are fixing the roof of a house .
# Translated score and sentence:
# -5.8568625 b'Leute sitzen auf dem Dach eines Hauses .'
# -8.22234 b'Leute ziehen das Dach eines Hauses .'
# -8.921047 b'Leute sitzen auf der Dach eines Hauses .'
# -9.342056 b'Leute sitzen auf dem Dach eines Geb\xc3\xa4udes .'
# Original sentence:
# A man in light colored clothing photographs a group of men wearing dark suits and hats standing around a woman dressed in a <unk> gown .
# Translated score and sentence:
# -27.87689 b'Ein Mann in dunkler Kleidung tanzt und unterh\xc3\xa4lt sich in einer Gruppe von M\xc3\xa4nnern , w\xc3\xa4hrend eine Frau in einem schwarzen Anzug mit Blumenmuster spricht .'
# -28.028143 b'Ein Mann in dunkler Kleidung tanzt und unterh\xc3\xa4lt sich in einer Gruppe von M\xc3\xa4nnern , w\xc3\xa4hrend eine Frau in einem schwarzen Anzug mit Kn\xc3\xb6pfen versammelt .'
# -28.0471 b'Ein Mann in dunkler Kleidung tanzt und unterh\xc3\xa4lt sich in einer Gruppe von M\xc3\xa4nnern , w\xc3\xa4hrend eine Frau in einem schwarzen Anzug mit Kn\xc3\xb6pfen spricht .'
# -28.147154 b'Ein Mann in dunkler Kleidung tanzt und unterh\xc3\xa4lt sich in einer Gruppe von M\xc3\xa4nnern , w\xc3\xa4hrend eine Frau in einem schwarzen Anzug mit Blumenmuster versammelt .'
# Original sentence:
# A group of people standing in front of an igloo .
# Translated score and sentence:
# -4.1678863 b'Eine Gruppe von Menschen steht vor einem Nachbarschaftsladen .'
# -4.7079077 b'Eine Gruppe von Menschen steht vor einem Schild .'
# -4.8235755 b'Eine Gruppe Leute steht vor einem Schild .'
# -5.976256 b'Eine Gruppe von Menschen steht vor einem McDonald .'
# Original sentence:
# A boy in a red uniform is attempting to avoid getting out at home plate , while the catcher in the blue uniform is attempting to catch him .
# Translated score and sentence:
# -18.686708 b'Ein Junge in einem gelben Trikot versucht den Ball zu , wie ein Spieler in einem schwarzen Trikot versucht , den Ball zu fangen .'
# -19.059294 b'Ein Junge in einem gelben Trikot versucht den Ball zu , wie ein Spieler in einem schwarzen Trikot versucht , den Ball zu blocken .'
# -19.230461 b'Ein Junge in einem gelben Trikot versucht den Ball zu , wie ein Junge in einem schwarzen Trikot versucht , den Ball zu fangen .'
# -19.32953 b'Ein Junge in einem gelben Trikot versucht den Ball zu , wie ein Spieler in einem wei\xc3\x9fen Trikot versucht , den Ball zu fangen .'
# Original sentence:
# A guy works on a building .
# Translated score and sentence:
# -0.78386396 b'Ein Mann arbeitet an einem Geb\xc3\xa4ude .'
# -3.0962322 b'Ein Typ arbeitet an einem Geb\xc3\xa4ude .'
# -4.4953036 b'Ein Mann arbeitet an einem Ger\xc3\xbcst .'
# -5.271198 b'Ein Mann arbeitet auf einem Ger\xc3\xbcst .'
# Original sentence:
# A man in a vest is sitting in a chair and holding magazines .
# Translated score and sentence:
# -5.544255 b'Ein Mann in einer Jacke sitzt auf einem Stuhl und h\xc3\xa4lt Zeitung .'
# -7.468552 b'Ein Mann in einer Jacke sitzt auf einem Stuhl und h\xc3\xa4lt einen Kopfh\xc3\xb6rer .'
# -7.7128587 b'Ein Mann in einer Jacke sitzt auf einem Stuhl und h\xc3\xa4lt einen Laptop .'
# -7.894903 b'Ein Mann in einer Jacke sitzt auf einem Stuhl und h\xc3\xa4lt einen Teller .'
# Original sentence:
# A mother and her young song enjoying a beautiful day outside .
# Translated score and sentence:
# -6.6494393 b'Eine Mutter und ihre Tochter genie\xc3\x9fen einen Kuchen im Freien .'
# -6.952464 b'Eine Mutter und ihre Tochter genie\xc3\x9fen einen sonnigen Tag im Freien .'
# -7.756836 b'Eine Mutter und ihre Tochter genie\xc3\x9fen einen \xc3\xb6ffentlichen Tag im Freien .'
# -8.022993 b'Eine Mutter und ihre Tochter genie\xc3\x9fen einen sch\xc3\xb6nen Tag im Freien .'
# Original sentence:
# Men playing volleyball , with one player missing the ball but hands still in the air .
# Translated score and sentence:
# -11.754563 b'Drei M\xc3\xa4nner spielen Basketball und einer von ihnen hat den Ball in die Luft .'
# -13.0884075 b'Drei M\xc3\xa4nner spielen Basketball und einer von ihnen hat die H\xc3\xa4nde in die Luft .'
# -13.131823 b'Drei M\xc3\xa4nner spielen Basketball und einer von ihnen hat den Ball in die H\xc3\xb6he .'
# -13.465887 b'Drei M\xc3\xa4nner spielen Basketball und einer von ihnen hat den Ball in der Luft .'
# Original sentence:
# A woman holding a bowl of food in a kitchen .
# Translated score and sentence:
# -4.85238 b'Eine Frau h\xc3\xa4lt eine Sch\xc3\xbcssel in einer K\xc3\xbcche .'
# -5.568251 b'Eine Frau h\xc3\xa4lt eine Sch\xc3\xbcssel in der K\xc3\xbcche .'
# -5.7526636 b'Eine Frau h\xc3\xa4lt in einer K\xc3\xbcche eine Sch\xc3\xbcssel .'
# -9.262185 b'Eine Frau h\xc3\xa4lt eine Sch\xc3\xbcssel in der K\xc3\xbcche auf einer K\xc3\xbcche .'
# Original sentence:
# Man sitting using tool at a table in his home .
# Translated score and sentence:
# -6.372499 b'Ein Mann sitzt in einem Stuhl an einem Tisch .'
# -11.505674 b'Ein Mann sitzt in einem Stuhl an einem Tisch und arbeitet mit dem Computer .'
# -11.799525 b'Ein Mann sitzt an einem Tisch auf einem Stuhl und schneidet den Bildschirm .'
# -12.881453 b'Ein Mann sitzt in einem Stuhl an einem Tisch und arbeitet mit seinem Computer .'
# Original sentence:
# Three people sit in a cave .
# Translated score and sentence:
# -3.7232769 b'Drei Personen sitzen in einer Kunstgalerie .'
# -3.948618 b'Drei Leute sitzen in einer Kunstgalerie .'
# -3.9914663 b'Drei Menschen sitzen in einer Kunstgalerie .'
# -4.1132812 b'Drei Personen sitzen in einer Badewanne .'
# Original sentence:
# A girl in a jean dress is walking along a raised balance beam .
# Translated score and sentence:
# -6.655631 b'Ein M\xc3\xa4dchen in einem rosa Kleid geht die Treppen herunter .'
# -6.9265933 b'Ein M\xc3\xa4dchen in einem rosa Kleid geht die Treppen hinunter .'
# -8.261998 b'Ein M\xc3\xa4dchen in einem rosa Kleid geht auf eine Leiter .'
# -16.031088 b'Ein M\xc3\xa4dchen in einem rosa Kleid geht auf eine Leiter und versucht einen Schuh zu .'
# Original sentence:
# A blond holding hands with a guy in the sand .
# Translated score and sentence:
# -8.927641 b'Ein asiatisch aussehendes h\xc3\xa4lt h\xc3\xa4lt einen Mann im Sand .'
# -8.94833 b'Ein asiatisch aussehender h\xc3\xa4lt h\xc3\xa4lt einen Mann im Sand .'
# -9.211441 b'Ein sehr blondes h\xc3\xa4lt h\xc3\xa4lt einen Mann im Sand .'
# -9.45311 b'Ein asiatisch aussehende h\xc3\xa4lt h\xc3\xa4lt einen Mann im Sand .'
# Original sentence:
# A woman in a gray sweater and black baseball cap is standing in line at a shop .
# Translated score and sentence:
# -11.910363 b'Eine Frau in einem grauen T-Shirt und blauen Shorts steht in der N\xc3\xa4he eines Gesch\xc3\xa4fts .'
# -13.47212 b'Eine Frau in einem grauen T-Shirt und mit schwarzen Schuhen steht in der N\xc3\xa4he eines Gesch\xc3\xa4fts .'
# -14.103345 b'Eine Frau in einem grauen T-Shirt und mit einer schwarzen Kopfbedeckung steht in der N\xc3\xa4he eines Gesch\xc3\xa4fts .'
# -14.7520485 b'Eine Frau in einem grauen T-Shirt und mit einer schwarzen Kopfbedeckung steht in der N\xc3\xa4he eines Ladens .'
# Original sentence:
# The person in the striped shirt is mountain climbing .
# Translated score and sentence:
# -6.9884486 b'Eine Person in einem T-Shirt macht einen Berg .'
# -7.3441215 b'Eine Person in einem T-Shirt klettert den Berg hoch .'
# -7.40074 b'Eine Person in einem T-Shirt klettert einen Berg hoch .'
# -7.859996 b'Eine Person in einem Tr\xc3\xa4gerhemd klettert den Berg hoch .'
# Original sentence:
# Two men pretend to be <unk> while women look on .
# Translated score and sentence:
# -8.013707 b'Zwei M\xc3\xa4nner versuchen , w\xc3\xa4hrend eine \xc3\xa4ltere Frau zuschaut .'
# -8.014628 b'Zwei M\xc3\xa4nner versuchen , w\xc3\xa4hrend eine \xc3\xa4ltere Frau zusieht .'
# -8.028272 b'Zwei M\xc3\xa4nner schauen zu , wie eine \xc3\xa4ltere Frau zuschaut .'
# -8.665325 b'Zwei M\xc3\xa4nner schauen zu , wie eine \xc3\xa4ltere Frau zusieht .'
# Original sentence:
# People standing outside of a building .
# Translated score and sentence:
# -0.9254015 b'Leute stehen vor einem Geb\xc3\xa4ude .'
# -2.045237 b'Menschen stehen vor einem Geb\xc3\xa4ude .'
# -2.7094443 b'Personen stehen vor einem Geb\xc3\xa4ude .'
# -3.1265142 b'Leute stehen au\xc3\x9ferhalb eines Geb\xc3\xa4udes .'
# Original sentence:
# A teenager plays her trumpet on the field at a game .
# Translated score and sentence:
# -9.487979 b'Ein Jugendlicher spielt auf dem Publikum auf einem Konzert .'
# -10.005076 b'Ein Gitarrist spielt auf dem Feld auf einem Konzert .'
# -10.198429 b'Ein Jugendlicher spielt auf dem Feld auf einem Konzert .'
# -10.961565 b'Ein Jugendlicher spielt auf dem Feld auf einem Feld .'
# Original sentence:
# A woman does a somersault on a trampoline on the beach .
# Translated score and sentence:
# -5.2241235 b'Eine Frau macht einen Sprung auf einem Trampolin im Freien .'
# -5.441429 b'Eine Frau macht einen Handstand auf einem Trampolin im Freien .'
# -5.771402 b'Eine Frau macht einen Sprung auf einem Strand im Freien .'
# -7.5697894 b'Eine Frau springt auf einem Kai im Freien auf einem Trampolin .'
# Original sentence:
# A man is standing by a group of video games in a bar .
# Translated score and sentence:
# -6.92136 b'Ein Mann steht vor einer Gruppe in einer Bar .'
# -6.9972625 b'Ein Mann steht in einer Gruppe von einer Frau .'
# -10.20948 b'Ein Mann steht vor einer Gruppe von einer Frau in einer Bar .'
# -10.591679 b'Ein Mann steht vor einer Gruppe von einer Frau in einer Werkstatt .'
# Original sentence:
# A woman uses a drill while another man takes her picture .
# Translated score and sentence:
# -9.992388 b'Eine Frau f\xc3\xbchrt ein Mikrofon , w\xc3\xa4hrend ein anderer Mann fotografiert .'
# -13.188674 b'Eine Frau f\xc3\xbchrt einen anderen Mann auf , w\xc3\xa4hrend ein Mann fotografiert .'
# -15.643009 b'Eine Frau f\xc3\xbchrt ein Mikrofon , w\xc3\xa4hrend ein anderer Mann auf dem Bild zeigt .'
# -15.720376 b'Eine Frau f\xc3\xbchrt ein Mikrofon , w\xc3\xa4hrend ein anderer Mann auf ihr zeigt .'
# Original sentence:
# A woman in a pink sweater and an apron , cleaning a table with a sponge .
# Translated score and sentence:
# -10.295689 b'Eine Frau in einem rosa Pullover und mit Brille benutzt einen Tisch mit Essen .'
# -10.891732 b'Eine Frau in einem rosa Pullover und mit Brille benutzt einen Tisch mit einem Messer .'
# -11.629829 b'Eine Frau in einem rosa Pullover und mit Brille benutzt einen Tisch mit Essen an .'
# -12.935095 b'Eine Frau in einem rosa Pullover und mit Brille benutzt einen Tisch mit Essen auf einem Tisch .'
# Original sentence:
# A man cutting branches of trees .
# Translated score and sentence:
# -9.292713 b'Ein Mann schneidet reinigt die B\xc3\xa4ume .'
# -9.853884 b'Ein Mann schneidet reinigt die K\xc3\xbcste .'
# -10.323516 b'Ein Mann schneidet reinigt die Steine .'
# -10.707152 b'Ein Mann schneidet fegt \xc3\xbcber den Schnee .'
# Original sentence:
# Group of Asian boys wait for meat to cook over barbecue .
# Translated score and sentence:
# -13.409066 b'Eine Gruppe junger Frauen wartet darauf , dass sie auf den Wettkampf vorbereitet .'
# -14.20204 b'Eine Gruppe junger Frauen wartet darauf , dass sie auf einem Grill warten .'
# -15.140177 b'Eine Gruppe von Frauen bereitet sich darauf vor , um ihr Ziel zu machen .'
# -15.598944 b'Eine Gruppe von Frauen bereitet sich darauf vor , um ihr Ziel zu verkaufen .'
# Original sentence:
# Women , wearing traditional clothing , are <unk> native life .
# Translated score and sentence:
# -14.064908 b'Eine Frau in traditioneller Kleidung , die wie Kleidung verkleidet .'
# -14.224869 b'Eine Frau in traditioneller Kleidung , die wie Kleidung verkleidet ist .'
# -14.37105 b'Eine Frau in traditioneller Kleidung , die wie Kleidung tragen .'
# -14.716899 b'Eine Frau in traditioneller Kleidung , die wie Kleidung verkleidet sind .'
# Original sentence:
# One man holds another man &apos;s head down and prepares to punch him in the face .
# Translated score and sentence:
# -15.846863 b'Ein Mann h\xc3\xa4lt einen Baseballschl\xc3\xa4ger , w\xc3\xa4hrend er sich der Hand in der Hand h\xc3\xa4lt .'
# -15.961581 b'Ein Mann h\xc3\xa4lt einen Basketball , w\xc3\xa4hrend er sich der Hand in der Hand h\xc3\xa4lt .'
# -16.577122 b'Ein Mann h\xc3\xa4lt einen Baseballschl\xc3\xa4ger , w\xc3\xa4hrend er sich der Hand in der Hand greift .'
# -16.72111 b'Ein Mann h\xc3\xa4lt einen Basketball , w\xc3\xa4hrend er sich der Hand in der Hand greift .'
# Original sentence:
# Six people ride mountain bikes through a jungle environment .
# Translated score and sentence:
# -9.653328 b'Sechs Personen fahren mit dem Fahrrad durch ein Waldgebiet .'
# -11.821972 b'Sechs Personen fahren mit dem Fahrrad auf einem Weg durch Stromschnellen .'
# -12.2208395 b'Sechs Personen fahren mit dem Fahrrad auf einem Weg durch die Luft .'
# -12.899532 b'Sechs Personen fahren mit einem Gel\xc3\xa4ndefahrzeug auf dem Weg durch die Luft .'
# Original sentence:
# 2 blond girls are sitting on a ledge in a crowded plaza .
# Translated score and sentence:
# -9.246177 b'Zwei junge M\xc3\xa4dchen sitzen auf einem B\xc3\xbcrgersteig in einem gesch\xc3\xa4ftigen Bereich .'
# -9.318744 b'Zwei junge M\xc3\xa4dchen sitzen auf einem B\xc3\xbcrgersteig in einem \xc3\xb6ffentlichen Bereich .'
# -9.361832 b'Zwei junge M\xc3\xa4dchen sitzen auf einem B\xc3\xbcrgersteig in einem belebten Bereich .'
# -9.38239 b'Zwei junge M\xc3\xa4dchen sitzen auf einem B\xc3\xbcrgersteig in einem \xc3\xbcberf\xc3\xbcllten Bereich .'
# Original sentence:
# A child is splashing in the water
# Translated score and sentence:
# -2.0506 b'Ein Kind planscht im Wasser .'
# -2.137957 b'Ein Kind schwimmt im Wasser .'
# -2.5911865 b'Ein Kind befindet sich im Wasser .'
# -4.237449 b'Ein Kind macht im Wasser .'
# Original sentence:
# Three people sit at a picnic table outside of a building painted like a union jack .
# Translated score and sentence:
# -17.028965 b'Drei Personen sitzen an einem Picknicktisch vor einem Zelt , das an einem bew\xc3\xb6lkten Tag steht .'
# -18.813272 b'Drei Personen sitzen an einem Picknicktisch vor einem Zelt , das an einem bew\xc3\xb6lkten Tag angebracht ist .'
# -19.000801 b'Drei Personen sitzen an einem Picknicktisch vor einem Zelt , das an einem bew\xc3\xb6lkten Tag angebracht .'
# -21.36103 b'Drei Personen sitzen an einem Picknicktisch vor einem Zelt , das an einem bew\xc3\xb6lkten Tag angebracht wird .'
# Original sentence:
# 3 boys are standing on a pier in their bathing suits .
# Translated score and sentence:
# -6.7807193 b'Zwei Jungen stehen auf einem Trampolin im Sand .'
# -7.146933 b'Zwei Jungen stehen auf einem Karussell im Sand .'
# -9.435339 b'Zwei Jungen stehen auf einem Trampolin in einem Park .'
# -9.572444 b'Zwei Jungen stehen auf einem Trampolin in einem Gew\xc3\xa4sser .'
# Original sentence:
# An employee is handing a woman a bag while she is browsing through fish on ice at a street market .
# Translated score and sentence:
# -16.850561 b'Ein Bild einer Frau zeigt auf einer belebten Stra\xc3\x9fe in der Hand auf einen Markt .'
# -17.243792 b'Ein Bild einer Frau zeigt auf einer belebten Stra\xc3\x9fe in der Hand auf einem Markt .'
# -18.342323 b'Ein \xc3\xa4lterer einer Frau zeigt auf einer belebten Stra\xc3\x9fe in der Hand ein Gericht .'
# -18.447258 b'Ein \xc3\xa4lterer einer Frau zeigt auf einer belebten Stra\xc3\x9fe in der Hand ein Produkt .'
# Original sentence:
# A pretty woman plays a <unk> .
# Translated score and sentence:
# -5.3237047 b'Eine junge Frau spielt Schlagzeug .'
# -5.653532 b'Eine junge Frau spielt zusammen .'
# -7.6112823 b'Eine junge Frau spielt auf einer Trommel .'
# -7.6820374 b'Eine junge Frau spielt auf einer Wiese .'
# Original sentence:
# Outside a building , a uniformed security guard looks at the camera from behind a fence .
# Translated score and sentence:
# -17.126204 b'Ein Mann mit einem Schild in der Hand steht hinter dem Zaun und h\xc3\xa4lt einen Korb .'
# -17.162773 b'Ein Mann mit einem Schild in der Hand steht hinter dem Zaun und h\xc3\xa4lt einen Zaun .'
# -17.296562 b'Ein Mann mit einem Schild in der Hand steht hinter einem Zaun und h\xc3\xa4lt die Hand .'
# -21.459257 b'Ein Mann mit einem Schild in der Hand steht hinter einem Zaun , das die Kamera hinter sich .'
# Original sentence:
# The young lady is looking at the pizza .
# Translated score and sentence:
# -5.840556 b'Die junge Frau schaut auf die Aussicht .'
# -5.8562593 b'Die junge Frau schaut auf die Kamera .'
# -6.4078884 b'Eine junge Frau schaut sich die Aussicht an .'
# -6.8657503 b'Die junge Frau schaut auf die Berge .'
# Original sentence:
# A shirtless man in shorts is fishing while standing on some rocks .
# Translated score and sentence:
# -9.826259 b'Ein Mann mit freiem Oberk\xc3\xb6rper und Shorts steht auf Felsen und schaut auf die Kamera .'
# -10.423609 b'Ein Mann in kurzer Hose und Shorts steht auf Felsen und schaut auf die Kamera .'
# -11.570583 b'Ein Mann mit freiem Oberk\xc3\xb6rper und Shorts steht auf Felsen und schaut sich die Kamera .'
# -11.903652 b'Ein Mann mit freiem Oberk\xc3\xb6rper und Shorts steht auf Felsen und schaut sich die Kamera an .'
# Original sentence:
# A girl wearing a life vest floats in water .
# Translated score and sentence:
# -10.8232565 b'Ein M\xc3\xa4dchen in einem Kleid , das durch Wasser Wasser .'
# -11.12569 b'Ein M\xc3\xa4dchen in einem Kost\xc3\xbcm , das durch Wasser Wasser .'
# -11.306933 b'Ein M\xc3\xa4dchen in einem Kleid , das durch das Wasser schwimmt .'
# -11.592319 b'Ein M\xc3\xa4dchen in einem Kost\xc3\xbcm , das durch das Wasser schwimmt .'
# Original sentence:
# A man in uniform and a man in a blue shirt are standing in front of a truck .
# Translated score and sentence:
# -7.243679 b'Ein Mann in einem Anzug und ein Mann in einem blauen Oberteil stehen vor einem Geb\xc3\xa4ude .'
# -7.7327547 b'Ein Mann in einem Anzug und ein Mann in einem blauen T-Shirt stehen vor einem Geb\xc3\xa4ude .'
# -7.7401414 b'Ein Mann in einem Anzug und ein Mann in einem blauen Hemd stehen vor einem Geb\xc3\xa4ude .'
# -8.285968 b'Ein Mann in einem T-Shirt und ein Mann in einem blauen Oberteil stehen vor einem Geb\xc3\xa4ude .'
# Original sentence:
# People sit inside a train .
# Translated score and sentence:
# -0.5555451 b'Leute sitzen in einem Zug .'
# -2.1333294 b'Menschen sitzen in einem Zug .'
# -3.0267744 b'Personen sitzen in einem Zug .'
# -3.9309046 b'Leute sitzen auf einem Zug .'
# Original sentence:
# A kid swings with his feet up in the air in a forest .
# Translated score and sentence:
# -8.608009 b'Ein Kind schaukelt mit seinem Armen in der Luft in einem Wald .'
# -8.700627 b'Ein Kind schaukelt mit seinem Armen in der Luft im Wald .'
# -9.055819 b'Ein Kind schaukelt mit seinem Armen in einem Wald in den Wald .'
# -9.07363 b'Ein Kind schaukelt mit seinem Armen in den Bergen in einem Wald .'
# Original sentence:
# A man in a red shirt entering an establishment .
# Translated score and sentence:
# -5.3326936 b'Ein Mann in einem roten Oberteil spricht in ein Mikrofon .'
# -5.903578 b'Ein Mann in einem roten Hemd spricht in ein Mikrofon .'
# -6.293084 b'Ein Mann in einem roten Oberteil spricht in ein Mikroskop .'
# -6.320499 b'Ein Mann in einem roten T-Shirt spricht in ein Mikrofon .'
# Original sentence:
# Two men wearing swim trunks jump in the air at a moderately populated beach .
# Translated score and sentence:
# -9.108443 b'Zwei M\xc3\xa4nner in Schneeschuhen springen auf einem Felsen in die Luft .'
# -9.281305 b'Zwei M\xc3\xa4nner in Schneeschuhen springen auf einem Weg in die Luft .'
# -9.732709 b'Zwei M\xc3\xa4nner in Shorts springen auf einem Weg in die Luft .'
# -9.8929615 b'Zwei M\xc3\xa4nner in Shorts springen auf einem Felsen in die Luft .'
# Original sentence:
# A toddler is cooking with another person .
# Translated score and sentence:
# -7.16041 b'Ein Kleinkind macht etwas mit einem anderen .'
# -7.170047 b'Ein Kleinkind macht etwas mit einer anderen Frau .'
# -7.524491 b'Ein Kleinkind zeigt etwas mit einer anderen .'
# -7.724371 b'Ein Kleinkind zeigt etwas mit einer anderen Person .'
# Original sentence:
# A <unk> and two children outside their home doing yard work such as using a hoe on the grass and planting a tree .
# Translated score and sentence:
# -24.886993 b'Ein Footballteam und zwei Kinder befinden sich auf dem Boden und sehen sich mit einem Weihnachtsbaum im Freien auf dem Boden an .'
# -25.366776 b'Ein Footballteam und zwei Kinder befinden sich auf dem Boden und sehen sich mit einem Weihnachtsbaum im Freien auf dem Boden aus .'
# -26.191032 b'Ein Footballteam und zwei Kinder befinden sich auf dem Boden und sehen sich mit einem Weihnachtsbaum an , w\xc3\xa4hrend sie auf dem Boden spielen .'
# -26.556595 b'Ein Footballteam und zwei Kinder befinden sich auf dem Boden und sehen sich mit einem Weihnachtsbaum an , w\xc3\xa4hrend sie auf dem Boden liegt .'
# Original sentence:
# A man cooking food on the stove .
# Translated score and sentence:
# -3.819289 b'Ein Mann kocht Essen auf dem Herd .'
# -4.2709928 b'Ein Mann grillt Essen auf dem Herd .'
# -5.275363 b'Ein Mann kocht Essen auf dem Essen .'
# -5.529165 b'Ein Mann kocht Essen auf den Herd .'
# Original sentence:
# A man in jeans at the beach playing with a red ball .
# Translated score and sentence:
# -8.041389 b'Ein Mann in Jeans kniet auf dem Rasen und spielt mit einem wei\xc3\x9fen Ball .'
# -8.068283 b'Ein Mann in Jeans sitzt auf dem Rasen und spielt mit einem wei\xc3\x9fen Ball .'
# -8.48703 b'Ein Mann in Jeans kniet auf dem Rasen und spielt mit einem roten Ball .'
# -8.904853 b'Ein Mann in Jeans sitzt auf dem Rasen und spielt mit einem gr\xc3\xbcnen Ball .'
# Original sentence:
# People walking down sidewalk next to a line of stores .
# Translated score and sentence:
# -8.47716 b'Leute gehen auf einem B\xc3\xbcrgersteig neben einigen Gesch\xc3\xa4ften .'
# -8.540099 b'Menschen gehen auf einem B\xc3\xbcrgersteig neben einigen Gesch\xc3\xa4ften .'
# -11.121227 b'Leute gehen auf einem B\xc3\xbcrgersteig neben einer Reihe von Gesch\xc3\xa4ften .'
# -11.262381 b'Menschen gehen auf einem B\xc3\xbcrgersteig neben einer Reihe von Gesch\xc3\xa4ften .'
# Original sentence:
# A wakeboarder performs a flip while being towed at high speed .
# Translated score and sentence:
# -20.938456 b'Ein Tourist f\xc3\xbchrt einen Stunt , w\xc3\xa4hrend er sich auf dem Weg teilnehmen .'
# -21.122038 b'Ein Tourist f\xc3\xbchrt einen Stunt , w\xc3\xa4hrend er sich auf dem Weg f\xc3\xbchrt .'
# -21.471367 b'Ein Tourist f\xc3\xbchrt einen Stunt , w\xc3\xa4hrend er sich auf dem Weg vorbereitet .'
# -21.855946 b'Ein Tourist f\xc3\xbchrt einen Stunt , w\xc3\xa4hrend er sich auf dem Weg f\xc3\xbchren .'
# Original sentence:
# A large group of people fill a street .
# Translated score and sentence:
# -4.0399528 b'Eine gro\xc3\x9fe Gruppe von Menschen \xc3\xbcberquert eine Stra\xc3\x9fe .'
# -4.408906 b'Eine gro\xc3\x9fe Gruppe von Menschen f\xc3\xa4hrt auf einer Stra\xc3\x9fe .'
# -4.7625976 b'Eine gro\xc3\x9fe Gruppe von Menschen kommt auf einer Stra\xc3\x9fe .'
# -5.9120374 b'Eine gro\xc3\x9fe Gruppe von Menschen f\xc3\xa4hrt eine Stra\xc3\x9fe entlang .'
# Original sentence:
# A man on a tag line going into the water .
# Translated score and sentence:
# -4.778913 b'Ein Mann auf einem Flo\xc3\x9f springt ins Wasser .'
# -5.597398 b'Ein Mann auf einem Surfboard springt ins Wasser .'
# -5.9146943 b'Ein Mann auf einem Wakeboard springt ins Wasser .'
# -6.4407616 b'Ein Mann auf einem Flo\xc3\x9f springt durch die Luft .'
# Original sentence:
# A woman in jeans walks by a bus with an ad depicting a woman peering over her sunglasses .
# Translated score and sentence:
# -12.24595 b'Eine Frau in Jeans geht mit einer Frau in der Hand und geht mit ihrem Handy \xc3\xbcber ihr Handy .'
# -13.003142 b'Eine Frau in Jeans geht mit einer Frau in der Hand und geht mit ihrem Handy \xc3\xbcber der Stra\xc3\x9fe .'
# -13.065503 b'Eine Frau in Jeans geht mit einer Frau in der Hand und geht mit ihrem Handy \xc3\xbcber eine Frau .'
# -13.39758 b'Eine Frau in Jeans geht mit einer Frau in der Hand und geht mit ihrem Handy \xc3\xbcber eine Stra\xc3\x9fe .'
# Original sentence:
# A man in a pink shirt is sitting in the grass and a ball is in the air .
# Translated score and sentence:
# -9.553492 b'Ein Mann in einem gestreiften Oberteil sitzt auf einem gr\xc3\xbcnen und h\xc3\xa4lt im Wasser .'
# -11.22943 b'Ein Mann in einem gestreiften Oberteil sitzt auf einem Surfboard und h\xc3\xa4lt die Luft .'
# -11.347293 b'Ein Mann in einem gestreiften Oberteil sitzt auf einem Surfboard und h\xc3\xa4lt einen gr\xc3\xbcnen Ball .'
# -11.613288 b'Ein Mann in einem gestreiften Oberteil sitzt auf einem Surfboard und h\xc3\xa4lt einen Volleyball in der Luft .'
# Original sentence:
# A car parked at the beach .
# Translated score and sentence:
# -2.7164686 b'Ein Auto steht am Strand .'
# -3.8138294 b'Ein Auto steht am Ufer .'
# -4.166155 b'Ein Hund steht am Strand .'
# -4.290242 b'Ein Auto ist am Strand .'
# Original sentence:
# Two men wearing black in a city
# Translated score and sentence:
# -5.2814393 b'Zwei M\xc3\xa4nner in schwarzer Kleidung in einer Stadt .'
# -5.66731 b'Zwei M\xc3\xa4nner in schwarzen Jacken fahren in einer Stadt .'
# -6.768201 b'Zwei M\xc3\xa4nner in schwarzer Kleidung fahren in einem Stadt .'
# -6.7726207 b'Zwei M\xc3\xa4nner in schwarzen Jacken fahren in einem Stadt .'
# Original sentence:
# The man in the yellow pants is raising his arms .
# Translated score and sentence:
# -7.3875813 b'Ein Mann in einem gr\xc3\xbcnen Oberteil hebt seine Arme .'
# -7.942577 b'Ein Mann in einem gr\xc3\xbcnen Oberteil springt mit den Armen .'
# -8.0794 b'Ein Mann in einem gr\xc3\xbcnen Oberteil hebt seine Arme hoch .'
# -9.261045 b'Ein Mann in einem gr\xc3\xbcnen Oberteil hebt seine Arme in die Luft .'
# Original sentence:
# Two men wearing hats and using walking sticks are walking near a body of water during <unk> .
# Translated score and sentence:
# -8.942967 b'Zwei M\xc3\xa4nner mit H\xc3\xbcten und H\xc3\xbcten gehen durch Wasser neben einem Gew\xc3\xa4sser .'
# -10.555373 b'Zwei M\xc3\xa4nner mit H\xc3\xbcten und H\xc3\xbcten gehen neben Wasser in einem Gew\xc3\xa4sser .'
# -11.787794 b'Zwei M\xc3\xa4nner mit H\xc3\xbcten und H\xc3\xbcten gehen in der N\xc3\xa4he von einem Gew\xc3\xa4sser .'
# -14.985598 b'Zwei M\xc3\xa4nner mit H\xc3\xbcten und H\xc3\xbcten gehen in der N\xc3\xa4he von einem Gew\xc3\xa4sser und Wasser \xc3\xbcber Wasser .'
# Original sentence:
# A cheerleading team doing a routine on chairs .
# Translated score and sentence:
# -5.902438 b'Eine Band macht auf der B\xc3\xbchne Musik .'
# -6.222818 b'Eine Band macht auf einer B\xc3\xbchne Musik .'
# -6.5068936 b'Eine Band macht auf der B\xc3\xbchne auf .'
# -7.3606043 b'Eine Band macht eine Auff\xc3\xbchrung auf dem B\xc3\xbcrgersteig .'
# Original sentence:
# A boy is playing checkers with an adult shown off-screen while a girl looks on .
# Translated score and sentence:
# -7.252237 b'Ein Junge spielt mit einem M\xc3\xa4dchen , w\xc3\xa4hrend ein anderes M\xc3\xa4dchen zusieht .'
# -7.3876624 b'Ein Junge spielt mit einem \xc3\xa4lteren M\xc3\xa4dchen , w\xc3\xa4hrend ein anderes M\xc3\xa4dchen zusieht .'
# -7.460432 b'Ein Junge spielt mit einem \xc3\xa4lteren M\xc3\xa4dchen , w\xc3\xa4hrend ein anderes M\xc3\xa4dchen zuschaut .'
# -7.53444 b'Ein Junge spielt mit einem \xc3\xa4lteren M\xc3\xa4dchen , w\xc3\xa4hrend ein M\xc3\xa4dchen zuschaut .'
# Original sentence:
# A crowd of people out for some fun in public park .
# Translated score and sentence:
# -6.830768 b'Eine Menschenmenge versammelt sich in einem \xc3\xb6ffentlichen Park .'
# -7.8450713 b'Eine Menschenmenge wartet in einem \xc3\xb6ffentlichen Park .'
# -8.045089 b'Eine Menschenmenge versammelt sich drau\xc3\x9fen in einem \xc3\xb6ffentlichen Park .'
# -12.206875 b'Eine Menschenmenge versammelt sich in einem \xc3\xb6ffentlichen Park oder Springbrunnen .'
# Original sentence:
# A man sits on a bench holding his dog and looking at the water .
# Translated score and sentence:
# -7.504711 b'Ein Mann sitzt auf einer Bank und h\xc3\xa4lt seine Wasser aus dem Wasser .'
# -10.106122 b'Ein Mann sitzt auf einer Bank und h\xc3\xa4lt ein Baby auf dem Wasser und schaut auf das Wasser .'
# -10.183 b'Ein Mann sitzt auf einer Bank und h\xc3\xa4lt ein Baby auf dem Wasser und blickt auf das Wasser .'
# -11.026931 b'Ein Mann sitzt auf einer Bank und h\xc3\xa4lt ein Baby auf dem Wasser und blickt \xc3\xbcber das Wasser .'
# Original sentence:
# A boy and his younger brother playing together at the playground .
# Translated score and sentence:
# -5.907562 b'Ein Junge und sein Sohn sitzen zusammen auf dem Spielplatz .'
# -6.568227 b'Ein Junge und sein Sohn liegen zusammen auf dem Spielplatz .'
# -6.9124 b'Ein Junge und sein Sohn sitzen zusammen auf einem Spielplatz .'
# -8.047862 b'Ein Junge und sein Sohn sitzen zusammen auf dem Beton .'
# Original sentence:
# A woman in blue looks in a black leather bag while sitting on a bench during a sunny afternoon while people and <unk> passed behind her .
# Translated score and sentence:
# -28.633059 b'Eine blau gekleidete Frau in einem braunen Kleid steht auf einer B\xc3\xbchne , w\xc3\xa4hrend ein Mann im Hintergrund auf einer Bank sitzt und auf dem Boden sitzen .'
# -28.762072 b'Eine blau gekleidete Frau in einem braunen Kleid steht auf einer Bank , w\xc3\xa4hrend ein Mann im Hintergrund auf einer Bank sitzt und auf dem Boden sitzen .'
# -32.443745 b'Eine blau gekleidete Frau in einem braunen Kleid steht auf einer B\xc3\xbchne , w\xc3\xa4hrend ein Mann im Hintergrund auf einer Bank sitzt und auf der anderen Seite etwas .'
# -32.960022 b'Eine blau gekleidete Frau in einem braunen Kleid steht auf einer B\xc3\xbchne , w\xc3\xa4hrend ein Mann im Hintergrund auf einer Bank sitzt und auf der anderen Seite etwas sitzen .'
# Original sentence:
# The brown dog is standing on the sandy beach .
# Translated score and sentence:
# -2.8973389 b'Der braune Hund steht am Strand .'
# -3.632281 b'Der braune Hund steht im Schnee .'
# -3.7926264 b'Ein brauner Hund steht am Strand .'
# -4.7264266 b'Der braune Hund steht auf dem Sand .'
# Original sentence:
# A woman is sitting with a basket of cloth , surrounded by cloth .
# Translated score and sentence:
# -12.953444 b'Eine Frau sitzt mit einem Eimer voller Eimer um einen Tisch .'
# -13.171233 b'Eine Frau sitzt mit einem Eimer voller Waren um einen Tisch .'
# -13.247624 b'Eine Frau sitzt mit einem Eimer voller Eimer um einen Stoff .'
# -14.528065 b'Eine Frau sitzt mit einem Eimer voller Eimer um einen Stoff herum .'
# Original sentence:
# A man is grilling out in his backyard .
# Translated score and sentence:
# -4.251449 b'Ein Mann grillt im Garten .'
# -5.18453 b'Ein Mann grillt drau\xc3\x9fen im Garten .'
# -7.848887 b'Ein Mann grillt drau\xc3\x9fen auf seinem .'
# -7.9639897 b'Ein Mann ruht sich im Hinterhof an .'
# Original sentence:
# A woman sings in a club with a guitarist behind her .
# Translated score and sentence:
# -6.4118576 b'Eine Frau singt in einem Club mit einer Gitarre .'
# -7.2961893 b'Eine Frau singt mit einem Mann im Freien auf einem Stuhl .'
# -7.5627685 b'Eine Frau singt in einem Club mit einem anderen Mann .'
# -10.824254 b'Eine Frau singt mit einem Mann im Freien auf einem mit Stuhl .'
# Original sentence:
# Guitar player performs at a nightclub red guitar .
# Translated score and sentence:
# -9.374134 b'Ein S\xc3\xa4nger macht einen Trick auf der B\xc3\xbchne .'
# -9.912733 b'Ein S\xc3\xa4nger macht einen Trick auf einer B\xc3\xbchne .'
# -12.032813 b'Ein S\xc3\xa4nger macht einen Trick auf einem roten Gitarre .'
# -12.146436 b'Ein S\xc3\xa4nger macht einen Trick auf einem roten Stuhl .'
# Original sentence:
# A child sitting on a lawn chair looking up at the camera
# Translated score and sentence:
# -4.398308 b'Ein Kind sitzt auf einem Stuhl und schaut auf die Kamera .'
# -5.065022 b'Ein Kind sitzt auf einem Felsen und schaut auf die Kamera .'
# -5.0702024 b'Ein Kind sitzt auf dem Boden und schaut auf eine Kamera .'
# -5.196109 b'Ein Kind sitzt auf einem Stuhl und blickt auf die Kamera .'
# Original sentence:
# Two ladies and three men looking at the ocean .
# Translated score and sentence:
# -4.215583 b'Zwei Frauen und zwei Frauen schauen auf das Meer .'
# -4.8068156 b'Zwei Frauen und zwei Frauen gehen auf dem Meer .'
# -5.1077833 b'Zwei Frauen und zwei M\xc3\xa4nner schauen auf das Meer .'
# -5.904241 b'Zwei Frauen und zwei Frauen gehen auf den Felsen .'
# Original sentence:
# A female performer with a violin plays on a street while a woman with a blue guitar looks on .
# Translated score and sentence:
# -14.645291 b'Eine Dame mit Sonnenbrille spielt auf einer Stra\xc3\x9fe Gitarre , w\xc3\xa4hrend ein Kind mit einer Gitarre Gitarre .'
# -14.955971 b'Eine Dame mit Sonnenbrille spielt auf einer Stra\xc3\x9fe Gitarre , w\xc3\xa4hrend ein Kind mit einer Gitarre Gitarre spielt .'
# -15.878026 b'Eine Dame mit Sonnenbrille spielt auf einer Stra\xc3\x9fe Gitarre , w\xc3\xa4hrend eine andere Person in einem schwarzen Mantel zuschaut .'
# -16.015097 b'Eine Dame mit Sonnenbrille spielt auf einer Stra\xc3\x9fe Gitarre , w\xc3\xa4hrend eine andere Person in einer blauen Jacke sitzt .'
# Original sentence:
# A young girl swimming in a pool
# Translated score and sentence:
# -1.5781118 b'Ein junges M\xc3\xa4dchen schwimmt in einem Pool .'
# -2.460025 b'Ein kleines M\xc3\xa4dchen schwimmt in einem Pool .'
# -2.5399973 b'Ein junges M\xc3\xa4dchen schwimmt in einem Schwimmbecken .'
# -3.4437253 b'Ein kleines M\xc3\xa4dchen schwimmt in einem Schwimmbecken .'
# Original sentence:
# Several children are outdoors getting ready to play tug-of-war .
# Translated score and sentence:
# -8.561423 b'Mehrere Kinder sitzen vor einem Fu\xc3\x9fballspiel .'
# -9.290013 b'Mehrere Kinder sitzen vor einem Fu\xc3\x9fballspiel im Freien .'
# -10.524147 b'Mehrere Kinder sitzen vor einem Fu\xc3\x9fballspiel im Sand .'
# -11.397221 b'Mehrere Kinder spielen im Freien f\xc3\xbcr ein Spiel .'
# Original sentence:
# Three teenagers in a subway playing around .
# Translated score and sentence:
# -5.207162 b'Drei Teenager in einer U-Bahn .'
# -5.2847886 b'Drei Teenager auf einer B\xc3\xbchne .'
# -5.617794 b'Drei Teenager in einer Menschenmenge .'
# -5.8167257 b'Drei Teenager auf einer Party .'
# Original sentence:
# A brown dog walks in the grass with its tongue hanging out .
# Translated score and sentence:
# -6.012504 b'Ein brauner Hund l\xc3\xa4uft im Gras mit seiner Zunge .'
# -7.108551 b'Ein brauner Hund l\xc3\xa4uft mit seinem Maul durch das Gras .'
# -7.188147 b'Ein brauner Hund l\xc3\xa4uft im Gras mit seinem Maul .'
# -7.928744 b'Ein brauner Hund l\xc3\xa4uft mit seinem Maul durch die Gras .'
# Original sentence:
# People sitting in the grass outside a building , taking a break .
# Translated score and sentence:
# -6.859892 b'Leute sitzen im Gras und machen ein Foto .'
# -9.598959 b'Leute sitzen im Gras und machen ein Foto von einer Veranstaltung .'
# -9.856063 b'Leute sitzen im Gras und machen ein Foto von einer Kirche .'
# -12.285313 b'Leute sitzen im Gras und machen ein Foto von sich in einem Geb\xc3\xa4ude .'
# Original sentence:
# Shirtless guy staring off in the distance while three woman are walking past a crowd sitting outside a cafe .
# Translated score and sentence:
# -16.633707 b'Ein Mann mit freiem Oberk\xc3\xb6rper wartet in die Kamera , w\xc3\xa4hrend andere Personen an der Stra\xc3\x9fenecke stehen .'
# -20.93019 b'Ein Mann mit freiem Oberk\xc3\xb6rper wartet in die Kamera , w\xc3\xa4hrend andere Personen in der N\xc3\xa4he stehen und unterhalten sich vor einer Menschenmenge .'
# -20.95156 b'Ein Mann mit freiem Oberk\xc3\xb6rper wartet in die Kamera , w\xc3\xa4hrend andere Personen in der N\xc3\xa4he stehen und unterhalten sich bei einer Menschenmenge .'
# -25.529371 b'Ein Mann mit freiem Oberk\xc3\xb6rper wartet in die Kamera , w\xc3\xa4hrend andere Personen in der N\xc3\xa4he stehen und unterhalten sich in der N\xc3\xa4he von einer Menschenmenge .'
# Original sentence:
# Two young boys putting fruit on the bike .
# Translated score and sentence:
# -6.0594454 b'Zwei kleine Jungen zeigen ihr Fahrrad .'
# -6.7402315 b'Zwei kleine Jungen machen ihr Fahrrad .'
# -8.051989 b'Zwei kleine Jungen zeigen ihr Fahrrad auf .'
# -8.687588 b'Zwei kleine Jungen machen ihr Fahrrad auf dem Fahrrad .'
# Original sentence:
# A man in a black t-shirt , cap and jeans is playing drums on an upside down yellow pail .
# Translated score and sentence:
# -12.258931 b'Ein Mann in einem schwarzen Oberteil und Jeans spielt auf seinem Rasen und tr\xc3\xa4gt einen schwarzen Hut .'
# -14.86555 b'Ein Mann in einem schwarzen Oberteil und Jeans spielt auf dem Rasen mit einem kleinen Jungen auf dem Boden .'
# -14.866149 b'Ein Mann in einem schwarzen Oberteil und Jeans spielt auf dem Rasen mit einem kleinen Jungen auf dem Rasen .'
# -15.974153 b'Ein Mann in einem schwarzen Oberteil und Jeans spielt auf dem Rasen mit einem kleinen Jungen in der Mitte .'
# Original sentence:
# A young female artists paints an image of a woman on a wall .
# Translated score and sentence:
# -7.429702 b'Eine junge Frau malt an einer Wand aus einer Wand .'
# -10.912083 b'Eine junge Frau malt an einer Wand , die auf einer Mauer malt .'
# -12.399571 b'Eine junge Frau malt an einer Wand , die eine Frau an einer Wand .'
# -12.79497 b'Eine junge Frau malt an einer Wand , die eine Frau an einer Wand ist .'
# Original sentence:
# Two female members of team USA performing a jump high-five surrounded by two other female members .
# Translated score and sentence:
# -20.339138 b'Zwei M\xc3\xa4nner k\xc3\xa4mpfen bei einem Wettkampf , zwei von ihnen tragen zwei Team .'
# -20.46692 b'Zwei M\xc3\xa4nner k\xc3\xa4mpfen bei einem Wettkampf , wobei zwei zwei von ihnen zusehen .'
# -21.226496 b'Zwei M\xc3\xa4nner k\xc3\xa4mpfen bei einem Wettkampf , zwei von ihnen tragen zwei anderen .'
# -22.215195 b'Zwei M\xc3\xa4nner k\xc3\xa4mpfen bei einem Wettkampf , zwei von ihnen tragen zwei anderen Flaggen .'
# Original sentence:
# A man stirring a pot of liquid in this kitchen .
# Translated score and sentence:
# -8.177445 b'Ein Mann unterh\xc3\xa4lt sich in einer K\xc3\xbcche in der K\xc3\xbcche .'
# -8.572126 b'Ein Mann unterh\xc3\xa4lt sich in einer K\xc3\xbcche in der Hand .'
# -11.362095 b'Ein Mann unterh\xc3\xa4lt sich in einer K\xc3\xbcche , um die Essen zu essen .'
# -13.157189 b'Ein Mann unterh\xc3\xa4lt sich in einer K\xc3\xbcche , um die Essen zu kaufen .'
# Original sentence:
# The boy is wakeboarding on the lake .
# Translated score and sentence:
# -5.0418134 b'Der Junge macht auf einem See .'
# -5.2148995 b'Ein Junge macht auf dem See .'
# -5.2606325 b'Ein Junge macht auf einem See .'
# -5.6666093 b'Der Junge macht auf dem See .'
# Original sentence:
# A man is working a hotdog stand .
# Translated score and sentence:
# -3.9940615 b'Ein Mann arbeitet an einem Tisch .'
# -4.799223 b'Ein Mann arbeitet an einem Obststand .'
# -5.160351 b'Ein Mann isst einen Tisch .'
# -5.2087016 b'Ein Mann arbeitet an einem Rednerpult .'
# Original sentence:
# A large group of people of various ages and <unk> sit outside together .
# Translated score and sentence:
# -12.331226 b'Eine gro\xc3\x9fe Gruppe von Menschen versammelt sich drau\xc3\x9fen und sitzt zusammen .'
# -12.525315 b'Eine gro\xc3\x9fe Gruppe von Menschen versammelt sich drau\xc3\x9fen und sitzen zusammen .'
# -12.539012 b'Eine gro\xc3\x9fe Gruppe von Menschen versammelt sich drau\xc3\x9fen und arbeitet zusammen .'
# -13.198738 b'Eine gro\xc3\x9fe Gruppe von Menschen versammelt sich drau\xc3\x9fen und sitzt zusammen im Freien .'
# Original sentence:
# A blond-haired woman is pouring drinks at a bar .
# Translated score and sentence:
# -8.156261 b'Eine blonde Frau schneidet etwas in einer Bar .'
# -8.273301 b'Eine blonde Frau schneidet gl\xc3\xbccklich in einer Bar .'
# -9.015278 b'Eine blonde Frau schneidet in einer Bar etwas aus .'
# -9.18113 b'Eine blonde Frau schneidet in einer K\xc3\xbcche etwas aus .'
# Original sentence:
# A small child wearing a blue and white t-shirt happily holding a yellow plastic alligator .
# Translated score and sentence:
# -9.773244 b'Ein kleines Kind in einem blauen T-Shirt und blauen Shorts h\xc3\xa4lt einen gelben Ballon in der Hand .'
# -10.609087 b'Ein kleines Kind in einem blauen T-Shirt und blauen Shorts h\xc3\xa4lt einen gelben Gegenstand .'
# -10.61174 b'Ein kleines Kind in einem blauen T-Shirt und gelben Shorts h\xc3\xa4lt einen gelben Ballon in der Hand .'
# -10.796553 b'Ein kleines Kind in einem blauen T-Shirt und blauen Shorts h\xc3\xa4lt einen gelben Gegenstand in der Hand .'
# Original sentence:
# A woman with pink hair dressed in black talks to a man .
# Translated score and sentence:
# -9.718901 b'Eine Frau mit schwarzen Haaren , die eine Frau tr\xc3\xa4gt , spricht mit einem Mann .'
# -10.35097 b'Eine Frau mit schwarzen Haaren , die ein schwarzes Kleid tr\xc3\xa4gt , spricht mit einem Mann .'
# -10.707184 b'Eine Frau mit schwarzen Haaren , die ein schwarzes Kleid tr\xc3\xa4gt , spricht zu einem Mann .'
# -11.478038 b'Eine Frau mit schwarzen Haaren , die in einem schwarzen Rock spricht , spricht zu einem Mann .'
# Original sentence:
# The man in a Japanese cooking suit is preparing a meal for two people .
# Translated score and sentence:
# -9.896216 b'Ein Mann im Anzug bereitet sich f\xc3\xbcr eine Menschenmenge vor einer Veranstaltung aus .'
# -10.061877 b'Ein Mann im Anzug bereitet sich f\xc3\xbcr eine Gruppe von Menschen vor .'
# -11.103037 b'Ein Mann im Anzug bereitet sich f\xc3\xbcr eine Menschenmenge vor einer Menge aus .'
# -14.741197 b'Ein Mann im Anzug bereitet sich f\xc3\xbcr eine Gruppe von Menschen f\xc3\xbcr ein Foto .'
# Original sentence:
# A girl hops across the river , from rock to rock .
# Translated score and sentence:
# -12.795437 b'Ein M\xc3\xa4dchen , das am Meer \xc3\xbcber einen Fluss wirft .'
# -14.582586 b'Ein M\xc3\xa4dchen , das auf einem Felsen klettert , klettert \xc3\xbcber einen Felsen .'
# -15.193723 b'Ein M\xc3\xa4dchen , das auf einem Felsen klettert , klettert \xc3\xbcber den Felsen .'
# -15.531156 b'Ein M\xc3\xa4dchen , das auf einem Felsen klettert , klettert \xc3\xbcber das Berge .'
# Original sentence:
# A male worker with his tool box is kneeling next to two women .
# Translated score and sentence:
# -10.173417 b'Ein Arbeiter mit Schutzhelm ruht sich vor zwei M\xc3\xa4nnern aus .'
# -10.679982 b'Ein Arbeiter mit Schutzhelm auf dem Kopf steht neben zwei Frauen .'
# -10.784031 b'Ein Arbeiter mit Schutzhelm auf dem Kopf steht zusammen von zwei Frauen .'
# -10.869383 b'Ein Arbeiter mit Schutzhelm auf dem Kopf steht neben zwei M\xc3\xa4nnern .'
# Original sentence:
# An older man is opening his arms wide and looking perplexed .
# Translated score and sentence:
# -8.676535 b'Ein \xc3\xa4lterer Mann h\xc3\xa4lt die Arme hoch und blickt nach oben .'
# -9.109965 b'Ein \xc3\xa4lterer Mann h\xc3\xa4lt die Arme hoch und schaut nach oben .'
# -9.13253 b'Ein \xc3\xa4lterer Mann h\xc3\xa4lt die Arme hoch und blickt nach unten .'
# -9.56619 b'Ein \xc3\xa4lterer Mann h\xc3\xa4lt die Arme hoch und schaut nach unten .'
# Original sentence:
# A child in a white karate outfit practicing a move
# Translated score and sentence:
# -7.718871 b'Ein Kind in einem wei\xc3\x9fen Trikot macht einen Sprung .'
# -7.8740335 b'Ein Kind in einem wei\xc3\x9fen Trikot macht einen Fu\xc3\x9fball .'
# -8.036638 b'Ein Kind in einem wei\xc3\x9fen Trikot schie\xc3\x9ft einen Fu\xc3\x9fball .'
# -8.606204 b'Ein Kind in einem wei\xc3\x9fen Trikot schie\xc3\x9ft eine Fu\xc3\x9fball .'
# Original sentence:
# Three men in same colored vests are in the outdoors .
# Translated score and sentence:
# -5.0709567 b'Drei M\xc3\xa4nner in formeller Kleidung sitzen im Freien .'
# -5.876298 b'Drei M\xc3\xa4nner in dunklen Kleidung sitzen im Freien .'
# -6.1304708 b'Drei M\xc3\xa4nner in Milit\xc3\xa4runiformen sind im Freien im Freien .'
# -6.6004825 b'Drei M\xc3\xa4nner in formeller Kleidung im Freien .'
# Original sentence:
# A woman takes a picture of a baby wearing a pink hat while a man carries her .
# Translated score and sentence:
# -10.491866 b'Eine Frau macht ein Foto von einem M\xc3\xa4dchen , der ein Baby und eine Sonnenbrille tr\xc3\xa4gt .'
# -12.467064 b'Eine Frau macht ein Foto von einem M\xc3\xa4dchen , der ein Baby tr\xc3\xa4gt und eine Sonnenbrille h\xc3\xa4lt .'
# -15.512177 b'Eine Frau macht ein Foto von einem M\xc3\xa4dchen , der ein Baby und eine Sonnenbrille tr\xc3\xa4gt , macht ein Foto .'
# -19.921638 b'Eine Frau macht ein Foto von einem M\xc3\xa4dchen , der ein Baby und eine Sonnenbrille tr\xc3\xa4gt , macht ein Foto von einem M\xc3\xa4dchen .'
# Original sentence:
# A group of mostly asian children sitting at <unk> in blue chairs .
# Translated score and sentence:
# -9.980868 b'Eine Gruppe von jungen Erwachsenen sitzt in einem gr\xc3\xbcnen Raum .'
# -10.884275 b'Eine Gruppe von sechs Erwachsenen sitzt in einem gr\xc3\xbcnen Raum .'
# -11.199253 b'Eine Gruppe von jungen Erwachsenen sitzt in einem Kreis auf gr\xc3\xbcnen St\xc3\xbchlen .'
# -11.302386 b'Eine Gruppe von jungen Erwachsenen sitzt in einem gr\xc3\xbcnen Raum auf St\xc3\xbchlen .'
# Original sentence:
# A young boy in a soccer uniform crying into his <unk> .
# Translated score and sentence:
# -7.867984 b'Ein kleiner Junge in einem Schwimmbecken schie\xc3\x9ft den Ball .'
# -13.435939 b'Ein kleiner Junge in einem Schwimmbecken , der sich den Ball befindet .'
# -13.598549 b'Ein kleiner Junge in einem Schwimmbecken , der sich den Baseball befindet .'
# -15.511158 b'Ein kleiner Junge in einem Schwimmbecken , der sich die Haare ins Gesicht hat .'
# Original sentence:
# A happy woman is preparing a <unk> at a coffee shop .
# Translated score and sentence:
# -11.47954 b'Eine afroamerikanische Frau bereitet sich auf einem Schneidebrett vor einem Gesch\xc3\xa4ft ein .'
# -11.967741 b'Eine afroamerikanische Frau bereitet sich auf einem Schneidebrett vor einem Gesch\xc3\xa4ft zu .'
# -12.201922 b'Eine fr\xc3\xb6hliche Frau bereitet sich auf einem Schneidebrett vor einem Gesch\xc3\xa4ft ein .'
# -12.513224 b'Eine afroamerikanische Frau bereitet sich auf einem Schneidebrett in einem Gesch\xc3\xa4ft ein .'
# Original sentence:
# A construction worker is driving heavy equipment at a work site .
# Translated score and sentence:
# -6.023193 b'Ein Bauarbeiter auf einer Baustelle .'
# -7.5135665 b'Ein Bauarbeiter tr\xc3\xa4gt auf einer Baustelle .'
# -8.312025 b'Ein Bauarbeiter tr\xc3\xa4gt auf einer Baustelle um eine Kurve .'
# -8.405922 b'Ein Bauarbeiter tr\xc3\xa4gt auf einer Baustelle eine Baustelle .'
# Original sentence:
# A woman runs after making a hit in women &apos;s softball , the catcher rises to her feet .
# Translated score and sentence:
# -28.935032 b'Eine Frau versucht , den Ball zu schlagen , w\xc3\xa4hrend ein M\xc3\xa4dchen auf der Matte auf den Schultern schl\xc3\xa4gt .'
# -29.067244 b'Eine Frau versucht , den Ball zu schlagen , w\xc3\xa4hrend ein M\xc3\xa4dchen auf der Matte auf das Bowlingbahn schl\xc3\xa4gt .'
# -29.582563 b'Eine Frau versucht , den Ball zu schlagen , w\xc3\xa4hrend ein M\xc3\xa4dchen auf der Matte auf das Base schl\xc3\xa4gt .'
# ...
# Translated score and sentence:
# -11.483079 b'Eine Frau in einer gelben Bluse versucht mit einem gro\xc3\x9fen Lastwagen aus .'
# -14.078225 b'Eine Frau in einer gelben Bluse versucht mit einem gro\xc3\x9fen Lastwagen zu .'
# -17.353254 b'Eine Frau in einer gelben Bluse versucht mit einem gro\xc3\x9fen Lastwagen aus . aus .'
# -18.552998 b'Eine Frau in einer gelben Bluse versucht mit einem gro\xc3\x9fen Lastwagen aus dem Licht her .'
# Original sentence:
# Two children cross a small brook using a stone bridge .
# Translated score and sentence:
# -11.274246 b'Zwei Kinder werden von einem kleinen Felsen \xc3\xbcber eine Br\xc3\xbccke .'
# -11.326001 b'Zwei Kinder werden von einem kleinen Felsen aus einer Br\xc3\xbccke aus .'
# -11.617763 b'Zwei Kinder werden von einem kleinen Felsen \xc3\xbcber eine Br\xc3\xbccke aus .'
# -11.899581 b'Zwei Kinder werden von einem kleinen Felsen aus einer Br\xc3\xbccke herunter .'
# Original sentence:
# Two African american females ride on a moped down a city street that appears to be in a well <unk> area of a large city area .
# Translated score and sentence:
# -18.862263 b'Zwei junge Frauen reiten auf einer st\xc3\xa4dtischen Stra\xc3\x9fe in einer Stadt an einem riesigen Tag in der Stadt entlang einer Stadt .'
# -20.358093 b'Zwei junge Frauen reiten auf einer st\xc3\xa4dtischen Stra\xc3\x9fe in einer Stadt an einem riesigen Tag in der Stadt auf einer st\xc3\xa4dtischen Stra\xc3\x9fe .'
# -20.367453 b'Zwei junge Frauen reiten auf einer st\xc3\xa4dtischen Stra\xc3\x9fe in einer Stadt an einem riesigen Tag in der Stadt auf einer Stra\xc3\x9fe in der Stadt .'
# -21.021944 b'Zwei junge Frauen reiten auf einer st\xc3\xa4dtischen Stra\xc3\x9fe in einer Stadt an einem riesigen Tag in der Stadt auf einer st\xc3\xa4dtischen Stra\xc3\x9fe in der Stadt .'
# Original sentence:
# Two boys in front of a soda machine .
# Translated score and sentence:
# -6.5934644 b'Zwei Jungen stehen vor einem Nachbarschaftsladen .'
# -6.8727164 b'Zwei Jungen stehen vor einer Maschine .'
# -7.736124 b'Zwei Jungen machen vor einem Nachbarschaftsladen .'
# -11.131933 b'Zwei Jungen machen vor einem Laden eine'
# Original sentence:
# Bicycle rider wearing black , riding down a dirt trail in a mountain bike .
# Translated score and sentence:
# -9.299635 b'Ein Motorradfahrer in schwarzer Kleidung f\xc3\xa4hrt einen Berg auf einem Weg .'
# -9.837119 b'Ein Motorradfahrer in schwarzer Kleidung f\xc3\xa4hrt mit seinem Gel\xc3\xa4ndemotorrad einen Berg hinunter .'
# -9.837639 b'Ein Motorradfahrer in schwarzer Kleidung f\xc3\xa4hrt mit einem Gel\xc3\xa4ndemotorrad einen Berg hinunter .'
# -10.3669815 b'Ein Motorradfahrer in schwarzer Kleidung f\xc3\xa4hrt mit einem Gel\xc3\xa4ndemotorrad durch einen Weg .'
# Original sentence:
# A lady with tattoos is taking a picture of a painting with her smartphone .
# Translated score and sentence:
# -8.859501 b'Eine Frau mit blonden Haaren macht ein Foto mit einem Bogen .'
# -9.356951 b'Eine Frau mit blonden Haaren macht ein Foto mit einem Freund .'
# -13.505342 b'Eine Frau mit blonden Haaren macht ein Foto mit einem Bild von der B\xc3\xbchne .'
# -13.923655 b'Eine Frau mit blonden Haaren macht ein Foto mit einem Bild mit der Aufschrift .'
# Original sentence:
# A woman in a mostly black outfit and white helmet riding a bike with blurred trees in the background .
# Translated score and sentence:
# -14.903268 b'Eine Frau , die ein wei\xc3\x9f und wei\xc3\x9f gekleidet tr\xc3\xa4gt , f\xc3\xa4hrt auf einem Fahrrad mit B\xc3\xa4umen im Hintergrund .'
# -17.799568 b'Eine Frau , die ein wei\xc3\x9f und wei\xc3\x9f gekleidet tr\xc3\xa4gt , f\xc3\xa4hrt mit dem Fahrrad auf einem Platz mit B\xc3\xa4umen im Hintergrund .'
# -17.806988 b'Eine Frau , die ein wei\xc3\x9f und wei\xc3\x9f gekleidet tr\xc3\xa4gt , f\xc3\xa4hrt mit dem Fahrrad auf der B\xc3\xa4ume mit B\xc3\xa4umen im Hintergrund .'
# -18.92944 b'Eine Frau , die ein wei\xc3\x9f und wei\xc3\x9f gekleidet tr\xc3\xa4gt , f\xc3\xa4hrt mit dem Fahrrad auf einem mit B\xc3\xa4umen ges\xc3\xa4umten Hintergrund .'
# Original sentence:
# A team of cyclists rounds a bend while nearby spectators cheer and take photographs .
# Translated score and sentence:
# -16.968388 b'Eine Gruppe von Radfahrern springt in die Luft , w\xc3\xa4hrend die Zuschauer zusehen und die Zuschauer zusehen .'
# -17.161415 b'Eine Gruppe von Radfahrern springt in die Luft , w\xc3\xa4hrend die Zuschauer zusehen und die Zuschauer zuschauen .'
# -17.277155 b'Eine Gruppe von Radfahrern springt in die Luft , w\xc3\xa4hrend die Zuschauer zusehen und die Menge zusehen .'
# -17.424694 b'Eine Gruppe von Radfahrern springt in die Luft , w\xc3\xa4hrend die Zuschauer zusehen und die Menge zuschauen .'
# Original sentence:
# Four football players in black are tackling the opposing team &apos;s player , shown in white , while it is raining .
# Translated score and sentence:
# -12.666565 b'Vier Fu\xc3\x9fballspieler in wei\xc3\x9fen Trikots versuchen einen anderen Spieler in einem schwarzen Trikot .'
# -12.674184 b'Vier Fu\xc3\x9fballspieler in wei\xc3\x9fen Trikots versuchen einen anderen Spieler im schwarzen Trikot .'
# -16.207804 b'Vier Fu\xc3\x9fballspieler in wei\xc3\x9fen Trikots versuchen einen anderen Spieler in einem schwarzen Trikot , der andere ist .'
# -17.330019 b'Vier Fu\xc3\x9fballspieler in wei\xc3\x9fen Trikots versuchen einen anderen Spieler in einem schwarzen Trikot , der andere ist dabei .'
# Original sentence:
# A runner <unk> for <unk> while being <unk> down by two <unk> .
# Translated score and sentence:
# -15.961144 b'Ein L\xc3\xa4ufer wird von einem anderen Bullen von einer Mannschaft angefeuert .'
# -18.694164 b'Ein L\xc3\xa4ufer wird von einem anderen Bullen von einer Gruppe von Zuschauern beobachtet .'
# -18.93104 b'Ein L\xc3\xa4ufer wird von der anderen Mannschaft von einer Gruppe von Zuschauern beobachtet .'
# -19.182346 b'Ein L\xc3\xa4ufer wird von der anderen Mannschaft von einer Gruppe von Zuschauern umgeben .'
# Original sentence:
# The basketball player in the white uniform with the number <unk> on it is guarding the player in the black uniform with the number 10 on it .
# Translated score and sentence:
# -23.129457 b'Der Basketballspieler in einem wei\xc3\x9fen Trikot mit der Nummer der Nummer der Nummer Mannschaft im wei\xc3\x9fen Trikot auf der Nummer der wei\xc3\x9fen Mannschaft .'
# -26.20908 b'Der Basketballspieler in einem wei\xc3\x9fen Trikot mit der Nummer der Nummer der Nummer Mannschaft im Hintergrund , der von der anderen Mannschaft im wei\xc3\x9fen Trikot befindet .'
# -28.4021 b'Der Basketballspieler in einem wei\xc3\x9fen Trikot mit der Nummer der Nummer der Nummer Mannschaft im Hintergrund , der von der anderen Mannschaft in der wei\xc3\x9fen Mannschaft befindet .'
# -28.530342 b'Der Basketballspieler in einem wei\xc3\x9fen Trikot mit der Nummer der Nummer der Nummer Mannschaft im Hintergrund , der von der anderen Mannschaft im wei\xc3\x9fen Trikot befindet sich .'
# Original sentence:
# A man is talking on a cellphone outside .
# Translated score and sentence:
# -2.8047836 b'Ein Mann telefoniert mit seinem Mobiltelefon .'
# -3.671677 b'Ein Mann telefoniert mit einem Mobiltelefon .'
# -3.6924002 b'Ein Mann spricht mit seinem Mobiltelefon .'
# -6.1794963 b'Ein Mann spricht mit seinem Mobiltelefon auf einem Gehweg .'
# Original sentence:
# <unk> baseball players during the All Star game watch an opponent at bat .
# Translated score and sentence:
# -24.281473 b'Footballspieler der Ball versuchen , w\xc3\xa4hrend der Schiedsrichter ein Spiel auf dem Eis Plate .'
# -24.444118 b'Footballspieler der Ball versuchen , w\xc3\xa4hrend der Schiedsrichter ein Spiel auf dem Home Plate .'
# -24.800686 b'Footballspieler der Ball versuchen , w\xc3\xa4hrend der Schiedsrichter ein Spiel auf dem Home Base .'
# -29.016611 b'Footballspieler der Ball versuchen , w\xc3\xa4hrend der Schiedsrichter ein Spiel auf dem Spielfeld des Balls'
# Original sentence:
# Dirt biker makes a sloping turn in a forest during the fall .
# Translated score and sentence:
# -10.096351 b'Ein Gel\xc3\xa4ndemotorradfahrer macht einen Stunt im Wald .'
# -11.893117 b'Ein Gel\xc3\xa4ndemotorradfahrer nimmt einen unbefestigten Tag im Wald ab .'
# -11.913845 b'Ein Gel\xc3\xa4ndemotorradfahrer nimmt einen unbefestigten Tag im Wald entlang .'
# -12.442242 b'Ein Gel\xc3\xa4ndemotorradfahrer nimmt einen unbefestigten Tag im Wald auf .'
# Original sentence:
# 3 basketball players <unk> for the ball and one in red jersey trying to take ball from guy in white jersey .
# Translated score and sentence:
# -21.676876 b'Zwei Basketballspieler in einem Trikot versuchen den Ball zu , wie ein Spieler in einem wei\xc3\x9fen Trikot und der andere Mannschaft versucht .'
# -23.530594 b'Zwei Basketballspieler in einem Trikot versuchen den Ball zu , wie ein Spieler in einem wei\xc3\x9fen Trikot und der andere Mannschaft in einem wei\xc3\x9fen Trikot versucht .'
# -23.583565 b'Zwei Fu\xc3\x9fballspieler in einem Trikot versuchen den Ball zu , wie ein Spieler in einem wei\xc3\x9fen Trikot und der andere Mannschaft in einem wei\xc3\x9fen Trikot versucht .'
# -23.602983 b'Zwei Footballspieler in einem Trikot versuchen den Ball zu , wie ein Spieler in einem wei\xc3\x9fen Trikot und der andere Mannschaft in einem wei\xc3\x9fen Trikot versucht .'
# Original sentence:
# A boy grabs his leg as he jumps in the air .
# Translated score and sentence:
# -8.159508 b'Ein Junge h\xc3\xa4lt seine Arme nach oben in die Luft .'
# -11.331953 b'Ein Junge dreht sich die Hand , um den Ball zu fangen .'
# -12.668949 b'Ein Junge dreht sich die Hand , um den Ball in die Luft zu fangen .'
# -12.70064 b'Ein Junge dreht sich die Hand , um den Ball in der Luft zu fangen .'
# Original sentence:
# Two children wearing striped sweaters and black pants tussle outdoors near a play set .
# Translated score and sentence:
# -10.858611 b'Zwei Kinder in T-Shirts und T-Shirts gestreiften T-Shirts stehen im Freien .'
# -13.60527 b'Zwei Kinder in T-Shirts und T-Shirts gestreiften T-Shirts stehen im Freien auf einem Bett .'
# -14.191189 b'Zwei Kinder in T-Shirts und T-Shirts gestreiften T-Shirts stehen im Freien und spielen zusammen .'
# -17.328588 b'Zwei Kinder in T-Shirts und T-Shirts gestreiften T-Shirts stehen im Freien und spielen vor einem Springbrunnen .'
# Original sentence:
# A man wearing sunglasses is riding a scooter .
# Translated score and sentence:
# -2.7897227 b'Ein Mann mit Sonnenbrille f\xc3\xa4hrt auf einem Roller .'
# -2.7912672 b'Ein Mann mit Sonnenbrille f\xc3\xa4hrt auf einem Motorrad .'
# -2.8680372 b'Ein Mann mit Sonnenbrille f\xc3\xa4hrt auf einem Motorroller .'
# -2.942026 b'Ein Mann mit Sonnenbrille f\xc3\xa4hrt auf einem Bike .'
# Original sentence:
# A small boy wearing baseball <unk> holds a bat behind his head with a baseball mounted in front of him .
# Translated score and sentence:
# -27.676609 b'Ein kleiner Junge , der einen Basketball tr\xc3\xa4gt , h\xc3\xa4lt einen Schl\xc3\xa4ger , w\xc3\xa4hrend er hinter ihm mit der Aufschrift \xe2\x80\x9e Balls steht .'
# -27.972982 b'Ein kleiner Junge , der einen Basketball tr\xc3\xa4gt , h\xc3\xa4lt einen Schl\xc3\xa4ger , w\xc3\xa4hrend er hinter ihm mit der Aufschrift \xe2\x80\x9e Balls h\xc3\xa4ngt .'
# -27.984438 b'Ein kleiner Junge , der einen Basketball tr\xc3\xa4gt , h\xc3\xa4lt einen Schl\xc3\xa4ger , w\xc3\xa4hrend er hinter ihm mit der Aufschrift \xe2\x80\x9e Balls \xe2\x80\x9c ist .'
# -28.532345 b'Ein kleiner Junge , der einen Basketball tr\xc3\xa4gt , h\xc3\xa4lt einen Schl\xc3\xa4ger , w\xc3\xa4hrend er hinter ihm mit der Aufschrift \xe2\x80\x9e Love \xe2\x80\x9c steht .'
# Original sentence:
# Six men sit in a field of crops containing wooden crates .
# Translated score and sentence:
# -11.588806 b'Sechs M\xc3\xa4nner sitzen auf einem Ger\xc3\xbcst in der N\xc3\xa4he von Baumst\xc3\xa4mmen .'
# -11.910819 b'Sechs M\xc3\xa4nner sitzen auf einem Ger\xc3\xbcst in der N\xc3\xa4he von Beton .'
# -15.596045 b'Sechs M\xc3\xa4nner sitzen auf einem Ger\xc3\xbcst in der N\xc3\xa4he von einer Reihe .'
# -17.831347 b'Sechs M\xc3\xa4nner sitzen auf einem Ger\xc3\xbcst in der N\xc3\xa4he von einer Art .'
# Original sentence:
# A brown dog picks up a twig from a stone surface .
# Translated score and sentence:
# -11.37151 b'Ein brauner Hund sch\xc3\xbcttelt eine Ziege aus einem Stein .'
# -15.689501 b'Ein brauner Hund wird von einer Stange aus einer Stange aus .'
# -19.203142 b'Ein brauner Hund wird von einer Stange aus , um eine Leine zu fangen .'
# -19.728167 b'Ein brauner Hund wird von einer Stange aus , um ein Eis zu .'
# Original sentence:
# This is a man dressed in yellow holding the <unk> of a brown horse
# Translated score and sentence:
# -11.034946 b'Ein Mann in einem gelben Trikot h\xc3\xa4lt den anderen eines Jungen .'
# -11.939573 b'Ein Mann in einem gelben Trikot h\xc3\xa4lt einen kleinen Jungen auf einem Pferd .'
# -12.086992 b'Ein Mann in einem gelben Trikot h\xc3\xa4lt einen anderen Jungen auf einem Feld .'
# -12.090689 b'Ein Mann in einem gelben Trikot h\xc3\xa4lt einen kleinen Jungen auf einem Feld .'
# Original sentence:
# A man in a white shirt and apron cuts up a bird .
# Translated score and sentence:
# -6.9746146 b'Ein Mann in einem wei\xc3\x9fen Hemd und mit Brille schneidet einen Fisch .'
# -7.0634317 b'Ein Mann in einem wei\xc3\x9fen Hemd und mit Sch\xc3\xbcrze schneidet einen Fisch .'
# -7.917148 b'Ein Mann in einem wei\xc3\x9fen Hemd und mit Sch\xc3\xbcrze bereitet einen Fisch .'
# -8.056977 b'Ein Mann in einem wei\xc3\x9fen Hemd und mit Brille bereitet einen Fisch .'
# Original sentence:
# A hispanic woman is using a outdoors wok to cook .
# Translated score and sentence:
# -9.486502 b'Eine braunhaarige Frau benutzt drau\xc3\x9fen vor einem Markt .'
# -11.464833 b'Eine braunhaarige Frau macht im Freien einen Kuchen mit Essen .'
# -12.205217 b'Eine braunhaarige Frau macht im Freien mit einem Kuchen vor .'
# -12.878894 b'Eine braunhaarige Frau macht im Freien mit einem Teller vor .'
# Original sentence:
# Marathon runners are racing on a city street , with other people standing around .
# Translated score and sentence:
# -12.751486 b'L\xc3\xa4ufer fahren auf einer Stra\xc3\x9fe in der N\xc3\xa4he von Leuten und andere Leute .'
# -13.031063 b'L\xc3\xa4ufer fahren auf einer Stra\xc3\x9fe in der N\xc3\xa4he von Menschen und andere Leute .'
# -13.360295 b'L\xc3\xa4ufer fahren auf einer Stra\xc3\x9fe in der N\xc3\xa4he von Leuten und andere Personen .'
# -13.658027 b'L\xc3\xa4ufer fahren auf einer Stra\xc3\x9fe in der N\xc3\xa4he von Menschen und andere Personen .'
# Original sentence:
# Asian woman wearing a sunhat while riding a bike .
# Translated score and sentence:
# -7.168694 b'Eine blonde Frau in einem Rollstuhl f\xc3\xa4hrt auf einem Fahrrad .'
# -7.540186 b'Eine blonde Frau in einem Tr\xc3\xa4gerhemd f\xc3\xa4hrt auf einem Fahrrad .'
# -7.551667 b'Eine blonde Frau in einem Kost\xc3\xbcm f\xc3\xa4hrt auf einem Fahrrad .'
# -7.5778418 b'Eine blonde Frau in einem Anzug f\xc3\xa4hrt auf einem Fahrrad .'
# Original sentence:
# Some children are outside playing in the dirt where two trees are .
# Translated score and sentence:
# -9.609521 b'Einige Kinder spielen im Freien auf zwei B\xc3\xa4umen .'
# -11.810652 b'Einige Kinder spielen im Freien auf der Wiese und zwei Hunde .'
# -12.288638 b'Einige Kinder spielen im Freien auf der Wiese und spielen Fu\xc3\x9fball .'
# -12.711921 b'Einige Kinder spielen im Freien auf einer Wiese und spielen Fu\xc3\x9fball .'
# Original sentence:
# An older man is playing a video arcade game .
# Translated score and sentence:
# -3.0494556 b'Ein \xc3\xa4lterer Mann spielt ein Instrument .'
# -3.1128752 b'Ein \xc3\xa4lterer Mann spielt ein Saiteninstrument .'
# -3.5471842 b'Ein \xc3\xa4lterer Mann spielt ein Videospiel .'
# -9.29527 b'Ein \xc3\xa4lterer Mann spielt ein Videospiel f\xc3\xbcr ein Kartenspiel .'
# Original sentence:
# A girl at the shore of a beach with a mountain in the distance .
# Translated score and sentence:
# -6.339472 b'Ein M\xc3\xa4dchen steht am Strand mit einem Berg im Wald .'
# -6.4969273 b'Ein M\xc3\xa4dchen steht am Strand mit einem Berg im Hintergrund .'
# -6.9162197 b'Ein M\xc3\xa4dchen steht am Strand mit einem Berg im Fluss .'
# -7.3415184 b'Ein M\xc3\xa4dchen steht am Strand mit einem Berg in der Ferne .'

# %% [markdown]
# 可以观察到如下的预测结果输出：

# %% [markdown]
# Original sentence:
# Two adults and two children sit on a park bench .
# Translated score and sentence:
# -2.5993705 Zwei Erwachsene und zwei Kinder sitzen auf einer Parkbank .
# -2.6617606 Zwei Erwachsene und zwei Kinder spielen auf einer Parkbank .
# -3.186554 Zwei Erwachsene und zwei Kinder sitzen auf einer Bank .
# -3.4353821 Zwei Erwachsene und zwei Kinder spielen auf einer Bank .

# %% [markdown]
# ## 总结
#
# 端到端的神经网络机器翻译是近几年兴起的一种全新的机器翻译方法。本章中，我们介绍了NMT中典型的“编码器-解码器”框架。由于NMT是一个典型的Seq2Seq（Sequence to Sequence，序列到序列）学习问题，因此，Seq2Seq中的query改写（query rewriting）、摘要、单轮对话等问题都可以用本教程的模型来解决。
#
# <a name="参考文献"></a>
# ## 参考文献
#
# 1. Koehn P. [Statistical machine translation](https://books.google.com.hk/books?id=4v_Cx1wIMLkC&printsec=frontcover&hl=zh-CN&source=gbs_ge_summary_r&cad=0#v=onepage&q&f=false)[M]. Cambridge University Press, 2009.
# 2. Cho K, Van Merriënboer B, Gulcehre C, et al. [Learning phrase representations using RNN encoder-decoder for statistical machine translation](http://www.aclweb.org/anthology/D/D14/D14-1179.pdf)[C]//Proceedings of the 2014 Conference on Empirical Methods in Natural Language Processing (EMNLP), 2014: 1724-1734.
# 3. Chung J, Gulcehre C, Cho K H, et al. [Empirical evaluation of gated recurrent neural networks on sequence modeling](https://arxiv.org/abs/1412.3555)[J]. arXiv preprint arXiv:1412.3555, 2014.
# 4.  Bahdanau D, Cho K, Bengio Y. [Neural machine translation by jointly learning to align and translate](https://arxiv.org/abs/1409.0473)[C]//Proceedings of ICLR 2015, 2015.
# 5. Papineni K, Roukos S, Ward T, et al. [BLEU: a method for automatic evaluation of machine translation](http://dl.acm.org/citation.cfm?id=1073135)[C]//Proceedings of the 40th annual meeting on association for computational linguistics. Association for Computational Linguistics, 2002: 311-318.
#
# <br/>
# <a rel="license" href="http://creativecommons.org/licenses/by-sa/4.0/"><img alt="知识共享许可协议" style="border-width:0"
# src="./88x31.png" /></a><br /><span xmlns:dct="http://purl.org/dc/terms/" href="http://purl.org/dc/dcmitype/Text" property="dct:title" rel="dct:type">本教程</span> 由 <a xmlns:cc="http://creativecommons.org/ns#" href="http://book.paddlepaddle.org" property="cc:attributionName" rel="cc:attributionURL">PaddlePaddle</a> 创作，采用 <a rel="license" href="http://creativecommons.org/licenses/by-sa/4.0/">知识共享 署名-相同方式共享 4.0 国际 许可协议</a>进行许可。
